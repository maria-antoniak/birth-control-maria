# %%
from collections import defaultdict
import random

import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import classification_report

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='ticks', font_scale=1.2)
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
data_directory_path   = '/Volumes/Passport-1/data/birth-control'
output_directory_path = '/Volumes/Passport-1/output/birth-control'

# %%
maria_path         = data_directory_path + '/labeling/labeled_by_maria.all.csv'
leann_reddit_path  = data_directory_path + '/labeling/labeled_by_leann.reddit-all.csv'
leann_twitter_path = data_directory_path + '/labeling/labeled_by_leann.twitter-all.csv'
leann_extra_path   = data_directory_path + '/labeling/labeled_by_leann.reddit_extra_examples.csv'
roz_path           = data_directory_path + '/labeling/labeled_by_roz.all.csv'

# %% [markdown]
# <br><br>
#
# # Load labeled data

# %% [markdown]
# ## MARIA

# %%
maria_df = pd.read_csv(maria_path)

# %%
len(maria_df.index)
# Out:
# 2570

# %%
maria_df['Labeler'] = 'Maria'

# %%
def rename_source(text):
    if text == 'reddit':
        return 'reddit-posts'
    return text

maria_df['Source'] = maria_df['Source'].apply(rename_source)

# %%
maria_df['Source'].value_counts()
# Out:
# reddit-comments    711
# reddit-posts       696
# twitter-replies    594
# twitter-posts      569
# Name: Source, dtype: int64

# %%
maria_df.sample(3)
# Out:
#       Unnamed: 0           Source       ID                            Label  \
# 812          812  reddit-comments  dnnjkyj            PROVIDING EXPERIENCES
# 1069        1069  reddit-comments  erp3kie            PROVIDING EXPERIENCES
# 903          903  reddit-comments  euzcfix  PROVIDING INFORMATIONAL SUPPORT
#
#                                                    Text Labeler
# 812   I just literally got Mirena today and my nexpl...   Maria
# 1069  I am on both. My clinic doc said they would wo...   Maria
# 903   That sounds awful! I know that copper IUDs are...   Maria

# %% [markdown]
# ## LEANN

# %%
leann_df = pd.concat([pd.read_csv(leann_reddit_path), pd.read_csv(leann_twitter_path), pd.read_csv(leann_extra_path)])

# %%
len(leann_df.index)
# Out:
# 2459

# %%
leann_df['Labeler'] = 'LeAnn'

# %%
leann_df['Source'] = leann_df['Source'].apply(rename_source)

# %%
leann_df['Source'].value_counts()
# Out:
# reddit-posts       666
# reddit-comments    621
# twitter-replies    621
# twitter-posts      551
# Name: Source, dtype: int64

# %%
leann_df.sample(3)
# Out:
#       Unnamed: 0           Source                  ID                  Label  \
# 1006        1006  reddit-comments             dtu9z3p  PROVIDING EXPERIENCES
# 719          719  reddit-comments             ffthgin  PROVIDING EXPERIENCES
# 589          589  twitter-replies  957870938338611200              DISCOURSE
#
#                                                    Text Labeler
# 1006  Damn beat me to it\n\nSo I can only vouch a-sp...   LeAnn
# 719   I supposed it’s possible but I’d think unlikel...   LeAnn
# 589   @FireCap203 @SlythSeeker2017 @DaddyLou13 @John...   LeAnn

# %% [markdown]
# ## ROZ

# %%
roz_df = pd.read_csv(roz_path)

# %%
len(roz_df.index)
# Out:
# 1617

# %%
roz_df['Labeler'] = 'Roz'

# %%
roz_df.sample(3)
# Out:
#       Unnamed: 0         Source                  ID  \
# 462          462   reddit-posts              4se0en
# 1073        1073  twitter-posts  804534043438174200
# 190          190   reddit-posts              60jyh8
#
#                                 Label  \
# 462     SEEKING INFORMATIONAL SUPPORT
# 1073  PROVIDING INFORMATIONAL SUPPORT
# 190     SEEKING INFORMATIONAL SUPPORT
#
#                                                    Text Labeler
# 462   [TITLE: skyla iud moderate cramping and bleedi...     Roz
# 1073  #IUD appointments up 82% after Trump's win. Re...     Roz
# 190   [TITLE: implantation bleeding??] \n\nOkay so l...     Roz

# %%
roz_df['Source'].value_counts()
# Out:
# reddit-posts       487
# reddit-comments    447
# twitter-replies    344
# twitter-posts      339
# Name: Source, dtype: int64

# %% [markdown]
# ## COMBINED

# %%
combined_df = pd.concat([maria_df, leann_df, roz_df])
len(combined_df.index)
# Out:
# 6646

# %%
combined_df.sample(3)
# Out:
#       Unnamed: 0         Source                  ID                  Label  \
# 1776        1776  twitter-posts  224376666414260220              DISCOURSE
# 423          423  twitter-posts          3686275807              DISCOURSE
# 1502        1502  twitter-posts  319207933743333400  PROVIDING EXPERIENCES
#
#                                                    Text Labeler
# 1776  Urgh....Sitting in this airport has reminded m...   Maria
# 423   Thinking about getting the Mirena IUD or alrea...   LeAnn
# 1502  Implanon is the best birth control ever!!! Not...   Maria

# %%
combined_df['Label'].value_counts(normalize=True)
# Out:
# PROVIDING EXPERIENCES              0.252784
# PROVIDING INFORMATIONAL SUPPORT    0.225399
# DISCOURSE                          0.177550
# SEEKING INFORMATIONAL SUPPORT      0.157087
# SEEKING EXPERIENCES                0.089377
# SEEKING EMOTIONAL SUPPORT          0.064851
# PROVIDING EMOTIONAL SUPPORT        0.032952
# Name: Label, dtype: float64

# %%
combined_df['ID'] = combined_df['ID'].astype(str)

# %%
combined_df.sample(3)
# Out:
#      Unnamed: 0           Source       ID                          Label  \
# 288         288     reddit-posts   hq2x0o            SEEKING EXPERIENCES
# 577         577     reddit-posts   4qaku3  SEEKING INFORMATIONAL SUPPORT
# 486         486  reddit-comments  exeejsv    PROVIDING EMOTIONAL SUPPORT
#
#                                                   Text Labeler
# 288  [TITLE: hello, i am looking for advice with th...   Maria
# 577  [TITLE: brown spotting with copper iud - is it...   Maria
# 486  You should take it easy for the first week at ...     Roz

# %%
id_labeler_labels_dict = defaultdict(lambda: defaultdict(list))
id_data_dict = {}
for i, r in combined_df.iterrows():
    id_labeler_labels_dict[r['ID']][r['Labeler']].append(r['Label'])
    id_data_dict[r['ID']] = r

dicts_for_comparison = []
for _id, _labeler_labels_dict in id_labeler_labels_dict.items():
    _dict = {'ID': _id,
             'Source': id_data_dict[_id]['Source'],
             'Text': id_data_dict[_id]['Text']}
    for _labeler, _labels in _labeler_labels_dict.items():
        _dict[_labeler] = _labels
    dicts_for_comparison.append(_dict)
df_for_comparison = pd.DataFrame(dicts_for_comparison)

df_for_comparison.sample(5)
# Out:
#                       ID           Source  \
# 1092  403249844200177660    twitter-posts
# 1479  329387870299246600    twitter-posts
# 658              e3t0jvx  reddit-comments
# 111               a7w4d5     reddit-posts
# 1622   59009287917281280  twitter-replies
#
#                                                    Text  \
# 1092      I'm so nervous to get this nexplanon put it 😰
# 1479  VOA Literary News: FDA Makes Contraceptive Pil...
# 658   If the IUD isn't sitting in the fundus(near th...
# 111   [TITLE: nexplanon &amp; mental health] \n\nI'v...
# 1622  @bellawrites Yes, Mirena is an IUD which also ...
#
#                                   Maria  \
# 1092        [SEEKING EMOTIONAL SUPPORT]
# 1479  [PROVIDING INFORMATIONAL SUPPORT]
# 658   [PROVIDING INFORMATIONAL SUPPORT]
# 111             [PROVIDING EXPERIENCES]
# 1622  [PROVIDING INFORMATIONAL SUPPORT]
#
#                                        LeAnn  \
# 1092  [DISCOURSE, SEEKING EMOTIONAL SUPPORT]
# 1479       [PROVIDING INFORMATIONAL SUPPORT]
# 658        [PROVIDING INFORMATIONAL SUPPORT]
# 111                  [PROVIDING EXPERIENCES]
# 1622       [PROVIDING INFORMATIONAL SUPPORT]
#
#                                                     Roz
# 1092                        [SEEKING EMOTIONAL SUPPORT]
# 1479                                                NaN
# 658                   [PROVIDING INFORMATIONAL SUPPORT]
# 111   [SEEKING EMOTIONAL SUPPORT, PROVIDING EXPERIEN...
# 1622                  [PROVIDING INFORMATIONAL SUPPORT]

# %%
df_for_comparison.to_csv(data_directory_path + '/labeling/labels_for_comparison.csv')

# %% [markdown]
# <br><br>
#
# # Compare labels for REDDIT POSTS

# %%
target_df = combined_df[combined_df['Source'] == 'reddit-posts']

# %%
id_text_dict = {}
for i, r in target_df.iterrows():
    id_text_dict[r['ID']] = r['Text']

# %%
len(id_text_dict)
# Out:
# 502

# %%
ids_labeled_by_roz = list(set([r['ID'] for i, r in target_df.iterrows() if r['Labeler'] == 'Roz']))
len(ids_labeled_by_roz)
# Out:
# 301

# %%
id_labeler_labels_dict = defaultdict(lambda: defaultdict(list))
for i, r in target_df.iterrows():
    if r['ID'] in ids_labeled_by_roz:
        id_labeler_labels_dict[r['ID']][r['Labeler']].append(r['Label'])
len(id_labeler_labels_dict)
# Out:
# 301

# %%
disagreements = []
for _id, _labeler_labels_dict in id_labeler_labels_dict.items():
    _maria_labels = _labeler_labels_dict['Maria']
    _leann_labels = _labeler_labels_dict['LeAnn']
    if sorted(_maria_labels) != sorted(_leann_labels):
        disagreements.append(_id)
len(disagreements)
# Out:
# 105

# %%
disagreements = []
for _id, _labeler_labels_dict in id_labeler_labels_dict.items():
    _maria_labels = _labeler_labels_dict['Maria']
    _roz_labels = _labeler_labels_dict['Roz']
    if sorted(_maria_labels) != sorted(_roz_labels):
        disagreements.append(_id)
len(disagreements)
# Out:
# 118

# %%
for _id in disagreements:
    # print(id_text_dict[_id])
    print(_id)
    print('Maria:', sorted(id_labeler_labels_dict[_id]['Maria']))
    print('Roz:', sorted(id_labeler_labels_dict[_id]['Roz']))
    print()
# Out:
# ch4aux
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING INFORMATIONAL SUPPORT']
#
# b9f1dj
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# 8d8u3h
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# fhewxq
# Maria: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# 6k0fpw
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['PROVIDING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# icyygr
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING INFORMATIONAL SUPPORT']
#
# d4auko
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# hrp6tb
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# 5r4va3
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# 96ldyj
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['PROVIDING EXPERIENCES', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# jepuyl
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# dqvjbb
# Maria: ['SEEKING EXPERIENCES']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# hxtcvx
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# fm3yuw
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# dqeyon
# Maria: ['PROVIDING EXPERIENCES', 'SEEKING EXPERIENCES']
# Roz: ['PROVIDING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
#
# akx2l0
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
# Roz: ['DISCOURSE', 'SEEKING EXPERIENCES']
#
# 47rsi5
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# g4hmr0
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# dg2mxt
# Maria: ['SEEKING EXPERIENCES']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
#
# 6uj77q
# Maria: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
#
# 6whiyr
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['PROVIDING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# 32fu8w
# Maria: ['SEEKING EXPERIENCES']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# hoy90d
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# 2f8atl
# Maria: ['DISCOURSE', 'SEEKING EXPERIENCES']
# Roz: ['SEEKING EXPERIENCES']
#
# dqm3vp
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# 7hohb0
# Maria: ['SEEKING EXPERIENCES']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# a7blpl
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# 3rdhy2
# Maria: ['DISCOURSE', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING INFORMATIONAL SUPPORT']
#
# adwj58
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# cq8bum
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# croqm4
# Maria: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
#
# 87omzo
# Maria: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# br8v50
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# ip057f
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# asuy3s
# Maria: ['PROVIDING EXPERIENCES', 'SEEKING EXPERIENCES']
# Roz: ['PROVIDING EXPERIENCES']
#
# 4kfnww
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# hqa29b
# Maria: ['PROVIDING EXPERIENCES', 'SEEKING EXPERIENCES']
# Roz: ['PROVIDING EXPERIENCES', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# 7p7z49
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# 2rdan6
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# 5htno2
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# 207fy8
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# bxt1gy
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# 6hjfwu
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# a7w4d5
# Maria: ['PROVIDING EXPERIENCES']
# Roz: ['PROVIDING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT']
#
# ja4xtp
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# j8zl0h
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# 5473mg
# Maria: ['PROVIDING INFORMATIONAL SUPPORT']
# Roz: ['PROVIDING EXPERIENCES', 'PROVIDING INFORMATIONAL SUPPORT']
#
# adiluc
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# 8nx66c
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
#
# empeyy
# Maria: ['SEEKING EMOTIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
#
# bjlpuv
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
#
# 5fnt7t
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# tbty3
# Maria: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EXPERIENCES']
#
# agid0b
# Maria: ['PROVIDING EMOTIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# Roz: ['PROVIDING EXPERIENCES']
#
# 6k6cwn
# Maria: ['SEEKING EXPERIENCES']
# Roz: ['PROVIDING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
#
# ej03po
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# ahnwel
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# 6mpgcd
# Maria: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# eyqp5d
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# 188b2w
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
# Roz: ['SEEKING EXPERIENCES']
#
# 4nf1v0
# Maria: ['SEEKING EXPERIENCES']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# c8ampd
# Maria: ['PROVIDING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT']
# Roz: ['PROVIDING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
#
# gcdv2u
# Maria: ['SEEKING EXPERIENCES']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
#
# geno68
# Maria: ['SEEKING EXPERIENCES']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
#
# f9m58x
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# 2fcrs3
# Maria: ['PROVIDING EXPERIENCES', 'PROVIDING INFORMATIONAL SUPPORT']
# Roz: ['PROVIDING EXPERIENCES']
#
# awqk3g
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING INFORMATIONAL SUPPORT']
#
# 4cb3q3
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
# Roz: ['SEEKING EXPERIENCES']
#
# 20pyds
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# d2kf2z
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# 97k4ra
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING INFORMATIONAL SUPPORT']
#
# etft5a
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# gkolnb
# Maria: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EXPERIENCES']
#
# fnp7oz
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# 84ldkz
# Maria: ['PROVIDING EXPERIENCES']
# Roz: ['PROVIDING EMOTIONAL SUPPORT', 'PROVIDING EXPERIENCES', 'PROVIDING INFORMATIONAL SUPPORT']
#
# 32sl4n
# Maria: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
#
# g357i0
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# eetc19
# Maria: ['SEEKING EXPERIENCES']
# Roz: ['SEEKING INFORMATIONAL SUPPORT']
#
# jauyp8
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
# Roz: ['SEEKING EXPERIENCES']
#
# ag48d9
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# 5f96bs
# Maria: ['SEEKING EXPERIENCES']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# 3hgc02
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# hq2x0o
# Maria: ['SEEKING EXPERIENCES']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
#
# 313z0b
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# 7ysro9
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# bdc0q4
# Maria: ['SEEKING EXPERIENCES']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# by54ok
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING INFORMATIONAL SUPPORT']
#
# 80igue
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# apqmk7
# Maria: ['SEEKING EMOTIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
#
# ah4ccf
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# exx6mu
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# amtxdt
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EXPERIENCES']
#
# 5m37qs
# Maria: ['SEEKING EXPERIENCES']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
#
# b0sjy1
# Maria: ['PROVIDING EXPERIENCES']
# Roz: ['PROVIDING EMOTIONAL SUPPORT', 'PROVIDING EXPERIENCES']
#
# 3ql32s
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# 14tpmo
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# ipq4yq
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# f6plgu
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# fdhn1t
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# ho2a10
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# co3oym
# Maria: ['DISCOURSE']
# Roz: ['DISCOURSE', 'SEEKING EMOTIONAL SUPPORT']
#
# 3lfhjz
# Maria: ['DISCOURSE', 'SEEKING EMOTIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# a5b3tj
# Maria: ['PROVIDING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT']
# Roz: ['DISCOURSE', 'SEEKING EMOTIONAL SUPPORT']
#
# dabw1i
# Maria: ['PROVIDING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT']
# Roz: ['DISCOURSE', 'PROVIDING EMOTIONAL SUPPORT', 'PROVIDING EXPERIENCES']
#
# aydazu
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
#
# 978m3d
# Maria: ['SEEKING EMOTIONAL SUPPORT']
# Roz: ['PROVIDING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT']
#
# bh8zwv
# Maria: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EXPERIENCES']
#
# hureuz
# Maria: ['PROVIDING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['PROVIDING EXPERIENCES']
#
# 1ps0g0
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# 5hoi6x
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# ifrefy
# Maria: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['PROVIDING EXPERIENCES', 'SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# 4se0en
# Maria: ['SEEKING EXPERIENCES']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# 65d0vp
# Maria: ['SEEKING EXPERIENCES']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
#
# 9hahn2
# Maria: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING INFORMATIONAL SUPPORT']
#
# 69o8cb
# Maria: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
# Roz: ['SEEKING EXPERIENCES']
#
# orqzb
# Maria: ['SEEKING EXPERIENCES']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
#
# 68qhc3
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
#
# 66m3w9
# Maria: ['PROVIDING EMOTIONAL SUPPORT', 'SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# Roz: ['PROVIDING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']

# %%
id_text_dict['96ldyj']
# Out:
# '[TITLE: i\'ve been keeping nuvaring in for 4 weeks at a time to prevent "period"/withdrawal bleeding - am i reducing effectiveness?] \n\nHey guys, I know I should speak to my gyno at my next appointment about this, but I was wondering if anyone here would have any info in the meantime. \n\nThe past few months I have not been taking my Nuvaring out after 3 weeks, but instead leaving it in for 4 and then immediately putting in a new one  to prevent withdrawal bleeding. It has been awesome lol.\n\nMy one concern is if I\'m reducing its effectiveness. Intuitively it seems like it would not effect it at all (similar to taking back-to-back oral contraceptive), but I was wondering if anyone here has a definitive answer on this. \n\nI\'ve lurked here a while - this really is a great resource. TAI for any info!'

# %%
complete_disagreements = []
for _id, _labeler_labels_dict in id_labeler_labels_dict.items():
    _maria_labels = _labeler_labels_dict['Maria']
    _roz_labels = _labeler_labels_dict['Roz']
    if not any(_label in _roz_labels for _label in _maria_labels):
        complete_disagreements.append(_id)
len(complete_disagreements)
# Out:
# 3

# %%
for _id in complete_disagreements:
    # print(id_text_dict[_id])
    print(_id)
    print('Maria:', sorted(id_labeler_labels_dict[_id]['Maria']))
    print('Roz:', sorted(id_labeler_labels_dict[_id]['Roz']))
    print()
# Out:
# bjlpuv
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
#
# eetc19
# Maria: ['SEEKING EXPERIENCES']
# Roz: ['SEEKING INFORMATIONAL SUPPORT']
#
# amtxdt
# Maria: ['SEEKING INFORMATIONAL SUPPORT']
# Roz: ['SEEKING EXPERIENCES']

# %%
id_majority_labels_dict = {}
for _id, _labeler_labels_dict in id_labeler_labels_dict.items():
    _label_count_dict = defaultdict(int)
    for _labeler, _labels in _labeler_labels_dict.items():
        for _label in _labels:
            _label_count_dict[_label] += 1
    _majority_labels = [_label for _label, _count in _label_count_dict.items() if _count >= 2]
    if _majority_labels:
        id_majority_labels_dict[_id] = _majority_labels
len(id_majority_labels_dict)
# Out:
# 301

# %%
for _id, _labels in id_majority_labels_dict.items():
    print(_id)
    print(_labels)
    print(id_text_dict[_id])
    print('=============================================')
# Out:
# 1jsiij
# ['SEEKING INFORMATIONAL SUPPORT', 'SEEKING EXPERIENCES']
# [TITLE: starting/getting birth control online with online health center?]
#
# New to all things birth control. Well, except condoms. Which my bf and I have been using up until this point. However, we both would like to ditch them or at least go without them once in awhile so I'm looking into birth control and ways to obtain it.  My preferred choice would be those ones implanted in the arm that I've read about, but due to expenses and being a poor college student at the moment... the pill seems as though the better solution to go for now.
#
# So being that I'll be at college without a mode of transportation and just overall being a socially awkward person that doesn't like to go to new places and talk to strangers all that often... I was quite intrigued in finding out Planned Parenthood has an Online Health Center and I was wondering if anyone here uses this or can give me any and all information about it?
#
# -If one has never gone in for an appt. before and has never been on BC, can this whole online visit + fee after filling out information really get you prescribed something? It *does* say on their site "It's a great option if you want to get started on the pill but haven't had a chance to book an appointment!"  ... What about if you just don't want to book an appointment? (Well, unless I'd start having issues that would needed to be discussed.)
#
# -Would they provide you with all details you should know about BC or even the specific kind you decide on? If not, would a simple question to their "Ask a Nurse" portion of the site provide such answers? Or would it be best to head to google and look for multiple resources?
#
# I guess overall I'm just wondering if it's a decent route to go for someone like myself, am trying to understand what it all entails, and would like to hear from anyone who uses it.
# =============================================
# ch4aux
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: took pill for 26 days - am i safe to start my placebo week?]
#
# Hey everybody! I'll try to make to make this very short -
#
# I'm in a LDR, I recently visited my lovely partner and the last time we've had unprotected intercourse was the night of the 21st to the 22nd of July. I should've already been on my placebo week then, but didn't want to deal with my mood swings while I was with him.
#
# Will I be protected if I take my 7 days of placebo week again starting on Saturday? This might be a no-brainer, sorry, but I just wanted to make sure! After that period, I'll start a new full blister and keep the started one for backup.
#
# Many thanks!
# =============================================
# avhdj7
# ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
# [TITLE: nervous about starting birth control for the first time (lo loestrin fe)]
#
# I am supposed to start taking Lo Loestrin Fe today but I am really nervous about the side effects. I have never taken any birth control before so I don’t have anything to compare it to. I felt good about it when I left my gyno but have becoming more anxious about it since. I also made the mistake of reading all the bad reviews for this particular pill and now I am even more freaked out.
# Has anyone taken Lo Loestrin Fe? Did you have a positive or negative reaction! Should I be this worried?
# =============================================
# 7r441j
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: took loryna (yaz generic) out of order?]
#
# I ended up confusing myself today. I popped a pill out of my pack without really looking and took it, but when I looked down I noticed the pill I was to take today was still in place, and all the preceding pills had been taken. So, I must have missed a pill some time earlier in the pack and taken that one. It's weird, because I don't remember missing a pill or noticing that one was still there. I'm extremely confused.
#
# Should I take the one I was supposed to take today as well? Am I in trouble as a result of taking a pill from earlier in the pack?
# =============================================
# b9f1dj
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: birth control suggestions/advice pls!!!]
#
# I am currently on the LOLO brand combination pill (Lo Loestrin Fe). I've been on it for almost 4 years but I'm starting to have mixed feelings about it. I have almost no side effects at all, but my biggest issue is that I NEVER get my period. I know that it is very common on this pill but it gives me constant anxiety. I feel like I would be more relaxed and more trusting of my birth control if I got my period each month.
#
# I have no idea **which birth control to switch to!** I honestly don't even know if I should switch at all.
#
# I originally went on birth control to control my periods which were very irregular, very heavy and very painful (to the point that I would spend about 2 days in bed with painkillers and a heating pad).
#
# I am worried about switching to a higher dose of pill as I really *do not* want to deal with weight gain or new side effects.
#
# I will be seeing my doctor sometime in the next couple months for a prescription refill and I would like to discuss my birth control options with her. I would just like to hear some advice/suggestions so that I can make a really informed decision!
#
# **tl;dr - birth control advice/suggestions; thinking about switching from Lo Loestrin Fe.**
# =============================================
# 3pu8v4
# ['PROVIDING EXPERIENCES', 'SEEKING EXPERIENCES']
# [TITLE: i got paragard today]
#
# It hurt. They had to dialate my cervix and I had a lot of cramping for a couple of hours. My doctor made me feel very comfortable and the procedure was quick. I'm so happy I don't have to take the pill anymore! Does anyone who has it have any advice for the cramping? I'm worried it might get worse.
# =============================================
# 47lzu2
# ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# [TITLE: fighting with gyno about ortho micronor (mini pill)]
#
# I will try make this short and sweet. I switched to Ortho Micronor (mini pill) due to migraines and moved to a different state. The new Gyno prescribed Gildess FE 1/20 (combination pill). When I picked it up from CVS, I knew it wasn't right and called the Gyno. His nurse said, "it's the same and Ortho Micrnor is ONLY for those breastfeeding." I couldn't understand why I had been given it before. I called the previous Gyno nurse and she said, "They're the same pill, you're okay." I said fine and took it.
#
# Flash forward to this week (placebo week) and I've had a migraine for the past 4 days. I called to switch back and they're making me come in person to talk about my options since they refuse to put me back on Ortho Micronor since it's "only for breast feeding."
#
# Can someone please help me defend myself to him that I want to take the mini pill and not have an IUD/implant? Is OM exclusively for those breast feeding?
#
# I'm desperate to get rid of these migraines and have a gyno listen to me again. Thank you!
# =============================================
# 8tighx
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: copper coil alongside the pill]
#
# I had to go off my birth control pill briefly for medical reasons just to test if it was causing a condition. It's since become apparent that's not the case, so I'm able to go back on hormones if I want. I'd like to do this as the pill helped with my acne, and was really its main purpose.
#
# However, in the meantime in order to prevent pregnancy I got the copper coil (paragard), which has been great although it was very painful getting it put in. I want to go back on the pill to get rid of my acne again, but just worry that it'll interfere somehow with my paragard. As I've only had the paragard in for three months I don't want to go through getting it out again, plus it gives such good protection. Will having both be okay?
# =============================================
# comiha
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: cystic acne that only comes around right before my period, plus getting implant, need some advice!]
#
# I've posted here before and got such helpful feedback, figured I'd give it another go!
#
# After switching between thinking I wanted the IUD, then the implant, then the IUD.....I've 95% settled on the implant and will be getting it soon. I just have one last question/concern!
#
# One of the main reasons I'm leaning towards the Implant is because I know that the hormone in the IUD is known for worsening acne, plus my cystic acne comes around just after ovulation and before my period...and the IUD doesn't stop the cycle.
#
# Is it likely that, since my acne is cycle-related and the implant stops the cycle/ovulation, my acne will lessen? In the past, when I haven't ovulated I haven't gotten cystic acne, just regular acne! Or is the implant hormone an androgen, like the IUD hormone?
# =============================================
# insbt3
# ['SEEKING EXPERIENCES']
# [TITLE: has anyone tried “natural cycles”?]
#
# Has anyone tried “Natural Cycles”??? I don’t want to be on birth control anymore. I’m sick of the mood swings.
# =============================================
# irii49
# ['SEEKING INFORMATIONAL SUPPORT', 'SEEKING EMOTIONAL SUPPORT']
# [TITLE: going crazy thinking i’m pregnant. could it be?]
#
# So, I’m actually sweating because I’m scared as fuck I could be pregnant.
# I took the pill after the 7 days of stop eight days ago. First pill I didn’t have water with me and couldn’t take it. It melted a bit in my mouth then I reached home and took it with water, even if it crumbled a bit paid attention to take it all and nothing remained.
#
# Kept keeping it each day same hour until yesterday I felt a little bit of white discharge. Before pill I used to have ovulation but like A LOT, sometimes I had to put a pad!
# In the last two days I had a small bit of discharge but still I’m so scared! I didn’t think much about the first pill since I paid attention to not leave any crumble in the tablet and the parts that melted were actually in my mouth so...
# Now I think I might have been very dumb to have sex anyway.
# Do you think I could be pregnant? What can I do now?
# Please, please give me your opinion.
# =============================================
# j13f0n
# ['PROVIDING EXPERIENCES']
# [TITLE: i'm so happy with my bc now]
#
# So I started Ashlyna 4 months ago and off and on up until my placebo week, I was dealing with terrible and constant breakthrough bleeding. Not enough for a pad but enough to mess up cute undies. Once I went on my placebo week, all my hormones and emotions chilled the eff out for the first time in months. I have never been so relieved and happy. It's all because of taking that extra week of no hormones. So experience wise, if you just started a new BC pill, take the placebo week. It'll be worth it especially if you're going 3 months without a period. 👌😇
# =============================================
# bosdh1
# ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# [TITLE: help me]
#
# okay so i might just be overreacting but like please help! so today i got the implant inserted and everything was all good except i got called into work and so i showed up because my job doesn’t require me to lift heavy stuff up which was the only thing they warned me about. however throughout the day i noticed that the gauze was placed from the insertion point to only the middle of the implant causing the other end to pop out. i didn’t want to move the gauze so i kept working with it like that. however as the day came to an end it became extremely sore to the point where it was painful to move my arm. is this normal? or it it possible that it snapped? i’m just really freaking out. should i fix the gauze? it’s really tight on my arm so could that have snapped it since it was only covering half of the implant and there was a lot of moving around? i’m off now and the pain went down but there’s like shockwaves of heat and pain that go throughout my arm. how can i check if it’s broken once i remove the gauze?
# =============================================
# 8d8u3h
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: missed period after coming off pill. pregnant??]
#
# Okay so I came off the pill (Noriday) almost a month ago (it’ll be a whole month in 4 days) Before that, I was on Cerelle for a year and I was on Microgynon for 5 years before that. I’ve never come off the pill since starting the pill all those years ago.
#
# I stopped my pill during my last period which started on the 15th of March. The period lasted 9 days, which is not unusual for my normal flow. Until now, I hadn’t had a period in years as Cerelle stopped my periods entirely. I was expecting my period about 5-7 days ago, however it hasn’t come.
#
# Because we don’t keep condoms in the house (due to being on the pill for so long) and we were horny, we ended up having unprotected sex on the 7th but he pulled out about 3 minutes before he came and we finished him off through foreplay instead.
#
# Because my period is 5 days late, I’m worried I’m pregnant. Alongside the absence of my period, I’ve felt nauseous (without vomiting), headaches and fatigue for the last 3 days. Today, I’ve been going to the bathroom every hour despite not drinking more water than usual.
#
# I took a pregnancy test on Saturday (first day my period was late) and it came back negative, but I’m not so sure. The symptoms all point to pregnancy :/
#
# Did I take my test too soon? Could I still be pregnant or can these simply be the side effects of coming off the pill?
# =============================================
# fhewxq
# ['SEEKING INFORMATIONAL SUPPORT', 'SEEKING EXPERIENCES']
# [TITLE: errin mini pill 💊 / factor v leidin]
#
# So I got put on Errin mini pill from Yaz due to finding out I have the Factor 5 Leiden gene. I’ve been on it for about 3 months now. The first month, I kept missing my pill by a few hours pretty often and was spotting almost every week - my doctor said that could happen even if I’m off my scheduled time by 2+ hours. So I’ve been consistent with it at 8am every morning on my 3rd month. During this time, my second month period never came. I noticed my usual ovulation days are not the same as they were up until this past week - I was having watery like discharge that felt like I peed myself ?! Checked my underwear and it was just wet, no other consistency. Weird.
# My boyfriend and I had sex 2 nights ago and the next morning I missed my pill by almost 3 hours. Almost immediately I started spotting and feeling crampy. HOW!? I thought it would stop like it did during the first month but I started a full on period today. It’s all just interesting to me and I’m not really sure if it’s normal. How did the feelings happen so instantly?! Does anyone have Errin or similar experiences as this, have tips, or even some insite on being positive for Factor V Leiden?
# =============================================
# i5h6gg
# ['PROVIDING EXPERIENCES', 'PROVIDING EMOTIONAL SUPPORT']
# [TITLE: my rollercoaster iud experience (paragard) - there is light at the end of the tunnel!!!]
#
# Hi everyone, I wanted to share my experience with my copper coil with you all in case anyone else is going through the same thing - hopefully I can offer some reassurance and hope to anyone who is at their wits end with their IUD!
#
# I got mine inserted in March - it was quite a bad experience for me as the pain was unbearable and I ended up being sick and nearly passing out, it felt borderline traumatic and has put me off having one again. I then bled consistently for around 3 and a half months, which obviously put a huge weight on my shoulders - it made me have horrible dark thoughts and with my IUD being my last resort when it came to birth control (I can’t have anything hormonal due to a history of blood clots in my family), I started to panic. I tried the pill, progesterone, herbal teas etc etc.
#
# Throughout this time I also wasn’t having a period, which I found strange. I’d been on the injection and the pill before I had my IUD inserted so I thought it was just down to me having excess hormones in my body and the trauma my body went through during the insertion.
#
# About a month ago I tried Evening Primrose Oil on a whim after reading about it on here and it completely took my consistent bleeding away, to the point where I’ve just finished my first natural period with my IUD! I’ve never felt relief like it. I can have sex again and wear nice underwear whenever I want to without fear as now I can track my natural cycle! I would highly recommend this to anyone struggling with consistent bleeding as a result of hormonal birth control as I’ve seen it mentioned a few times on here.
#
# I just wanted to offer reassurance that it does come to an end for anyone currently struggling with it - your body will adjust to your IUD and things get back to normal! I’m so happy that I chose to stick it out. Anyone who is/was going through something similar please don’t hesitate to message me if you want to! But I just wanted to say that there is light at the end of the tunnel, and to always listen to your body if you think something is wrong!!
# =============================================
# 6k0fpw
# ['SEEKING INFORMATIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# [TITLE: month long period after 1 year+ on my bc pill]
#
# I've been taking Althea for over a year now, and it was great for several months. My periods became lighter and shortened to 5-7 days. But recently, I've been getting periods that last for more than a month! It's usually a steady flow of brown discharge (sometimes bright red though), and the flow is not that light or heavy either. I haven't missed any pills or changed my diet.
#
# I'm considering going to a clinic but I want to avoid this because I'm afraid of going to the doctor.
#
# Additional info if it helps: Althea contains Estrogen and Progesterone, with 21 pills.
# =============================================
# c5lqf4
# ['SEEKING INFORMATIONAL SUPPORT', 'SEEKING EMOTIONAL SUPPORT']
# [TITLE: could i be pregnant?]
#
# This is my first month on birth control and I switched birth controls after the first few weeks and started another and am now on the placebo pills. Tonight is my third placebo pill but I have not gotten my period. I sometimes have taken the pill 2 hours late maximum but it is mixed hormone so I didn’t think it was a major problem. I started having sex on my 9th day on the new pills with condoms although some of the condoms got stuck in me when he pulled out leaving me to think that it possibly came off during, which means cum could’ve gotten inside me. Am I pregnant? I’m worried that me not getting it means I’m pregnant but I’ve also heard that can b normal?
# =============================================
# 7mu61z
# ['SEEKING EXPERIENCES']
# [TITLE: anxiety with mirena?]
#
# Hi All — not sure if what I’m experiencing is due to Mirena, which was inserted almost three weeks ago, but I’ve had a recent surge of anxiety/inability to focus/overthinking small things. These emotions typically don’t plague me, so it feels a bit out of nowhere.
#
# Has anyone experienced this with Mirena, or similar IUD?
#
# Thanks!
# =============================================
# i3uz2i
# ['SEEKING EXPERIENCES']
# [TITLE: copper iud period side effects! help lowkey freaking out!]
#
# Hi ok so I have the Paragaurd (copper IUD) and I'm have it for about 10 months now and my period is very regular. But this month it seems to be "struggling" to start. Meaning cramping but with little to no bleeding. I know that your period is supposed to lessen after six months and mine never really did.
#
# Has anyone else had this experience?
#
# Just want to know if this is normal and 10 months is my six or if something is wrong. And I can't be pregnant I haven't had sex in like a month.
# =============================================
# 39jvkb
# ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
# [TITLE: anybody experience nausea or worsened hormonal symtpoms when going continuous on birth control?]
#
# So I'm 5 days into my new pill pack, this is my first time skipping the placebo week as suggested by my doctor due to pain/suspected endo.
#
# I still feel some symptoms of my period, as in my pelvic pain and bad lower backpain but the pain isnt as bad. One thing that developed tonight was some nausea, though I took my pill without food tonight. Normally I just combine it with my dinner but I was putting dinner off due to the pelvic/rlq pain. (Again, normal amount of pain for me)
#
# However, I've been on the particular pill for like six months now and have had very little problems with it! But I was wondering if starting to take it continuous makes hormones much worse? Thanks guys!
# =============================================
# icyygr
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: completely overwhelmed and completely new to birth control options]
#
# Hi,
#
# I have birth control pills (Mylan) and I'm currently sexually active. I had plan b fuck my cycle last time but I want to get protected asap and want to start taking pills soon as possible.
#
# My last period was from 23rd Jul- 28th Jul. Then I took plan B on the 28th then got my "period" on the 4th Aug - 8th Aug. Super weird. Anyway, I want to get started on the pills asap.
#
# Would it be okay to start taking Mylan starting today?
#
# Also, would I get my periods (whenever that is) and do I continue taking pills when I get the period? And how would the placebo pills work in this case?
#
# I will definitely be visiting a planned parenthood center but I want to know what I'm walking into so any information on this would be very helpful. Thank you very much.
# =============================================
# d4auko
# ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
# [TITLE: nightly leg cramps on lo loestrin fe]
#
# I’m not sure if this is a side effect of my birth control or something that is just happening. I’m at the end of my second month and I’ve been having bad calf leg cramps at night. And that’s got me worried that I could have a blood clot. I read an article about how some girls have almost died from blood clots caused from their birth control and it all started with leg cramps so now I’m freaking out! I know if could be caused from multiple things but has anyone else on this pill had any similar things happen?
# =============================================
# jdsq03
# ['SEEKING EXPERIENCES']
# [TITLE: mid-cycle bleeding?]
#
# I've been on Junel Fe 1/20 for 5 months and have had no adverse side effects, aside from a little nausea during month 1. My periods have been mostly normal until last month, when I was 5 day late and it was really light and short
#
# I've missed a couple pills here and there recently bc I'm forgetful, and this past Friday I started spotting. It's all been brown discharge and clear watery discharge, but today I've had (sorry tmi) huge brown globs of mucous coming out. I've never had anything happen like this while taking this pill and I've missed days before
#
# Just wondering if anyone has experienced anything similar?
# =============================================
# hrp6tb
# ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# [TITLE: possible pregnancy with condom/pullout/period?]
#
# Me and my girlfriend had sex almost 3 weeks ago for the first time since March. During quarantine she went off the pill so she was using no BC when we had sex. I used a condom, pulled out and she was on the second day of her period when we had sex. We had no more penetrative sex over the next few days and I only ejaculated on her upper body. She has been having some irregular bleeding/spotting for the last 2 and a half weeks and nausea along with intense stabbing pain. She has had irregular periods when she was younger and we were thinking this could be coming from her stopping birth control in mid March, as I’ve read weird stuff can be going on with a women’s periods for a few months after stopping BC. I’m pretty sure it’s basically impossible that she got pregnant but she is planning to take a test soon. Can anyone help to calm us down?
# =============================================
# 7fr11w
# ['SEEKING EXPERIENCES']
# [TITLE: any experienced sleepiness when taking yaz?]
#
# I recently have started taking Yaz and noticed that I am more tired often. My doctor hardly went over any side effects. She just said it would clear my face. It has made my periods shorter and less painful but I’m constantly tired and very emotional. Just wondering what kind of side effects you all had that have used it.
# =============================================
# 222oa5
# ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# [TITLE: panicking]
#
# So my girlfriend and I, both young adults,  recently had sex with no condom,  but I pulled out and shes on minastrin 24....should I still be freaking about possible pregnancy?
# =============================================
# 9vhn1n
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: anyone know what happened with the cost of pills at prjkt ruby?]
#
# I could have sworn when I started them last year, I could buy the packs single and now it says I need to buy them in three months each.
#
# Does anyone know what changed?
#
# I have the Nexplanon, but I've been bleeding for some time and wanted Sprintec or something to help with it.
#
# Just curious.
# =============================================
# ebmb78
# ['SEEKING EXPERIENCES']
# [TITLE: xulane/ortho evra experiences]
#
# Just got off the pill after 5 years because of how it made my skin breakout and some other issues I was having.
#
# Those who used/are using the patch, how is it? Any weight gain/loss, acne, mood swings, shorter/longer periods? Just looking for some insight before I talk to my doctor about it.
# =============================================
# a1a43s
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: two week early period on lo-loestrin fe]
#
# My girlfriend is taking Lo-Loestrin Fe, and she got her period around two and a half weeks early. We’re wondering what this means? Whenever we have sex it’s usually with a condom and I’ve never ejaculated inside of her. We suspect that it’s breakthrough bleeding, but we’re not sure. She started the pill 1.5-2 months ago. It also might be worth noting that two days in a row she was off of her regular time by like thirty minutes
# =============================================
# as6j4p
# ['PROVIDING EXPERIENCES']
# [TITLE: got my nexplanon implant today!]
#
# Decided to switch from the combined pill to nexplanon, as I am moving out of the country for grad school and wanted something long lasting that wouldn't require me getting a new prescription in a new country. I have been incredibly nervous (I rescheduled my appointment three times prior to this) but today I finally did it!
#
# Insertion was just as everyone has described - small pinch/burning for the numbing shot, another pinch when the applicator went in, and then lots of pressure when the actual implant went in. It all happened so fast! It is now about 8 hours after the procedure and I feel fine. Numbing has of course worn off, and I haven't needed ibuprofen or anything. My bicep feels a little sore (just like it usually does after any shot) and I feel a bit of pain when the implant gets touched/shifted, but nothing too serious. I took the compression bandage off briefly to take a shower, and so far I haven't bruised at all (I'm sure I will eventually though, as I bruise super easily).
#
# Only symptom I'm feeling now is short bouts of minor nausea. It could be the implant, it could be the Chinese food I ate, it could be the fact that I was advised to continue taking my pill for a week so there's a lot of hormones in my body, or it could be nerves (I was SUPER anxious today and almost threw up when they had me feel the implant in my arm). Either way, it's not too severe and I'll reevaluate the situation in the morning.
#
# Both nervous and excited to see how my body reacts to the nexplanon. My period is super irregular when I am not on birth control anyways, so irregular bleeding on this won't be anything brand new to me.
# =============================================
# 710tul
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: dirreah 2 hours after birth control]
#
# So I took my bc at 10 pm like I usually do, and at 11:58 PM I had diarreah (I have IBS, it happens sometimes).
#
# I'd normally treat this as a missed pill, but unfortunately I was late taking my pill last night as well for the first time in a long time. I took it when I got up this morning.
#
# I'm on Sprintec, it says to treat this like a missed pill so thats two missed in a row in week three. I only have two pills left in this entire pack. It's saying for me to start a whole pack over and skip my period, is this correct? I'll call my gyno tomorrow to double check as well.
# =============================================
# 5r4va3
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: second iud expelling, depo gave me my period for 2 months, pill gives me migraines]
#
# I am at a complete loss. When I was 16 I got depo and it gave me my period for two months. They switched me over to the pill and I was on it for a while until I got a migraine with an aura and they said it put me at an increased chance of stroke so they took me off. I finally got the courage to get the Paragaurd because it was hormone free and lasts practically forever, but my first one expelled completely (found it hanging out in my vagina) and my second one I got last week I can feel in my cervix so I'm going to Planned Parenthood tomorrow to have it checked out and to ask about the arm implant. Anything you would suggest I try as well?
# =============================================
# 96ldyj
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: i've been keeping nuvaring in for 4 weeks at a time to prevent "period"/withdrawal bleeding - am i reducing effectiveness?]
#
# Hey guys, I know I should speak to my gyno at my next appointment about this, but I was wondering if anyone here would have any info in the meantime.
#
# The past few months I have not been taking my Nuvaring out after 3 weeks, but instead leaving it in for 4 and then immediately putting in a new one  to prevent withdrawal bleeding. It has been awesome lol.
#
# My one concern is if I'm reducing its effectiveness. Intuitively it seems like it would not effect it at all (similar to taking back-to-back oral contraceptive), but I was wondering if anyone here has a definitive answer on this.
#
# I've lurked here a while - this really is a great resource. TAI for any info!
# =============================================
# fyx282
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: period/ovulation cycle]
#
# recently saw a post that said you don’t get your period on birth control. how does tracking ovulation work then? is it even worth tracking my ovulation week? is every week the same amount of low pregnancy risk (except placebo week)?
# =============================================
# d2wh63
# ['SEEKING INFORMATIONAL SUPPORT', 'SEEKING EMOTIONAL SUPPORT']
# [TITLE: basically having a period in the middle of my cycle (on birth control pills)]
#
# hey guys,
#
# so i'm a little bit concerned by this. i've been on the pill for 6 months, always take it on time, and have never missed a pill. i'm on my sixth pack now and i'm in the middle of the second week. since i've been on the pill, i always have a little bit of bleeding in the middle of my cycle, but nothing alarming. this time i'm bleeding a fairly large amount for what i consider normal. it's basically like a period, and it hurts like one too. i have no idea why this is happening in the middle of my cycle. i haven't missed a pill or even been late on one.
#
# my biggest fear is always pregnancy, but i'm pretty sure this isn't a symptom. it's happening right at the time i would normally be ovulating if i weren't on the pill, and that's not when implantation bleeding happens as far as i know.
#
# i really just want to make sure this doesn't mean my birth control isn't working. i do have sex at least once a week and my bf doesn't always pull out.
#
# does anyone know what this could be? is it normal or is there something wrong? is my birth control still effective? thanks!!
# =============================================
# jepuyl
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: is it a bad idea to get the copper iud if i already have bad periods?]
#
# I really want to avoid hormonal birth control so the copper IUD seems like the best option for me however my periods already suck. They are quite heavy the first couple days. I wouldn’t say super heavy, but probably above average and I get a lot of small blood clots.
#
# I also get terrible cramps, these don’t occur every period and have gotten better since I got older. There have been times I’ve been curled up in a ball because of the pain though and even felt like I was going to throw up (this is rare tho maybe once a year).
#
# I just really worried because my periods are already on the bad side this will be too much. On top of this I’m pretty sure I’m already a little anaemic. The thing is the side effects of hormonal birth control aren’t worth even trying it to me so I’m sort of stuck on what to do. I’m also worried about how the length of my periods might change on it, they are about 3-4 days atm but recently I’ve been noticing them go on longer like 7/8 days but only very light the last few days, like brown blood.
# =============================================
# dqvjbb
# ['SEEKING EXPERIENCES']
# [TITLE: iud strings disappear...then come back]
#
# I’ve had my Mirena IUD since the end of May this year 2019. No issues with it, I’ve used a pregnancy test here and there to make sure everything going well.
#
# Since I got it, I always have unprotected sex with my boyfriend
#
# I’ve noticed around the time I get my “period spotting” it’s harder to feel my strings/I can’t feel my strings. This has happened a couple of times already, but they seem to come back after I finish bleeding
#
# Does anyone else have this experience? Where the strings sort of disappear for the duration of your period then come back a bit after?
#
# I do the monthly string check, but sometimes I check it a few more times in the month. I felt it when I first checked it early October but the last week I checked and I only felt a small bump (which I think was the strings curled) and now I can’t feel anything
# =============================================
# hxtcvx
# ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT', 'SEEKING EXPERIENCES']
# [TITLE: iud spotting]
#
# Hi guys,
#
# I’ve had an IUD for a year now. At first I experienced a lot of pain with it to the point I was admitted to hospital because I was convinced it was put in wrong but since then my periods have become less painful but still heavy.
#
# However I haven’t had any spotting when I’ve not been on my period.
#
# Fast forward to a year later (now) I’m bleeding in between periods (well, only one, which is right now), probably enough to fill a couple liners a day at most and it’s kind of on and off. Is this anything to be worried about or is this normal? It’s only worrying me because it’s never happened before only just now?
#
# Any advice will be appreciated. I’m gonna check the strings when I have a shower next.
#
# Thanks! X
# =============================================
# fg951w
# ['PROVIDING EXPERIENCES', 'PROVIDING INFORMATIONAL SUPPORT']
# [TITLE: iud insertion experience from someone who does not do piv]
#
# Just want to add my experience because I’m sure there are other gays/trans people/people who don’t do PIV that might benefit! I got the liletta IUD today for long term period relief after doing depo.
#
# I took 800 mg of Motrin an hour before (they said 600 but I was expecting mega pain) and ate a protein and carb heavy breakfast hoping that I wouldn’t pass out . The doctor was super nice when I got there, she said she also has the liletta and really likes it. Explained everything well and my nerves went down a little, but spiked immediately once the speculum was in. The alignment of the cervix, measurement, and insertion were quite literally the worst pain of my life.
#
# This part is a little graphic I’ll put it in spoiler format: &gt;! The pain from the insertion made me tense so hard that I literally forced the speculum out of my body! The doctor called in the nurse practitioner to help and the nurse helped her while simultaneously calming me down. They successfully got it in despite all this. The doctor said she’s never seen that happen before, I apologized profusely !&lt;
#
# After the insertion i was a sweaty, shaky mess and laid on the exam table for a while. My glasses were completely fogged up! When I got up I almost passed out (more from adrenaline than pain) so I decided to wait some more and drank a full glass of water in the waiting room which really helped.
#
# I drove myself home and it was really uncomfortable but definitely doable. I had extreme cramps the first 2 hours, then they slowly subsided. It’s 12 hours after insertion right now and the persistent cramps are now gone, with occasional short pains. I had bleeding for the first 4 hours and then it stopped completely.
#
# Overall, I’m crossing my fingers that the pain was worth it! My tips are:
#
# 1. Tell your doctor if you don’t do PIV! I think it would have been easier if my doctor had known, so she could have prepared for my reaction.
#
# 2. Ask for local anesthesia at the clinic if it’s available
#
# 3. Don’t plan to get anything done the day of insertion
#
# 4. Have someone else drive you if possible
# =============================================
# fm3yuw
# ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# [TITLE: weird occurrences on nexplanon... please help!!]
#
# Okay. So this is going to be a long post, but I need to make sure I can explain everything to get the best answer(s) possible. Any response helps me a lot! (I am a 21 year old female college student)
#
# I got the Nexplanon implant put in my arm in June of 2018. So, it’s been in there a little over a year and a half. I have had absolutely no issues with it - no weight gain, no breast pain, no spotting/periods, nothing since the day it was put in. I wasn’t worried about the lack of periods because 1) that’s why I got it in the first place and 2) I knew it was working.
#
# My boyfriend and I started having unprotected sex in like September of 2019, but he has never ever finished in me. Fast forward to the beginning of February. My boyfriend and I had sex twice one day, I can’t remember the details but I know they were at least a couple hours apart from each other AND he peed in between. (Still never finished inside of me, but I know about precum and how there’s some slight chances it contains live sperm). That was some time at the very beginning of the month, then we had sex again on February 8th.
#
# Between then, my nipples started getting really really tender, and my roommate jokingly mentioned that I might be pregnant, so of course I started freaking out and took 2 pregnancy tests - both came out negative, but it wasn’t very long after we had sex so who even knows if it was accurate. Then on February 11th, I started spotting lightly, which then turned into a period that required me to use a tampon. That ended on the 18th, and then between the 23rd and the 28th I started bleeding again, but lighter than the first time.
#
# We did not have sex for the rest of February, because I was nervous about what was going on and also that I was bleeding so randomly. I took a pregnancy test March 3rd and another one March 11th, both came up negative. They were approximately 4-5 weeks after the time we had sex that I think I’m worried about (the time we had sex twice in a day). I read on the instructions that if you don’t pee for exactly 5 seconds that the test may be inaccurate so I keep thinking that I got a false negative because I messed something up.
#
# I really don’t think that I’m pregnant, but yesterday I noticed that my right boob has gotten bigger. It is not tender or painful or anything of the sort, I just looked in the mirror and noticed it was bigger. I also noticed bumps on my areola that were never there previously, and I know they come out during pregnancy or hormone changes. I haven’t had a period since February. I have no idea if all of these things going on are because of my implant and just the changes in hormones since it’s been in for almost two years, or if I’m pregnant... I also don’t even know if this implant is still working or if it stopped working and that’s why these things are going on. I seen around so many times if you feel the implant it’s working but what if I got a defective one or something. I feel like I’m going crazy over this thing
#
# I would talk to my parents or my boyfriend but I really can’t... I don’t have anyone to talk to so this is basically my only source of information. Please help me if you can, anything that you can tell me will help me so much. I really appreciate it. If you need any further information, I’ll tell you whatever, just ask! :)
# =============================================
# 60cgtx
# ['SEEKING EXPERIENCES']
# [TITLE: cramps after sports?]
#
# Hi ! I just finished my first period with my copper IUD and went to train at the gym for the first time since the insertion too. During but mostly post exercices I started getting ''period cramps''. Is there anyone that got cramps after training ?
#
# Thank you :)
# =============================================
# dqeyon
# ['SEEKING EXPERIENCES', 'PROVIDING EXPERIENCES']
# [TITLE: just started liletta!]
#
# I just got my liletta iud at my local Planned Parenthood yesterday, and I'd like to thank the internet for all the stories and resources available!
# So I chose to get an iud because of the 5 years of protection that I dont have to remember to take every day.
# I was terrified of a possibly painful experience so I read as many iud stories about liletta and similar iuds as I could, and even watched procedure YouTube videos to get an idea of what I was gonna expect.  When I went in for the actual procedure, it was not as painful as I thought. It was, at worst,  a 7/10, which for me is like almost some of my worst period pains, and it was quick.
# I even learned that I have a retroverted uterus! Afterwards there was some light cramping but since I'm at the end of my period anyways, it wasn't out of the ordinary. Heat pads and naps always do the trick.
# Today I feel fine. Still some cramps but very light and minimal. The only thing I am concerned with is the possibility of this thing feeding into my depressive tendencies. I say tendencies because I've never been diagnosed with depression but I've definitely felt the symptoms at one point or another. Lately work has been a nightmare and sometimes when winter comes I get a little moody, but usually I just exercise and I feel better.  When I asked the doctor about this before, he said based on my answers I should be fine. But as of right now I feel down. I'm keeping an eye on it. I'm gonna get this thing out if it gets worse.
# Anyone have a similar experience with liletta?
# =============================================
# akx2l0
# ['SEEKING EXPERIENCES']
# [TITLE: can i keep my iud after removal?]
#
# On a scale of kind of weird to super weird, how weird is it to ask my doctor tomorrow if I can keep my Skyla IUD as a weird keepsake? I know some people keep their wisdom teeth after removal.
#
# Has anyone asked their doc this before when getting an IUD removed/replaced? I’m having it replaced with a Kyleena tomorrow!
# =============================================
# 89z5oc
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: how many times can nuvaring be taken out?]
#
# Hello!  I was wondering how many times you can remove the Nuvaring for the recommended 3 hour periods.   For example, if I took it out for an hour or so one night, could I take it out for another hour the next morning?
# =============================================
# 1pu0kf
# ['SEEKING INFORMATIONAL SUPPORT', 'SEEKING EMOTIONAL SUPPORT']
# [TITLE: i'm into my second pack of generess fe, and it feels like i'm ovulating...?]
#
# I could just be imagining it because I'm paying even more attention to my body with the birth control, but I swear it feels like I'm ovulating. I start the second week of my second pack today. I'm having a lot of discharge that I only have around the time of ovulation, I'm having light cramping, increased sex drive, body temperature feels higher...
#
# Is this possible? Or is this just entirely in my head? If a hormonal birth control is not a high enough dosage for someone, could they still ovulate while taking it? I'd also like to add that I have taken it religiously at the same time and have not missed one pill. What gives?
#
# As an aside, my long distance SO was going to be in town this weekend and we were planning on having some fun (can't have penetration at this time due to a septate hymen, but we were going to try outercourse). Should I hold off on doing this if this is a thing?
# =============================================
# fjr9f0
# ['SEEKING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT']
# [TITLE: sex on the 7th day after mirena - did i mess up severly?]
#
# I had my Mirena inserted on Thursday 5th at 9am, and had unprotected sex on the following Thursday 12th at around 11pm. I had a complete mind blank when calculating the 7 days after insertion even though my OB STRESSED That I should use a barrier method till then. Does anyone have any experience with this? I have a feeling I might be over reacting, but I will take a pregnancy test at the right time regardless.
# =============================================
# 9eql4b
# ['SEEKING INFORMATIONAL SUPPORT', 'SEEKING EMOTIONAL SUPPORT']
# [TITLE: getting nexplanon before my period?]
#
# I'm having Nexplanon inserted this Thursday, the 13th, but I don't start my period til Sept. 23rd. Is this okay? I know they say you can have it inserted at any point in your cycle, but I'm just nervous about side effects. Thanks for any advice!
# =============================================
# 828gyi
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: 12th day of my period - when should i be concerned?]
#
# History: I had the Paraguard until November 1. I went to the hospital for severe abdominal pain and found out that my IUD had dislodged and was embedded in my myometrium. The IUD was removed that day and I was prescribed 0.35 mg of Norethindrone. I used the Norethindrone up until the beginning of this month. At the beginning of the month, I went to the doctor for my annual exam and explained that I was having severe cramps during my period (not before) and at that time, the doctor switched my precription to Tri-Lo-Marzia. I've made it through one full pack of the pills as of today and I am currently on the 12th day of my period. When my period began, I was in the middle of week 3 on my BC pack. My first 3 days were low flow but every day since has been regular to slightly heavy and it doesn't look like its going to stop anytime soon. The cramps continue to occur every day.
#
# I have an extensive history of extremely irregular periods. My longest period was ~60 days when I was a teenager and the irregularity occurs on all types of BC (pill, IUD, depo). At what point should I be concerned about the duration of my period and go to the doctor?
# =============================================
# 47rsi5
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: [which method?] any advice on getting mirena with pcos?]
#
# I'm currently using Nuva Ring and it's reduced a number of my PCOS symptoms (acne, facial hair, heavy flow etc.).
#
# My doctor wants me to consider Mirena, and while I like the idea, I've been reading some negative stories from women with PCOS. Now I'm wondering if it's a good idea, Nuva Ring works so why mess with it??
#
# So please, if you have any insight into how Mirena affects PCOS, I would really appreciate it :)
# =============================================
# crn8bw
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: ring back in on 28th day or the 1st day?]
#
# I'm unsure if I should put a new ring back in on the 28th day of my cycle or the 1st day of the next cycle.
#
# ...
# =============================================
# gd1su4
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: junel fe painful cramps?]
#
# I’ve been on Junel Fe for about a year now. I experience horrible cramps a week before my period and throughout it. I also sometimes bleed on my last couple active pills some cycles. My biggest concern are the cramps. They feel a lot like ovulation cramps but I thought birth control stops ovulation. Wondering if anyone has any insight on this
#
# **also: about 7 months into taking junel fe I had a ovarian cyst that went away on it’s own and I’m not sure if the BC caused it. Again, this flagged another concern because not only is BC supposed to prevent cramps but also ovarian cysts.
# =============================================
# ijr98z
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: can't feel my iud strings, need an opinion]
#
# So I got my IUD little over a month ago, I could feel my strings fine the day before yesterday but I could not find them today. I had unprotected sex today so I am a bit worried about this. Should I make an appointment to get it checked?
# =============================================
# e7cls5
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: switching brands on birth control pill]
#
# I started birth control about two years ago, and I was on Lessina originally. Once I came back to college, the pharmacy didn’t have that brand and switched me to Vienva. I told my boyfriend and he’s a little paranoid about whether we are fully protected and if there’s a bigger risk of pregnancy. Both are combination pills and I am going straight from one pack to another. I was just wondering if there are any side effects or if it’s less safe? Any input would be much appreciated. Thank you!
# =============================================
# ifrefy
# ['SEEKING INFORMATIONAL SUPPORT', 'SEEKING EXPERIENCES']
# [TITLE: physical changes after switching from mirena to paragard?]
#
# Hi all, I'm wondering if any of you all have had experience after switching from Mirena (and briefly Liletta) to Paragard?
#
# I got the Mirena 9 years ago and really liked it - not having periods, mostly. But throughout that time I developed severe anxiety and depression and started getting panic attacks, not realizing that it could have been associated with the IUD.
#
# In May of this year, I was due to get my IUD replaced and the NP at planned parenthood who I've been seeing said they had switched to the Liletta, but it was supposed to be very similar to the Mirena. However, starting in June/July I started experiencing major depressive symptoms and my anxiety was through the roof. I gained weight fast that I could not seem to lose, through exercise, diet, no alcohol, etc. and I always felt bloated. The thought of sex made me feel sick and I didn't want my SO to touch me.
#
# I scoured this subreddit and did tons of research online and found that I wasn't the only one experiencing these symptoms, so I got the Paragard in 2 weeks ago and it's been night and day as far as mood.
#
# My questions are about the physical adjustment period though. I've noticed my breasts feel bigger and really tender. Is this just because my hormones are still adjusting? Will my breasts continue to get bigger? Will I experience weight gain again or will I lose that water weight I had gained? I know everyone is different, and I have an appointment with my PCP next week, I'm just wondering if anyone else has experience with physical symptoms after going off HBC.
#
# Thanks!!
# =============================================
# 4se0en
# ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
# [TITLE: skyla iud moderate cramping and bleeding 2.5 weeks after insertion, normal???]
#
# 22 y/o. never had kids. had skyla inserted 2.5 weeks ago. Insertion process was very easy and not nearly as painful as people made it seem. I waited to insert a tampon or have intercourse for 10 days after insertion. However I have had moderate and sometimes slightly debilitating cramps ever since and constant bleeding. My GYN didn't really explain to me what I should expect and when I called them to ask if this was normal they just said "yeah" and that was all the info the nurse could give me as the doc was busy. I wanted to know if anyone has had similar experiences? what helped with the cramps? should I schedule a sooner appt than my follow up which is scheduled for a month from now  or is this really normal???
# =============================================
# 65d0vp
# ['SEEKING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT']
# [TITLE: people with bc that stops periods--how often do you take pregnancy tests?]
#
# Hi everyone,
# I got Mirena in December and stopped having periods in Feb. I've been taking a pregnancy test once every month I haven't had a period. I was wondering if you take one every month or more? I know I'm a little paranoid but can't hurt to be safe!
# =============================================
# eow89d
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: i got the implant today!]
#
# So, I got the implant today’s around 11:30 am. My doctor said to not take off the gauze I have around my arm and to not lift weight in 24 hours.
#
# Is it safe to go to the gym and lift weight around 10:15 am?
#
# I wouldn’t be waiting exactly 24 hours... so, I’m just wondering if It’s a delicate issue where I should be very careful about and absolutely follow the 24 hr resting period or if it’s no biggie.
# =============================================
# 17it7a
# ['SEEKING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
# [TITLE: pharmacy switched my birth control from aviane to alysena?]
#
# Hi everyone -
#
# My pharmacist told me the other day went I went to pick up my birth control that the product Avaine was being switched to Alysena. They said it was the same product, but different packaging. I've looked online for reviews - but I am unable to find any. Has anyone also had this happen to them? Does any have any knowledge as to why Avaine would suddenly be switched to Alysena?
# =============================================
# dmmhll
# ['SEEKING EMOTIONAL SUPPORT', 'SEEKING EXPERIENCES']
# [TITLE: crippling periods and compound methods only work]
#
# So my periods used to put me out of commission for 3 days. I could walk, eat, move, even breathing would hurt. The first day, it wasnt uncommon for me to faint and then vomit from the cramps. To combat that, I went on depo. It helped a lot but the bleeding wouldnt stop and I would have spotting every single day for just over a year after starting. So after talking with my doctor, we also added hormones to combat the bleeding that depo couldnt take care of and the hormones are in the form of The Pill. This is a match made in heaven. I have my body back. My boobs back. My life back. I would miss work and school and have to take trips to the hospital because I was in so much pain. No one ever believed me when I told them how bad it was either, my own psychiatrist didnt believe me untill I fainted in her office.
#
# So the problem is, I thought I would just keep doing the pill and also depo but now my lady parts doc is telling me we cant keep up with them because theres just too much hormones and it's not healthy. I need to switch up my method but honestly, I am so fucking scared to. This is the first year of my life where I have my control back. I honestly dont even care that it's bad for me, I feel amazing. I feel free.
#
# I have untill january/February to come up with a new method. What are you guys on? My lady parts doc recommended an IUD and I'm willing to try anything at this point. I just dont know how the IUD will be any different from the depo. They're both hormones and the one hormone wasnt enough last time anyway :(  lady's with bad bad bad periods, what is your method for dealing with it? If I could take my uterus out I would, but they said i have to wait untill I'm 26. Share your stories! It will be such a huge help. I had a panic attack last night over this so this is me reaching out I guess.
# =============================================
# 9hahn2
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: this might be a silly question.. i apologize in advance!]
#
# Can you use organic coconut oil for lube? The only reason I ask is because I’m SUPER sensitive to certain lube and condoms and it really sucks when something gives me a reaction :(
#
# Can anyone relate??
# =============================================
# eo2a2j
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: if i take a pill then throw up 2 hours later, should i take another?]
#
# As title says. I’m on cerazette.
# =============================================
# 69o8cb
# ['SEEKING EXPERIENCES']
# [TITLE: problems with expulsion of copper iud, tilted uterus...]
#
# Hello, I'm 22 years old and got the copper IUD 3 months ago, the thing is that it got expelled a week after; I went to another gyno and asked to put another one, he did but unintensionally took it off when he turned around to tell the nurse something (very unprofessional, I know), I didn't say anything and he didn't either, just put another (a third) one, it was more painful than the first one and I bled longer too.
# Everything seemed alright for one month until I checked the strings one day and it was almost out... I felt terrible and took it out completely.
# I got another one 3 days ago, because I really don't want to get hormones and the new gyno told me that my uterus was retroverted and that was the cause of it getting expelled, the collocation was the less painful, he was not very careful though. Well, do any of you have a similar experience?, is there anyone who has a retroverted uterus and a IUD?, am I more prone to get it expelled?
# The whole experience has been really bad and I have wasted much money by now (in my country, you have to pay almost totally for this things) which I don't have since I'm a student...
# thanks!
# =============================================
# 6yteta
# ['PROVIDING EXPERIENCES']
# [TITLE: seizures increased with paraguard.]
#
# For the record I have epilepsy and am B12 deficient. However I haven't had a seizure in over three years... On July 24th I had paraguard inserted since it was pretty much one of the very few birth control I could take and ended up being the best option at the time. Well, after three years without a seizure in under two months I've found myself with two gran mal seizures, absent seizures that I've lost count of, and auras which I've never experienced before.
#
# It's always after a period, I bleed so much that I use the 10 hour overnight pads as my daily now, and even changing that every 3 hours I still get stained occasionally. Just a word of warning to you ladies, take iron and talk to your doctor if you have something that could be affected by heavy bleeding. I now have a chipped tooth after smashing my face on the floor.
# =============================================
# euelwx
# ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# [TITLE: i’m freaking]
#
# My girlfriend got nexplanon and her nipples were bleeding 6 days afterwards. Is it a side affect or could it be another underlying issue?
# =============================================
# orqzb
# ['SEEKING EXPERIENCES']
# [TITLE: thinking about implanton- any advice?]
#
# I'm on the pill, but because of my medicine for an infection I had earlier this year, I ended up pregnant and had a miscarriage. On top of that mishap, I have heavy breakthrough bleeding exactly like my heaviest periods. When I am on my period, I have contractions, my blood pressure drops, and I vomit. It's hell. I also have PCOS, so I try to avoid not being on a BC. So I'm looking for a more permanent birth control method- something that I won't have to remember to take every day that would have the potential stop my periods entirely. I don't want an IUD for personal reasons, but Implanton is just invasive enough for me, I think. I've been looking into it, and have heard some great things, but I want to know if anyone in the community has had any experience with it?
# =============================================
# g5qx4k
# ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# [TITLE: might be freaking out but help]
#
# So, I had sex for the first time on 3/10 and he used a condom and he said that when he pulled out the condom didn’t break or anything. The morning after (3/11) we had sex I immediately went to Planned parenthood and got a Plan B, and the Depo shot for birth control. I do have anxiety and tend to think of the worse case scenario, keep that in mind. Well, 3/12 I got my period and everything I think it lasted about a week. I think it was the normal heaviness it always is. Now, a month I’m not getting my period which I’ve heard is a side effect of the BC, but for some reason my anxiety is spiking and telling me I am pregnant and what if these things didn’t work etc. Am I just freaking out or should I take a test because I could be pregnant?
# =============================================
# hnaybn
# ['SEEKING INFORMATIONAL SUPPORT']
# [TITLE: iud placement visit?]
#
# Hello!
#
# So I have to go back in 4 weeks for an IUD visit to make sure it was placed correctly?
#
# I turned down the ultrasound today because my insurance is awful and it was $200.
#
# Do you know how they check placement? I didn’t ask, and I’m thinking it over now... if they have to open my cervix again, and it’s the pain, I would rather pay the $200. I can’t do that again!
# =============================================
# g00cps
# ['SEEKING INFORMATIONAL SUPPORT', 'SEEKING EMOTIONAL SUPPORT']
# [TITLE: how to transition from pill to no pill? side effects?]
#
# Due to lockdown I cannot buy my usual birth control pills and due to the circumstances, I’m pretty sure the lockdown won’t end soon. Let’s just say it’s impossible to get it now (if ever you’re going to give me advice on how to get it). I’m planning to go back to my pill when the lockdown ends.
#
# My question is... are there any bad effects if you stop for a month or two and go back again? Is this recommended? Also, will I still get my regular menstruation once I stop? I am really anxious about this whole thing since I have been using pills since 3 years ago.
# =============================================
# 68qhc3
# ['SEEKING INFORMATIONAL SUPPORT', 'SEEKING EXPERIENCES']
# [TITLE: bleeding while on the pill]
#
# Hi, /r/birthcontrol, I started the pill Tri-Sprintec last month. I had my "period" during the placebo week and it ended last Friday. I started the next pack of birth control pills last Thursday. Today I noticed a bit of what looked like blood when I went to the bathroom and I don't know if that is to be expected or not. I take my pills every day, 8 AM +/- 3 minutes so it's not irregular use of the pills that's causing the bleeding. Does anyone know if this is normal?
# =============================================
# 66m3w9
# ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# [TITLE: IUD falling out???]
#
# I got my paragard in a little less than a month ago. From the two string checks I did, I really had to reach up inside of myself to feel them. (note: the last time I checked my strings before this was at least a week ago) I started my first period with it last Friday. Yesterday, my tampon was causing pain so I pulled it out to replace it with a smaller one. When I did so, it felt kind of odd, like it was pulling on something. Then last night I decided to check my strings and I could literally feel them right at the opening of my vagina. I didn't feel any discomfort from my tampon today, but when I took it out I could literally feel the strings hanging just out of the tip of my vagina. Do you think that this is expulsion or has my cervix really just dropped super low?? I know I have to see my doctor to make sure, just looking for some reassurance or similar experiences.                   [Update] it had moved down! Went to the doctor today and had it replaced. Please ladies, take this as a warning to always trust your intuition if you're worried something isn't right with your body!
#
#
#
# =============================================

# %%
final_dicts = []
for _id, _labels in id_majority_labels_dict.items():
    for _label in _labels:
        final_dicts.append({'ID': _id,
                            'Label': _label,
                            'Text': id_text_dict[_id],
                            'Source': 'reddit-posts',
                            'Decision': 'two or more'})
final_df = pd.DataFrame(final_dicts)
final_df.to_csv(data_directory_path + '/labeling/majority.reddit_posts.csv')

# %%
final_df.sample(3)
# Out:
#          ID                          Label  \
# 274  7ss2cp            SEEKING EXPERIENCES
# 161  a7w4d5          PROVIDING EXPERIENCES
# 238  3gt02l  SEEKING INFORMATIONAL SUPPORT
#
#                                                   Text        Source  \
# 274  [TITLE: those who have switched from the patch...  reddit-posts
# 161  [TITLE: nexplanon &amp; mental health] \n\nI'v...  reddit-posts
# 238  [TITLE: stopping period day of start by taking...  reddit-posts
#
#         Decision
# 274  two or more
# 161  two or more
# 238  two or more

# %%
maria_labels = []
leann_labels = []
for _id, _maria_labels in maria_id_labels_dict.items():
    _maria_labels = ['_'.join(_label.split()) for _label in _maria_labels]
    _leann_labels = ['_'.join(_label.split()) for _label in leann_id_labels_dict[_id]]
    maria_labels.append(' '.join(_maria_labels))
    leann_labels.append(' '.join(_leann_labels))

vectorizer = CountVectorizer().fit(maria_labels)
maria_Y = vectorizer.transform(maria_labels)
leann_Y = vectorizer.transform(leann_labels)
label_names = vectorizer.get_feature_names()

print(maria_Y.shape, leann_Y.shape)

print(classification_report(maria_Y, leann_Y, target_names=label_names))
# Out:
# (500, 7) (500, 7)
#                                  precision    recall  f1-score   support
#
#                       discourse       0.20      0.25      0.22         4
#     providing_emotional_support       1.00      0.25      0.40         4
#           providing_experiences       0.83      0.94      0.88        32
# providing_informational_support       1.00      0.40      0.57         5
#       seeking_emotional_support       0.84      0.48      0.61       123
#             seeking_experiences       0.74      0.89      0.81       170
#   seeking_informational_support       0.93      0.90      0.92       355
#
#                       micro avg       0.85      0.82      0.83       693
#                       macro avg       0.79      0.59      0.63       693
#                    weighted avg       0.86      0.82      0.83       693
#                     samples avg       0.89      0.86      0.85       693

# %%
maria_labels = []
roz_labels = []
for _id, _roz_labels in roz_id_labels_dict.items():
    _maria_labels = ['_'.join(_label.split()) for _label in maria_id_labels_dict[_id]]
    _roz_labels = ['_'.join(_label.split()) for _label in _roz_labels]
    maria_labels.append(' '.join(_maria_labels))
    roz_labels.append(' '.join(_roz_labels))

vectorizer = CountVectorizer().fit(maria_labels)
maria_Y = vectorizer.transform(maria_labels)
roz_Y = vectorizer.transform(roz_labels)
label_names = vectorizer.get_feature_names()

print(maria_Y.shape, roz_Y.shape)

print(classification_report(maria_Y, roz_Y, target_names=label_names))
# Out:
# (300, 7) (300, 7)
#                                  precision    recall  f1-score   support
#
#                       discourse       0.25      0.25      0.25         4
#     providing_emotional_support       0.40      0.67      0.50         3
#           providing_experiences       0.79      0.96      0.87        27
# providing_informational_support       0.80      0.80      0.80         5
#       seeking_emotional_support       0.59      0.82      0.69        77
#             seeking_experiences       0.72      0.95      0.82        96
#   seeking_informational_support       0.94      0.95      0.94       203
#
#                       micro avg       0.78      0.92      0.84       415
#                       macro avg       0.64      0.77      0.70       415
#                    weighted avg       0.80      0.92      0.85       415
#                     samples avg       0.84      0.94      0.86       415

# %% [markdown]
# <br><br>

# %% [markdown]
# <br><br>
#
# # Get majority labels for REDDIT COMMENTS

# %%
target_df = combined_df[combined_df['Source'] == 'reddit-comments']

# %%
id_text_dict = {}
for i, r in target_df.iterrows():
    id_text_dict[r['ID']] = r['Text']
len(id_text_dict)
# Out:
# 553

# %%
ids_labeled_by_roz = list(set([r['ID'] for i, r in target_df.iterrows() if r['Labeler'] == 'Roz']))
len(ids_labeled_by_roz)
# Out:
# 345

# %%
id_labeler_labels_dict = defaultdict(lambda: defaultdict(list))
for i, r in target_df.iterrows():
    if r['ID'] in ids_labeled_by_roz:
        id_labeler_labels_dict[r['ID']][r['Labeler']].append(r['Label'])
len(id_labeler_labels_dict)
# Out:
# 345

# %%
id_majority_labels_dict = {}
for _id, _labeler_labels_dict in id_labeler_labels_dict.items():
    _label_count_dict = defaultdict(int)
    for _labeler, _labels in _labeler_labels_dict.items():
        for _label in _labels:
            _label_count_dict[_label] += 1
    _majority_labels = [_label for _label, _count in _label_count_dict.items() if _count >= 2]
    if _majority_labels:
        id_majority_labels_dict[_id] = _majority_labels
len(id_majority_labels_dict)
# Out:
# 342

# %%
for _id, _labels in id_majority_labels_dict.items():
    print(_id)
    print(_labels)
    print(id_text_dict[_id])
    print('=============================================')
# Out:
# exeejsv
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EXPERIENCES', 'PROVIDING EMOTIONAL SUPPORT']
# You should take it easy for the first week at least, you'll have bruising and it'll be tender.
#
# Just go with your body! I've had mine for almost 3 months and I don't notice it at all, the insertion mark is a tiny dot on my arm. Unless you were actively looking/feeling for it - you'd never know!
# =============================================
# ew0eara
# ['PROVIDING EXPERIENCES']
# It didn't feel good, but I'd do it again. It was a 9 on the pain scale, but it only lasted 5 seconds. When the sound was in, it was like a light cramp that got more intense. Nothing I hadn't felt before from normal menstrual cramps. Then during the insertion of the IUD, the pain got worse. It was at it's height for 5 seconds, and I put my jacket over my mouth because I was going "owwwwWWWW." Then my doc said "you're all done!" and helped me get up, it was immediate relief of pain. The recovery was pretty easy and well worth it. It was very fast, I was probably only with the doctor for 10 minutes, mostly talking. I would ask for anxiety medicine in advance, and I'd say my pain tolerance is moderate.
# =============================================
# e80luyz
# ['PROVIDING INFORMATIONAL SUPPORT']
# As long as your pill allows for a 7 day break and you start the next pack on time you are protected continuously.
# =============================================
# dyj5ay6
# ['PROVIDING EXPERIENCES', 'PROVIDING EMOTIONAL SUPPORT']
# If it helps reassure you at all, I get PMS symptoms most months when I’m due for my period even though I get no bleeding and haven’t for a year.
# =============================================
# e052txu
# ['PROVIDING EXPERIENCES']
# I know I'm super late but anyway.
# I was in so much pain I could barely stand for nearly a week after I had an abortion and it was probably a month before the cramps went away. I don't have an iud but my best friend does and she said it felt pretty similar to the post abortion cramps. If you had that recently it may just be doubled up.
# =============================================
# f8uktxo
# ['PROVIDING INFORMATIONAL SUPPORT']
# after you’ve taken your 8th pill (since the previous 7 all had 24 hours to produce effects), you’re protected.
# =============================================
# dtfnhaj
# ['PROVIDING EXPERIENCES', 'PROVIDING INFORMATIONAL SUPPORT']
# The practice I went to expressed similar concerns about my insurance company's reimbursement rates when I got my Mirena in October but at least they were willing to do a buy and bill. Your insurance company sounds like they also want providers to buy and bill. Personally I wouldn't want to risk submitting a claim on my own, so that leaves finding a practice that has Paraguard in stock or is willing to buy and bill.
#
# Planned Parenthood should be able to help you out. Most locations do enough Paraguard insertions that they should have them in stock. They also work with all manner of insurance as well as the uninsured, so it's usually the most cost effective place to get birth control. (I used to be on the board for my local Planned Parenthood affiliate.)
# =============================================
# fb2twtd
# ['PROVIDING EXPERIENCES']
# I had a very similar experience. Bled for over 3 months. It was hell. Try breaking for 7 days instead of 4. Currently on day 6 of my break and justtttt stopped bleeding.
# =============================================
# ekbavbn
# ['PROVIDING EXPERIENCES']
# I've had Nexplanon for 4 years now (on my second implant) and also have a skin picking thing.  I'll feel around for it but don't pick at it.
# =============================================
# eb742q1
# ['PROVIDING INFORMATIONAL SUPPORT']
# I think it most of the concern about mixing cups and iuds is when you are removing them. You might grab the strings and remove the iud. Maybe if your strings aren't that long that would be less of a risk but it's up to you.
#
# Also *heard* female performers in porn use sponges (anything from natural sea sponge to a make up sponge, never dish sponge).  I'm assuming that would carry a similar risk. So maybe look into that. Please for the love of God do not forget it's there.
#
# Hopefully someone else here has experience with mixing cups and iuds :/
# =============================================
# eaa8non
# ['PROVIDING INFORMATIONAL SUPPORT']
# I was thinking the same, honestly. I've heard that the main mechanism of action of the implant is preventing ovulation, but then it also thickens the cervical mucus and thins the uterine lining - so basically there's three ways it prevents pregnancy - prevents the release of an egg, prevents sperm from getting in the uterus, and prevents the zygote from implanting, if anything else fails.
#
# That being said, I found [this](https://www.ncbi.nlm.nih.gov/pubmed/11246602):
# &gt;Implanon inhibits ovulation by preventing the mid-cycle luteinizing hormone peak. Although it initially suppresses follicular development and estradiol production, ovarian activity slowly increases after 6 months, and follicle stimulating hormone and estradiol levels are almost normal. Endogenous progesterone levels remain in the subovulatory range for &gt; 3 years in most subjects. In ovarian ultrasound studies, ovulation occurred in &lt; 5% of users after 30 months of use.
#
# [This](https://www.researchgate.net/publication/13195166_The_pharmacodynamics_and_efficacy_of_Implanon_R_-_An_overview_of_the_data) might be a good read as well.
# &gt;This *(pregnancy prevention)* was achieved by inhibition of ovulation, which was reflected by suppressed P levels, as the primary mode of action. Ovulation was inhibited, but otherwise ovarian activity was still present (follicle growth, E2 synthesis). The FSH serum concentrations were only slightly lower than preinsertion levels **and LH surges were prevented**.
#
# So I'm guessing that's the reason why certain types of cervical mucus might still be present. But yeah, with no LH surge, there's no ovulation.
# =============================================
# f1bl292
# ['DISCOURSE']
# Holy fucking smokes. Now I appreciate the doctor who dangled the old IUD that she removed before my eyes way more.
# =============================================
# e7fplfw
# ['PROVIDING EXPERIENCES']
# I've been trying to curl them. He's big and my cervix is normally a little low so it's like whyyyyy me.
# =============================================
# ffx07p6
# ['PROVIDING EXPERIENCES']
# For me I took vitamins probiotics and stopped eating g sugar that helped and I haven’t gotten a yeast infection yet... the pill doesn’t cause a yeast infection for me. I’ve never heard of birth control causing yeast
# =============================================
# e2n1s9h
# ['PROVIDING EXPERIENCES']
# I bled constantly on my second and third Nexplanon. Got the Mirena at the end of November. Bled lightly for the first few months during my cycle but since then I haven't had any bleeding(I did have the Nexplanon for 4 &amp; 1/2 years so my uterine lining was thinned out) I do get cramping around my cycle time. I also do get more moody around my cycle than I did with Nexplanon. I can't use anything with estrogen. The Mirena has worked out for what I needed it for. Hope this information helps.
# =============================================
# dkk0o2g
# ['PROVIDING EXPERIENCES']
# My cervix is really small too and they recommended (and placed) a Skyla
# =============================================
# f83rqe8
# ['PROVIDING EXPERIENCES']
# I got mine removed on the 11th &amp; I didn’t even feel when she took it because they numbed it. I didn’t realize it was out until I saw she was holding it up with the tool she used to take it out. She did struggle a bit to take it out because of scar tissue formation but it wasn’t even bad. Just like insertion, the most painful part was the shot. I didn’t even get a bruise afterwards!
# =============================================
# evrpibr
# ['PROVIDING INFORMATIONAL SUPPORT']
# I haven’t seen the sources you’re referring to talking about waiting for a missed period. Everything I’ve seen says that a pregnancy test will give an accurate result 3 weeks after the sexual encounter in question. It’s possible to detect earlier than that, but I wouldn’t trust a negative test until after 3 weeks.
# =============================================
# eohva35
# ['PROVIDING EXPERIENCES']
# I’m on day 21 of spotting/breakthrough bleeding after starting Yasmine a month ago 😩
# =============================================
# ffuy8d0
# ['PROVIDING EXPERIENCES']
# Hey! I got mine in a month ago. Personally I found the pain to be super tolerable. It’s basically like a bad period cramp (but tbh I’ve had cramps worse than the insertion pain). I would def recommend eating before you go tho!
# I didn’t have enough so when I went to stand up I almost passed out. Felt much better after they gave me crackers and OJ haha.
#
# My Roomate had bad cramps from insertion though so everyone is different. She loves her iud now and is glad she did it :)
# =============================================
# f9hi7ty
# ['PROVIDING EXPERIENCES']
# Do you mean the constant general anxiety that you deal with while on bc?
#
# I’ve been tracking mine! I’m still kind of new to tracking so I’ve been totally focused on trying to find my cycle/ovulation rhythm before officially using it as a form of preventing pregnancy. But, according to my tracking data, I should be safe around the middle of December, so I think I’m going to try things out with my partner by using this method (but still use a condom to relieve my anxiety).
# =============================================
# et1ayk6
# ['PROVIDING INFORMATIONAL SUPPORT']
# Here's the handy chart I always reference regarding changing birth control methods: https://www.aafp.org/afp/2011/0301/p575.html
#
# It says to have the IUD inserted 7 days before stopping the pill. This is because the IUD takes a week for the hormones to build up to an effective level in your body. If you overlap for 7 days, there won't be a gap in protection. There's not a lot of information on effectiveness or risk of pregnancy when something like this happens though. The IUD isn't completely effective yet, but it's pretty close, and the pill isn't completely out of your system yet either. The "better safe than sorry" answer is you need to take Plan B before the 72 hour window ends, but the decision you make is based on what level of risk you're comfortable with.
# =============================================
# f374i3p
# ['PROVIDING INFORMATIONAL SUPPORT']
# Nuvaring, arm implant, patch... Depo shot could be something too but it's not supposed to be used for too long.
# =============================================
# dkrzwkw
# ['PROVIDING EXPERIENCES']
# I have Paragard, and love it so much.  I had no pain with insertion (didn't take anything, didn't have my period, have never been pregnant), got it at Planned Parenthood and they are experts :). They had a heating pad for me during insertion which helped me stay relaxed, I kept waiting for pain but it just felt weird for a few seconds and then it was over. I had some cramping for a few days but nothing that got in the way of my life.  I had really bad experiences with hormones and it took me almost a year to feel normal after stopping them, I got my IUD another year after that and I wish I had gotten it sooner because it is the best.  I have no side effects other than a little spotting leading up to my periods (which have always been heavy but are not longer heavier or worse now) and the occasional cramp but most of the time I forget it's there.  I have never been so comfortable and spontaneous and confident with any other method and my boyfriend loves it to.  I highly recommend it!  Good luck!
# =============================================
# exm5f6q
# ['PROVIDING EXPERIENCES']
# It’s ok? I’m 2 weeks into it so I’m adjusting to the headaches and nausea.  I think it’ll be much easier after the first couple months.
# =============================================
# ewkkzu7
# ['PROVIDING EMOTIONAL SUPPORT']
# It sounds like you may have some feelings or beliefs connected to not producing enough natural lubrications or needing lube. It’s totally normal and a common side effect of the pill. If your partner is giving you shit about it have a talk with them about it being a side effect. There’s no way to really stop it since it’s a side effect. I have a friend who has a boyfriend who felt like he wasn’t a good enough sex partner if they needed to use lube. Or that she must not be into it enough if she’s not producing enough lubrication. If either you or your partner have these kind of thoughts and beliefs that’s more of the issue rather than the side effect of the pill.
# =============================================
# erdmhtp
# ['PROVIDING EMOTIONAL SUPPORT']
# Good luck on whatever choice you make, I hope for the best for you :)
# =============================================
# el9umid
# ['PROVIDING INFORMATIONAL SUPPORT']
# i think anywhere that wouldnt have any food products that might be moist, like fresh vegatables and such. so it shouldnt be too difficult to find a spot in your fridge.
# =============================================
# e4oka2x
# ['PROVIDING INFORMATIONAL SUPPORT']
# First of all, I hope it's not already used by someone else. I wouldn't touch anything that didn't have the factory seal, let alone put  it anywhere near my vagina.
#
# Spermicide by itself isn't particularly reliable. It's mostly used in combination with barrier methods (condoms, diaphragm, cervical cap, sponge) to boost their effectiveness, or as a backup when you're on other types of birth control (IUD, pill, etc) if you're anxious and need more than 1 method for peace of mind.
# =============================================
# euufwqs
# ['PROVIDING INFORMATIONAL SUPPORT']
# "6 times more likely" is a bit exaggerated. [This link](https://www.bedsider.org/features/315-ring-risks-separating-hype-from-fact) explains it really well, and here's a rundown:
#
# &gt;Healthy young women who are not using hormonal birth control have an incredibly low risk of blood clots, so even when that risk is doubled, it’s still pretty low. How low? Here are the annual chances of a blood clot for different groups of women:
#
# &gt;- Not taking any type of hormone: 2-5 per 10,000 women
#
# &gt;- Taking a pill with “early progestin”: 6-8 per 10,000 women
#
# &gt;- **Taking a pill with drospirenone (Yaz or Yasmin): 10 per 10,000 women**
#
# &gt;- Using the patch (Ortho Evra): 10 per 10,000 women
#
# &gt;- Using the ring (NuvaRing): 8-12 per 10,000 women
#
# &gt;- Pregnant or gave birth recently: 300-400 per 10,000 women
#
# As you can see, it's not 6 times more likely.
# =============================================
# f94pjv0
# ['PROVIDING EMOTIONAL SUPPORT']
# Maybe kinda derailing but I wouldn't recommend sleeping with this dude anymore if you haven't quit already. This guy's got issues.
# =============================================
# fczrobi
# ['PROVIDING INFORMATIONAL SUPPORT']
# You don't ovulate on the pill, while on active pills or placebo pills. Sleeping pills will do nothing but hopefully help you sleep!
# =============================================
# erdw98o
# ['PROVIDING EXPERIENCES']
# I just gained a little weight, nothing too majors. And I have moments where I get real hot, and feel like I’m burning up and people can be okay, cool feeling. (However this could just be me in general)... I don’t remember if it began when depo started. (Sorry) but then I gained a little more hair in places and I may experience more headaches but it’s usually when I become hot.
#
# It was all side effects that were kind of okay, and didn’t make me stop taking the shot.
# =============================================
# f84zqml
# ['PROVIDING INFORMATIONAL SUPPORT']
# Skipping a withdrawal bleed on birth control doesn’t mean you’re going to skip the side effects of it, which include cramping and spotting. If you were pregnant enough to have symptoms, you’d be pregnant enough to test positive
# =============================================
# etgnp1j
# ['PROVIDING EXPERIENCES']
# I just have to point mine in the correct direction and it works great... but they definitely don't work for everyone!
# =============================================
# e1ljehr
# ['PROVIDING EMOTIONAL SUPPORT', 'PROVIDING INFORMATIONAL SUPPORT']
# Alright, just keep waiting and if you are worried then take a pregnancy test. Morning after pills are very effective though so it shouldn’t be a problem :)
# =============================================
# dtws4nn
# ['PROVIDING EXPERIENCES']
# It can be even better than that - took one ibuprofen 200mg, vaguely felt the clamp on the uterus but the rest was entirely painless and I was chatting leisurely to the nurse the whole way through. It doesn’t have to hurt necessarily!
# =============================================
# e9caf95
# ['PROVIDING EMOTIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# I'm sorry you had such a bad experience with jadelle! It totally differs for each person, levonorgestrel can be pretty bad for mood too. I started taking antidepressants at the same time as I got my implant so I can't speak to any emotional effects as there was too much going on in my life for me to attribute anything to the implant alone. I'm still not totally stoked on Jadelle but that was just my decision making process when thinking about it vs an IUD!
# =============================================
# f88ndta
# ['PROVIDING EXPERIENCES']
# I do exactly the same. Alarm set for 7am and I can go back to sleep after if I want. Otherwise I’m up and out to university. I find it easy to keep a glass by my bed and do it every morning :)
# =============================================
# e8e3o3n
# ['PROVIDING EMOTIONAL SUPPORT']
# Do you see my point that it’s not fair for him to have such a heavy-handed say in what BC method you’re on, when you can’t even talk to him about the implications of it? Correct me if I’m wrong but you went from the pill back to Nexplanon because *he* was paranoid about the effectiveness?
# =============================================
# ek3h70u
# ['PROVIDING INFORMATIONAL SUPPORT']
# To be honest - your title is quite hard to grasp.
#
#
# But it does not look like a second line to me. Wait a week and test again, to put your mind at ease.
#
# &amp;#x200B;
# =============================================
# e2vd5ob
# ['PROVIDING INFORMATIONAL SUPPORT']
# by 9, do you mean 9pm and you took your pills around midnight and 11:20pm? if so, most combo pills have a window of 12 hours to take pills. your pills are technically not late.
# =============================================
# f9z6d5j
# ['PROVIDING EXPERIENCES']
# This. I spotted for a month straight when I had the Mirena
# =============================================
# f9hdgr5
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EMOTIONAL SUPPORT']
# Nah, you’re good. Promise. You’re not at any more risk than if you’d put neosporin on a cut... they’re totally unrelated and not going to interact.
#
# Also, the antibiotics thing is pretty misunderstood. It’s only certain types of antibiotics (crazy strong specific ones) that are an issue not because they like... cancel birth control out, but because your body metabolizes certain medications differently, it can throw off how you ‘digest’ oral contraceptives.
# =============================================
# e6n0063
# ['PROVIDING INFORMATIONAL SUPPORT']
# You can order plan B or Ella One from amazon. Copper IUD works as emergency contraception too. Were you taking the pills before?
# =============================================
# f7geck1
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# Skyla has less hormones and only about 15% of women stop having a period while they have it.  It is not a proven method for reducing cramps.  It is minimally smaller than Mirena, but pretty much the same size. I have had it for the last 3 years.
#
# I’m switch to Kyleena in a couple weeks.  It is between Skyla and Mirena.
#
# Mirena is used to help reduce cramps and a significant amount of users have reduced or minimal periods.  It has more hormones, but they are locally released so not as likely to cause hormonal mood changes like the pill.
#
# There is also a copper IUD that does not have any hormones.  It is known to make you have a heavier period with more cramping. However if you aren’t good with hormones this is your only option.  Also if you don’t really have any cramps now, I’ve been told this one isn’t bad.
# =============================================
# ffthgin
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# I supposed it’s possible but I’d think unlikely since generic to generic or brand name to generic, it’s the same active hormones. Sometimes the inactive ingredients can vary slightly but I wouldn’t think the inactives could mess with libido enough to make a difference. In my experience, switching from Yaz to generics of Yaz all obliterated my sex drive unfortunately haha.
# =============================================
# ek4zido
# ['PROVIDING EXPERIENCES']
# Mirena user since December 2014. Was on the shot before. Have not given birth. Periods are non existent now. My weight hasn't changed since insertion. Insertion made me jump and I was sore for the first couple of days. Sometimes I can be sore after intercourse, but it goes away in a few hours. Spotting every once in a while. TBH, not looking forward to removal, but it's the method that has made me the happiest.
# =============================================
# dylwg2h
# ['PROVIDING EXPERIENCES']
# It was a different brand, but when I was trying to decide on which IUD to get my doc gave me some discount cards from each of the companies. One made it so my maximum out of pocket was like $75 or something. So definitely check with the doc and the drug companies!
# =============================================
# f84ova9
# ['PROVIDING INFORMATIONAL SUPPORT']
# No. Why are you looking to take Plan B, if you have Nexplanon? I can’t think of any reason you should need it.
# =============================================
# f17v2kj
# ['DISCOURSE']
# I would think because it sounds like she’s already made up her mind about keeping the babies- so it’s kind of like someone asking “are you sure?” to someone to has made up their mind about an abortion.
#
# However, I completely agree with this post and agree that these are all extremely valid points. Everyone jumps to congratulate someone being pregnant even though it is very likely not a great situation. I just hope OP has a support system.
# =============================================
# ff54ogg
# ['PROVIDING INFORMATIONAL SUPPORT']
# They should of had you come back while you was on your period when cervix is slightly open already. I bet them forcing it in has caused all your issues
# =============================================
# ecsfd18
# ['PROVIDING EXPERIENCES']
# As far as the generic versions go, I took loryna and was satisfied with it, I just had to get off it because my topamax was increased to a point which made it ineffective and I spotted every day. I've heard that gianvi has given many women side effects, but each person is different after all.
# =============================================
# e5j1qlh
# ['PROVIDING INFORMATIONAL SUPPORT']
# At the 3 week mark you're pretty much gonna get an accurate result on a test that actually works, haha. No need to spend money on expensive, bulky thermometer-like ones, feel free to get strip tests. Blue dye is also pretty notorious for evaporation lines, so I always recommend pink dye tests. Keep us posted!
# =============================================
# ex5v63n
# ['PROVIDING EXPERIENCES']
# http://imgur.com/a/hKJrh5i Here's mine 😩 the first 4 days are the actual period with symptoms and the rest shows spotting and when I had sex
# =============================================
# es7vtxs
# ['PROVIDING INFORMATIONAL SUPPORT']
# 80 degrees is fine, keep them out of the sun and in a cooler area of the house and it will be fine.
# =============================================
# euifc9r
# ['PROVIDING EXPERIENCES']
# I was on it for about 27 years and stopped about a year ago at the end of my pill pack.  My boobs shrunk instantly (sucks!), but I lost weight, feel great, periods are shockingly regular, and light, cellulite is reduced, and no acne.  I had so many hormonal issues when I was younger that I’m still shocked my body is doing so well off of it. I am so much happier off of it.
# =============================================
# dm2cf3h
# ['PROVIDING INFORMATIONAL SUPPORT']
# Unlikely related. At most you might be having bloat / water rentention since you are back to your natural cycle which can trigger that. Are you seeing any correlation related to your cycle?
# =============================================
# dljmeqg
# ['DISCOURSE']
# Do you say that to patients who ask questions that have been asked millions of times too?
# =============================================
# dn3wit1
# ['SEEKING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT']
# I actually am really grateful that you posted this because I was just about to ask about the Paragard myself. Reason why I want it is obviously for pregnancy prevention but also because I really don't do well with hormones considering I have a history of anxiety and depression and am medicated for it. I've been using a diaphragm while I've been with my boyfriend of 6 months but it's been giving me so many UTIs, yeast infections, etc. it's getting ridiculous. I'm pretty sure I have a yeast infection right now as I'm typing this. But so the Paragard is probably what I'm leaning towards the most, but I am a little concerned about the side effects. I know periods tend to get longer and heavier which is something that won't be fun, but I can deal with because my periods are pretty short and moderate as it is. The one thing I'm concerned about though is cramps as you said they do get worse. I know it's not like a walk in the park and it's different for everyone, but would you say the increase in cramps interfered with your daily life? Because that's one thing that I really can't have happen to me considering I lead a pretty active life. If it's just a little pain that can be solved with some Advil that's fine, but is it like excruciating? Let me know! Thank you again!
# =============================================
# e4pl6wn
# ['PROVIDING INFORMATIONAL SUPPORT']
# You missed it, so you take the next pill ASAP. Then one at your regular time so two pills today.
# =============================================
# f79islq
# ['PROVIDING INFORMATIONAL SUPPORT']
# Yes, as long as u start the next pack on time and took ur pack as directed now.
# =============================================
# epdnlbs
# ['PROVIDING INFORMATIONAL SUPPORT']
# When you miss 3 doses in the same week, you are beyond doubling up and essentially have to start over.
#
# Meaning, using condoms for the next 7 full days of proper use.
#
# Yes, you are at risk of pregnancy.
#
# Take a pregnancy test three weeks from the 27th.
# =============================================
# duj6mf6
# ['PROVIDING INFORMATIONAL SUPPORT']
# Yes, she needs a second Plan B pill.
# =============================================
# dx2tq74
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# Its working. Just because you had a period doesnt means it stopped working. Irregular bleeding is one of the side effects and guess what, a period after a year of no period means exactly that.
#
# Happened to me too. Then I didn't stop bleeding for months.
# =============================================
# dng2gwq
# ['PROVIDING EXPERIENCES']
# My period went away like instantly when I got the shot. (Within a few weeks). But I had been heavily bleeding for a month. I had all the same side effects as you though so I got off of it and switched to the pill instead which I like much better.
# =============================================
# e9l03ah
# ['PROVIDING INFORMATIONAL SUPPORT']
# There are zero methods that work all of the time, and they all depend on luck. Doesn't mean they "don't work." The numbers people are giving for method effectiveness are from the CDC - it's 98% for condoms and 96% for pulling out.
# =============================================
# f2ujb26
# ['PROVIDING INFORMATIONAL SUPPORT']
# You can start any day you like, it doesn’t have to be a Sunday or the first the day of your period. I start my packs on Thursdays.
#
# Especially if you’ve been having irregular periods and messing with different hormonal types, you could be waiting a while for your next period.
#
# When you start determines how long till you are protected from pregnancy - day 1 of period start, you are protected immediately. Starting any random day (a Sunday, Wednesday, Thursday, etc.), you need to wait till the 8th full day (so it’s been 7, 24 hr lengths) before having sex without a condom. That’s the only difference in when you start.
# =============================================
# ewp6x9l
# ['PROVIDING INFORMATIONAL SUPPORT']
# Because no method is 100% and there’s a lot of potential user error and even potential metabolism issues with oral contraceptives. And if it is the mini pill OP used, assuming it’s not desogestrel, this type works by thickening the cervical mucus to block sperm from entering the womb, and only occasionally prevents ovulation. So there’s a lot more potential for failure than we think or are told.
# =============================================
# e7w5w8l
# ['PROVIDING EXPERIENCES', 'PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EMOTIONAL SUPPORT']
# I do have the Skyla. It has worked really well for me. When I got it, they said I can keep it for up to three years. Now they say that it is ok for 5 years.
#
# I understand your concern for acne. However, it is one of the smaller IUDs that produce smaller amounts of hormones compared to the Mirena. Perhaps, you can give it a shot? I do however, understand your hesitation of getting another IUD after going through the expulsion of Paraguard.
# =============================================
# dzjo6xk
# ['PROVIDING EXPERIENCES']
# I would use it if I had a life modelling gig on the day my period was due. Unfortunately oestrogen now gives me migraines so I can’t take it.
# =============================================
# dzkrmhy
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# The withdrawal method is not very reliable, as you have to take into account pre\-ejaculation \(a small amount of sperm that your partner may produce to lubricate\). Also, the IUD has a success rate of 98&amp;#37;, so it's useless to do so. If you're really worried, take a pregnancy test. I have a Jaydess IUD too, and I was told it was completely normal if my period completely stopped \(it's been 7 months, it hasn't, it's worse than before, but that's another problem lol\)
# =============================================
# evxw6h2
# ['PROVIDING INFORMATIONAL SUPPORT']
# Cramping etc is normal for a while after insertion; given her situation, it seems like this is being magnified. Does she have anything stronger to try for a day and see how it goes?
# =============================================
# eyxe1c9
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# I think it’ll be a week before it is effective, since you are putting it in once you are due for a new shot. I put the Nuva ring in immediately after the nexplanon removal and was told it would be a week
# =============================================
# dsxmpqo
# ['PROVIDING INFORMATIONAL SUPPORT']
# Sounds like a colpo or a LEEP surgery, which is taking cervical tissue. It occurs when the pap smear is abnormal. Pretty routine to do if a pap comes back abnormal.
# =============================================
# e6seshh
# ['PROVIDING EXPERIENCES']
# I have Kyleena and got it about two months ago.  I noticed that my cramps are not necessarily matched with my cycle, and my cycle is now very light but last a bit longer.  The cramps I get with Kyleena feel much different than regular cramps and often times radiate down my legs and lower back.
# =============================================
# exeyfim
# ['PROVIDING INFORMATIONAL SUPPORT']
# Um, your doctor sounds like an idiot. You don’t ovulate on the shot so you don’t have periods. You might have random bleeding but never periods.
#
# As for future children, if you want to be able to conceive very quickly after discontinuing your birth control method, you might want to use something else. The shot is the one that often takes a little longer for fertility to return for some reason- nothing major, an average of 10 months- regardless of how long you’ve used it. That said, you CAN conceive quickly after stopping so you should use another method after stopping if you don’t want to get pregnant right away.
# =============================================
# etjpxij
# ['PROVIDING EMOTIONAL SUPPORT']
# Wait til you get out of your adolescence(24) before making big decisions
#
# and use your peers as examples of what *not* to do.  Because chances are, they're fucking up at something in their life.
# =============================================
# e926i50
# ['DISCOURSE']
# Haha yeah, that's the point you switched to once your statement that "perfect use for pills is not 99.7% effective" was proven wrong.
# =============================================
# emka9mm
# ['PROVIDING INFORMATIONAL SUPPORT']
# Yes, you just skip all the brown pills and start a new pack of active pills right away. Bear in mind that there's also a chance that it might not work, or that you'll still encounter some spotting. Be prepared!
# =============================================
# ds6mkwz
# ['PROVIDING INFORMATIONAL SUPPORT']
# There's really no way for us to tell you what exact amount of risk you're in. Your best bet is to take a pregnancy test 21 days after the sex in question.
# =============================================
# e906qp6
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EMOTIONAL SUPPORT']
# Well there is a new ecp called ella which is different than plan b if ever in the future you want to try it. I hope all goes well for you!
# =============================================
# ea4vb8d
# ['DISCOURSE']
# Men’s problems (including pain) are always treated more attentively than women’s problems (even by female doctors).
#
# UGH, indeed.
# =============================================
# e1pl6we
# ['PROVIDING EXPERIENCES', 'PROVIDING INFORMATIONAL SUPPORT']
# I am on my second one,  I am one of the lucky 33&amp;#37; who don't have a period with Nexplanon. I do have more back acne than i did before though. After having it for a year I tend to spot maybe a day in a month but its not noticable to anyone but me. My husband and I have been together almost 3 years and not a single time have we used secondary protection. If you do start to bleed contact your doctor and see if they can prescribe you the pill so it will even out your hormones. Everyones body reacts different. You could read every horror story in the book and it won't apply to you. Give it the 6 month adjustment period and go from there!
# =============================================
# ff21nv1
# ['PROVIDING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT', 'PROVIDING EMOTIONAL SUPPORT']
# I’m about to start this too!
#
# I am also quite nervous.
# =============================================
# el2n64n
# ['PROVIDING EXPERIENCES']
# I've used the pill club and it is legit but they are slow to respond. Especially if you make any errors on your part. They also do not respond normally on the weekend. Good luck!
# =============================================
# dys8f2d
# ['PROVIDING EXPERIENCES']
# oh god i recently bled on a guy! i spotted for about a month on the pill and i thought all was fine until after sex and im in the bathroom and hes just like "uuuh did i injure you? because i have blood on my dick." mortifying. he was really good spirited about it though, just washed off, and we got back to cuddling lmao.
# =============================================
# dw06k6s
# ['PROVIDING EXPERIENCES']
# My weight gain is due to meeting my husband and becoming happy.
# It also could happen if you were on BC and then switched onto Paragard. I have the paragard, but I refuse to believe that my IUD is to blame for the fact that I'm a size 8 vs a size 4. Especially when I can easily lose weight through diet and exercise. Everyone's different though.
# =============================================
# dvz4evv
# ['PROVIDING INFORMATIONAL SUPPORT']
# You are right, most of them do. I've been before and the trick is to not buy their products but have them recommend some and try and find them at a natural foods store. Some you won't be able to find and will have to buy there. Unfortunately I do not, from what I remember she was on a regime of certain types of seeds and nuts (crazy I know!)
# =============================================
# ewia8oa
# ['PROVIDING EXPERIENCES', 'PROVIDING INFORMATIONAL SUPPORT']
# I’m not a doctor and if you’re worried you should absolutely seek professional advice (especially if it is the same size or bigger over the next day or so). But I would ask, are you particularly constipated at the moment (sorry lol). I used to have exactly the same feeling in the place you’ve described and it often coincided with times when I was eating a lot of bread etc. I’m not coeliac but my digestive system isn’t very happy after I’ve had a lot of wheat, and my bowel had this dull ache and was hard and swollen.
# =============================================
# ellufat
# ['PROVIDING EXPERIENCES']
# My dr says the same thing but I usually don’t skip and the spotting stops on its own relatively quickly. It’s possible that even though you skipped the pills, 3 days off wasn’t long enough to start. During my sugar pill week it usually takes 3-4 days for my period to start and then stops pretty quickly when I start taking the actual pills again
# =============================================
# dy0hxcy
# ['PROVIDING EXPERIENCES']
# They said mine fell out because I have super heavy clotty periods (sorry if tmi) and it just sorta got pushed out with everything else. It’s actually pretty uncommon for one to just fall out like that, just different for everyone I guess.
# =============================================
# etq5n05
# ['DISCOURSE', 'PROVIDING EMOTIONAL SUPPORT']
# Happy to help!
# =============================================
# dnnjkyj
# ['PROVIDING EXPERIENCES']
# I just literally got Mirena today and my nexplanon taken out. I’m excited to see if it helps with my anxiety, that would be such a relief.
# =============================================
# dlq27ij
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EMOTIONAL SUPPORT']
# Pregnancy symptoms don't start that soon, don't worry you're fine. :)
# If you still have those symptoms in a week or two then just ask your doctor. You were extra doubly safe!!!
# =============================================
# fb29g0k
# ['PROVIDING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT']
# I’m getting my Mirena reinserted tomorrow after 5 years with my first one! I had a pretty painful insertion the first time around but my periods went away after ~6 months and it’s been such a convenient and great birth control I was really keen to continue with it. I had pretty bad  weekly/monthly cramps for the first 6 months but after that hurdle it worked out great with some occasional very light spotting here and there over the years. Given the initial insertion was so painful, I’m really nervous for the replacement but your story has put me at a little ease. Thank your so much for putting a positive experience! This is what I needed to hear the day before :) Happy holidays!
# =============================================
# f7vyec7
# ['PROVIDING EXPERIENCES']
# Yes, this! I was on the pill for many years and never let anyone finish in me. Now that I have an IUD I’m comfortable with it. Also, I feel mature enough finally (30) that I’d be able to handle the situation if I did get pregnant.
# =============================================
# e7bxkit
# ['PROVIDING INFORMATIONAL SUPPORT']
# Are you on the pill normally? If so, did you miss any pills?
#
# I don't see your brand on this list, but perhaps the list is not exhaustive.
#
# [https://ec.princeton.edu/questions/dose.html](https://ec.princeton.edu/questions/dose.html)
# =============================================
# e5wrqla
# ['PROVIDING EXPERIENCES']
# I had a really awful experience with my Nexplanon. Everything was great for about the first year and a half. Then I gained a ton of weight, started bleeding all the time and overall just feeling like a crazy person. I got it removed three weeks ago and now the weight is just falling off. (I workout with a trainer 2x a week, 1x on my own, and make sure to stay in a calorie deficit-but I was still just not losing weight). Everyone is different- but my friends that had it too had similar experiences to mine! It was nice not having to worry about taking a pill every day and the no periods factor- but it just ended up being so much worse than planned. I hope it works out for you!
# =============================================
# eb9opmj
# ['SEEKING INFORMATIONAL SUPPORT']
# Thanks! It's supposed to act locally but sometimes it doesn't and hence ppl with side effects? Also it inhibits ovation right? So isn't concentration important?
# =============================================
# e4sml25
# ['PROVIDING INFORMATIONAL SUPPORT']
# Just sleep it off so you can combat the nausea.
# =============================================
# f937h7u
# ['PROVIDING EXPERIENCES']
# I’m on Junel fe. I don’t like it. It causes me to spot way tooo much.
# =============================================
# elkuno5
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# It could be because it’s your period soon. I know I tend to get bad cramps a week before my period or even more than a week. Not sure if Monistat could be a contributor. Since a yeast infection isn’t connected to your uterus, or I could be wrong. But see how you are without the a Monistat. Use a hot water bottle or a heating pad for the pain, that helped me to an extent.
# =============================================
# fdnupat
# ['PROVIDING EXPERIENCES']
# ugh I miss my nuva ring... everything about it was so convenient.
# =============================================
# e29y0wy
# ['PROVIDING INFORMATIONAL SUPPORT']
# &gt;They say it is covered, but only 75% of the cost is covered after I pay my deductible (which I haven't reached yet)
#
# If in USA...
#
# That would be correct **only** if your plan is grandfathered or otherwise exempted from the ACA. Ask them if your plan is ACA compliant.
#
# If the ACA applies no cost sharing is allowed (so no copay or no deductible).
# =============================================
# e7vhq4l
# ['PROVIDING EXPERIENCES']
# I had mine expel after 3.5 years! So of course after having no other problems with it, I tried another one. It expelled after 2 weeks. They told me if your body expels it once the chance of another coming out is like 70% more. Especially if you haven’t given birth before... Now I’m not on any bc and come from the most fertile family ever, so I’m at a complete loss because I don’t want to be on anything hormonal.
# =============================================
# eoci4bi
# ['PROVIDING EMOTIONAL SUPPORT', 'PROVIDING INFORMATIONAL SUPPORT']
# No problem! I would choose a method that seems like it will fit with your lifestyle best and talk with your OB about formulations that they think make sense for you and any concerns you have. They will definitely be able to help.
#
# I wouldn’t worry about the weight gain part though, it’s a myth that won’t die.
# =============================================
# duglcjz
# ['PROVIDING EXPERIENCES']
# i’ve had mine for two months. sex isn’t painful but i do bleed after :/
# =============================================
# dmu83u3
# ['PROVIDING EXPERIENCES']
# Will it hurt? Yes. Like a fucking bitch. But it's so worth it, I got mine about two months ago and was using the nuva ring before. I had ZERO sex drive, it has come back full force as of late.
# I hate being touched too and it was incredibly uncomfortable, they couldn't get it in my first visit and it hurt so bad to have them try, I cried like a little bitch. The second time they injected numbing medication into my cervix and after that I felt nothing. Cramped for a few weeks but I couldn't be more happy.
# =============================================
# dxr4m2p
# ['PROVIDING INFORMATIONAL SUPPORT']
# Flex cups are pretty great.
# =============================================
# f9ihfk1
# ['PROVIDING INFORMATIONAL SUPPORT']
# You must take all the hormonal pills to be protected.
# =============================================
# er7f9xo
# ['PROVIDING EXPERIENCES']
# Hey,
# I got mine 2 months ago. We had sex a week after and I was sooooo scared. But guess what, nothing happened. It wasn’t bad at all.
# My periods are longer tho. Normally it lasts like 5 days but for the last 2 months it lasted like 9 days.
# My doc says it’s normal. I don’t have more painful periods. Maybe I do but Ive always been in agony during my periods so I cant really tell the difference.
# I am waiting for my milestone to get back to normal. Other than that I am loving it.
# Good luck!
# =============================================
# fbebj7q
# ['PROVIDING INFORMATIONAL SUPPORT']
# That may be your best bet. Idk what the requirements are in your state, but in California for Planned Parenthood, aside from insurance, they ask for income and household size. Might be the same?
# =============================================
# e5sps2z
# ['PROVIDING EMOTIONAL SUPPORT', 'PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# I totally get that! Counting calories and weighing myself wreck me out mentally. You might want to talk to you doctor about a different pill. Yaz was really hard on me when I took it but it was better than not having it if that makes sense. There are a lot of options out there!
# =============================================
# e70dmz8
# ['PROVIDING EXPERIENCES']
# Yeah I try to check a few times during the month cause I know my cervix can be higher or lower depending. But lately I haven’t had much luck and I know it’s probably because of the strings softening plus having more lubrication around the cervix can make it difficult.
#
# But it’s tough not having peace of mind even though I know it’s probably still there 😅
# =============================================
# e6po5te
# ['PROVIDING INFORMATIONAL SUPPORT']
# So you had sex on the 10th while you were on the pill, but no condoms? Or were you not on the pill yet? But you did use pull-out.
#
# When you got the previous test, did you get a blood test or a urine test?
#
# Again, I highly recommend a counselor or a therapist to deal with the issues. You need to learn to trust your birth control, and be informed about it, first and foremost. Scarleteen and Bedsider both have really good resources/info about birth control, plan B and abortion.
# =============================================
# ez886f7
# ['SEEKING EXPERIENCES']
# How was your transition from shot-&gt;pill? Just started nuvaring on the 1st and my shot will no longer be active (?) on the 16th and I’m worried about what it’ll be like after that
# =============================================
# esj1qr4
# ['PROVIDING INFORMATIONAL SUPPORT']
# Do you log food before you eat it?  Log oil and all drinks etc? Do you have a food scale for portion size?
#
# Remember food label counts should be seen as an estimate as they can be off by a lot.
# =============================================
# dki55no
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# I would definitely try to talk to a pharmacist or doctor.
#
# I had a clot/stroke on estrogen based BC and just went through a bunch of doctors to get approved for Nexplanon. In general it is considered safer clot wise and that it's an option for me with my history makes me think it would be ok...but best to talk to someone about your specific situation. I feel pretty good about it (after talking to a contraceptive specialist), but am not without reservations.
# =============================================
# dyfm4u5
# ['PROVIDING INFORMATIONAL SUPPORT']
# ...
# =============================================
# c56holh
# ['PROVIDING INFORMATIONAL SUPPORT']
# Sometimes doctors make mistakes, they can't know everything about everything.
#
# Go to Paraguard's website for their pros and cons, including decrease risk in endometrial cancer.
#
# www.paraguard.com
# =============================================
# fad8r9a
# ['PROVIDING EMOTIONAL SUPPORT']
# I totally get where your girlfriend is coming from with this anxiety. I too get really anxious about the idea of getting pregnant, even though I have a copper IUD, which is more effective than the pill.
# Honestly, I think your girlfriend’s anxiety about the matter is very justified and mature. She doesn’t want to get pregnant, and so she is being cautious from doing so. Even when the pill is used 100% perfectly, which it almost never is, it is not 100% effective. There is a chance with any birth control that one could still get pregnant, and getting pregnant is not something (in my opinion at least), that should be disregarded carelessly.
# I don’t think that your girlfriend should have to change her boundaries about you cumming inside of her. I think that her boundaries about that should be respected.
# I would suggest talking to her about pulling out and cumming somewhere else on her. That way you both have satisfactory sex, but she doesn’t have to worry about sperm actually being inside of her. If she’s not comfortable with that, or you are always going to be pushing for cumming inside of her, then honestly, it doesn’t sound like you two are so compatible sexually.
# And as a last thought, maybe try changing up which types of condoms you use and giving condoms another shot?
# =============================================
# ezpzhhr
# ['PROVIDING INFORMATIONAL SUPPORT']
# Your pill has a 12h window before it's considered "missed". So as long as you try to keep a similar time (+/- a few hours is okay, just try to not make it a habit), all fine.
# =============================================
# eljs5ck
# ['PROVIDING INFORMATIONAL SUPPORT']
# Lol, one pill is enough.
# =============================================
# e5jaob5
# ['PROVIDING EXPERIENCES']
# Wife never had bad acne while taking Lutera. In our experience, pimples formed when she didn't wash her face daily or scratched her face with unwashed hands or used towels/bedsheets that hadn't been washed in a week.
# Everyone's biology is a little different. Keep in mind, the hormones take a month to kick in and suppress ovulation. You might be safe from the side effects in that regard.
# =============================================
# dw2yq91
# ['PROVIDING EXPERIENCES']
# I went to a gyne specifically for the copper IUD because I wanted off hormome pills and to switch to something that has a huge reliability that will last a while. She tried to convince me to try the mirena because the painful cramps and heavy bleeding that comes with the copper is more than most girls can handle but I told her that I want to go back to my natural hormone chemistry and be done with hormonal side effects. She seemed pretty sure that I would eventually switch but Im at 5 months in and Im pretty happy with my decision to go with the copper. Im still dealing with my body going back to normal hormone-wise so Im getting my period every 2-3 weeks instead of the average 4 weeks but my cramps are still super manageable with an aleve once a day.
# =============================================
# fism2uo
# ['PROVIDING INFORMATIONAL SUPPORT']
# Opinions are divided on this, so it's really up to you! Do what you feel comfortable with, have your follow-up ultrasound, check your strings regularly, and go to the doctor if anything seems "off" and you should be fine.
# =============================================
# fvvnfgn
# ['SEEKING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT']
# Really? That’s cool! I’m glad to see it’s not just me. Maybe there’s something to it. Yes, it’s norethindrone only. I’m switching to Lo Loestrin Fe in hopes that the tiny dose of estrogen will be just enough to prevent the two periods a month but not enough to increase my mood swings. I’m a little scared though.
# =============================================
# fko83nr
# ['PROVIDING EXPERIENCES']
# I felt much more stable on an estrogen &amp; progrestorine pill than I do now with Nexplanon for what it's worth. Might depend on the type of pill/BC you use.
# =============================================
# g0tw2yw
# ['PROVIDING EXPERIENCES']
# Hi there!! I just got my copper IUD YESTERDAY!! If you have any questions about the process let me know. This is my second IUD and my 4th birthday control method (hope it will be the last).
# =============================================
# fikzdnz
# ['PROVIDING EXPERIENCES', 'PROVIDING EMOTIONAL SUPPORT']
# I have heard lots of good stories of Nexplanon - mine isn’t one of them.
#
# I have been completely miserable and depressed since I got mine (my second one, oddly) 6 weeks ago. It has significantly altered my mood, and enough so that I can’t deal with it more. I am having my implant removed tomorrow morning and continuing my journey to the right BC. I know they tell you to wait 6 months but i can’t handle 6 months of being this anxious and miserable.
#
# Good luck, I hope you are able to figure yours out soon 💕
# =============================================
# dncx6cb
# ['PROVIDING INFORMATIONAL SUPPORT']
# As long as your break is only 7 days or less and you start a new pack on time, you're fine.
#
# For combo pills, just remember the following:
#
# * Always take at least 21 active pills in a row on time before taking any kind of break.
# * Once you have had 21 active pills in a row, you are safe to take a break anytime.
# * When taking a break from active pills, never take a break more than 7 days long.
# * You can always take *more* than 21 active pills in a row.
# * You can always take *less* than 7 days break.
# * Always take your pill at the same time each day - for most combo pills, within a 12 hour window is considered "on time" but don't risk it. Just take it at the same time everyday.
# * If you miss a pill, follow the instructions in your insert - and you can be extra safe by skipping the next placebos too.
# * Bleeding means nothing - you don't have a real period. If you think you might be pregnant, take a pregnancy test 21 days after the risky sex.
#
# Remember all that, and you should be just fine.
# =============================================
# drew22k
# ['PROVIDING EXPERIENCES']
# I don't know a thing about Paraguard but I also cramp after sex. It's never severe or anything just uncomfortable.
# =============================================
# euv8ms2
# ['PROVIDING EXPERIENCES', 'PROVIDING INFORMATIONAL SUPPORT']
# I am on the mini pill norethindrone, so far I like (about 4 months now). You might be able to get the desogestrel mini pill too, depending on where you live.
#
# I wonder if trying a pill would be easier on your body and how your body metabolizes a pill than an object inside giving off a constant dose.
#
# Good thing about the mini pill would be how easy it is to stop if you’re having adverse effects.
#
# Good luck!!
# =============================================
# fc75mqx
# ['PROVIDING EXPERIENCES']
# I was on Tri Sprintec Lo for years and there were times in the last year or two where my fiance/husband would want to have sex and I would be not into it AT ALL. I felt so bad because my drive was just soooo low. I recently switched to Nexplanon and I'm feeling much better! I actually want to sleep with my husband, woo hoo!
# =============================================
# ei6v68u
# ['PROVIDING EXPERIENCES']
# I had the skyla put in yesterday and as it was being inserted my doctor said I would feel 3 contractions, like I’m giving birth. I’ve never had a baby but holy hell I can only imagine how unbearably painful that would be without an epidural after that experience! It hurt.
# Also, I would have passed out if i would have sat up immediately after the procedure. My doc told me to stay laying down until the rush passed because it is quite common to pass out.
# I experienced heavy cramping for about 8 hours after and minimal today.
# =============================================
# es3z7h0
# ['PROVIDING EMOTIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# I'm sorry you had such a scary experience, but take a deep breath because you rocked it and now you're protected for 5 years! My insertion was painful, but I haven't regretted it, and I hope you won't either!
# =============================================
# fwdn42k
# ['PROVIDING INFORMATIONAL SUPPORT']
# It's safe to take active pills for as long as you desire past the first 21 pills. There is no set period where it becomes dangerous or whatnot.
# =============================================
# g0aa3et
# ['PROVIDING EXPERIENCES']
# I’m currently on Apri but when I was first prescribed my doctor told me I’d be able to take it continuously to skip my periods, what she didn’t tell me was that I would most likely experience breakthrough bleeding. After about 3 1/2 months continuously taking Apri i experienced something similar to you, red-brown bleeding which eventually turned into a full on period with cramps and everything. I freaked out and ended up scheduling an appointment with a different doctor and she told me it was perfectly normal as my body is adjusting to the hormones and skipping periods. She did tell me that the best plan of action, for me personally, was to take it three months at a time and then let my body have a period, which I’ve been doing for about a year now and haven’t had an issue with breakthrough bleeding since then.
#
# But you should finish your current pack and reach out and/or schedule an appointment with your doctor just to be safe. Everyone’s body is different but this reminded me of something I’ve experienced so I thought I would share.
# =============================================
# fqdch03
# ['PROVIDING EXPERIENCES']
# Wow, it's nuts that implanon made you gain so much weight?! Was it because it increased your appetite, or..? It's wonderful to hear that you found a pill that works for you, I think I'm going to have to experiment with quite a bit before I find what works for me. I was taking Yaz before the implant, which is pretty low dose and had breakthrough bleeding but it made me feel pretty good in other respects: mood, skin, etc. but it's extremely pricey!! I was really hoping that Implanon would change that and ideally it would've saved me so so much money but not everything works out :( I have ADHD and Implanon has made my symptoms so much worse (in addition to depression, headaches, oily skin, and hair loss??!), I genuinely thought there was something wrong with me and that I was going to fail uni because I had managed to lose my intelligence D: I really managed to hit the lottery with all the negative side effects
#
# Ahh yes, lots of things have been "COVID-cancelled" recently hahaha but I'm interested in hearing how the copper IUD works for you once and when you do get it in!! So cool that you go to Monash hehe
# =============================================
# dccxjps
# ['PROVIDING EXPERIENCES']
# Mirena iud gave me anxiety, crying spells, worsened my sleep paralysis and gave me paranoia. But everyone is different.
# =============================================
# dl88qs8
# ['DISCOURSE']
# For PhD candidates you're both being incredibly stupid and reckless. I hope you're both on the same page regarding abortion or postponement of your PhDs if it comes to that. There is no way to tell what day a woman ovulated and we can even ovulate twice in a cycle sometimes (that's how fraternal twins are a thing).
# =============================================
# dkhlots
# ['PROVIDING INFORMATIONAL SUPPORT']
# Huh? I am 30, no kids and have a copper IUD. get yourself another doctor for a second opinion. Your uterus might be too small, however, the hormonal IUDs aren't that bad. Skyla is the smallest of IUDs and most still get their cycle on it.
#
# Edit: your height has no correlation to do with the size of your uterus.
# =============================================
# eah9ror
# ['PROVIDING EXPERIENCES']
# I have the copper iud and my person hasn’t said anything about feeling the strings. I had sex about a week after insertion. To my knowledge your partner should be able to move or dislodge it but it may take you a second to get used to it since you say he hits your cervix often. Every body is different. Personally love my copper iud! And it’s only been a few months
# =============================================
# g7vv3re
# ['PROVIDING EMOTIONAL SUPPORT', 'DISCOURSE']
# Wow! What a story! I hope you are feeling better today.
#
# Thank you card with a gift card for them to get coffee or lunch? Or you could make a snack basket for the break room?
# =============================================
# dhfzja6
# ['PROVIDING EXPERIENCES']
# I lost half my hair with the mirena IUD. Came out in clumps for 3-4 months straight. Had it removed and still had terrible shedding for another 3-4 months. I'm finally getting back to normal at 10 months
# =============================================
# g71tq68
# ['DISCOURSE', 'PROVIDING INFORMATIONAL SUPPORT']
# You will hear awful things about everything out there. Including pills, implants, patches, everything! Nothing comes without risks or without side effects.
# =============================================
# fvyeeuq
# ['PROVIDING INFORMATIONAL SUPPORT']
# Ella interacts with your birth control, and your birth control interacts with ella. That's why you shouldn't take it because they make each other less effective and you'll have to use backup or abstain for a while, in addition to ella being already less effective. If you want to take plan B, you're better off taking the usual 1.5mg levonorgestrel type.
#
# Check your pamphlet in terms of what to do when you miss pills. I've never heard of a norethindrone acetate minipill so I have no idea what timeframes they have or whatnot.
# =============================================
# dfwq8yy
# ['PROVIDING INFORMATIONAL SUPPORT']
# I've not had an abortion, but I would suggest all the basics that you would have for any other period or when she's ill. A heat pad or hot water bottle, somewhere comfy for her to be, things that make her feel better when she's unwell - comforting food or sweets, a cheerful TV show to distract her, lots of water and warm drinks etc.
#
# But the best thing is to try and be there for her - she's made a very difficult decision and she may feel all sorts of different emotions before, during and after the abortion. Don't try and solve the problems, just let her feel what she needs to feel and comfort her, and of course give her privacy when she needs it.
#
# Also some heavy and super heavy flow sanitary towels will be necessary and she may have some bleeding for quite a while after the abortion is over.
# =============================================
# d80yoqr
# ['PROVIDING EXPERIENCES']
# I had such bad acne after a year with it in!
# =============================================
# dk6v12f
# ['DISCOURSE', 'PROVIDING EXPERIENCES']
# I said "I would personally wait a month." Not, OP has to wait a month. I know it's 7 days and I stated that above. I was on the pill for 6 years and waited a month myself even though I knew it was instantly effective because I started the first day of my period.
# =============================================
# dg69ixs
# ['PROVIDING INFORMATIONAL SUPPORT', 'DISCOURSE']
# I'm utterly confused. You have said you have had the IUD for **3 months**? Why on Earth did you take Plan B in February (6-7 weeks ago)?
# =============================================
# fpdekpl
# ['PROVIDING EXPERIENCES']
# How long have you had it? I'd give it time. My first few periods were pretty painful. Once I got through a few months, it's great. I'd wait it out of you can!
# =============================================
# dunp3jb
# ['PROVIDING INFORMATIONAL SUPPORT']
# Just to clarify, you can feel the plastic tip with your fingers?
# =============================================

# %%
final_dicts = []
for _id, _labels in id_majority_labels_dict.items():
    for _label in _labels:
        final_dicts.append({'ID': _id,
                            'Label': _label,
                            'Text': id_text_dict[_id],
                            'Source': 'reddit-comments',
                            'Decision': 'two or more'})
final_df = pd.DataFrame(final_dicts)
final_df.to_csv(data_directory_path + '/labeling/majority.reddit_comments.csv')

# %% [markdown]
# <br><br>
#
# # Get majority labels for TWITTER POSTS

# %%
target_df = combined_df[combined_df['Source'] == 'twitter-posts']

# %%
id_text_dict = {}
for i, r in target_df.iterrows():
    id_text_dict[r['ID']] = r['Text']
len(id_text_dict)
# Out:
# 497

# %%
ids_labeled_by_roz = list(set([r['ID'] for i, r in target_df.iterrows() if r['Labeler'] == 'Roz']))
len(ids_labeled_by_roz)
# Out:
# 292

# %%
id_labeler_labels_dict = defaultdict(lambda: defaultdict(list))
for i, r in target_df.iterrows():
    if r['ID'] in ids_labeled_by_roz:
        id_labeler_labels_dict[r['ID']][r['Labeler']].append(r['Label'])
len(id_labeler_labels_dict)
# Out:
# 292

# %%
id_majority_labels_dict = {}
for _id, _labeler_labels_dict in id_labeler_labels_dict.items():
    _label_count_dict = defaultdict(int)
    for _labeler, _labels in _labeler_labels_dict.items():
        for _label in _labels:
            _label_count_dict[_label] += 1
    _majority_labels = [_label for _label, _count in _label_count_dict.items() if _count >= 2]
    if _majority_labels:
        id_majority_labels_dict[_id] = _majority_labels
len(id_majority_labels_dict)
# Out:
# 285

# %%
for _id, _labels in id_majority_labels_dict.items():
    print(_id)
    print(_labels)
    print(id_text_dict[_id])
    print('=============================================')
# Out:
# 1266030580036259800
# ['SEEKING EMOTIONAL SUPPORT']
# I want the IUD so bad but I’m scared 🥺🙄
# =============================================
# 1215895024107507700
# ['DISCOURSE']
# i cannot believe there’s a non-hormonal oral contraceptive that’s been on the market for thirty YEARS but it’s only available in india. this world is a sick joke
# =============================================
# 1208819982840344600
# ['SEEKING EXPERIENCES']
# Hey ladies, Do any of y’all have an IUD and use a menstrual cup?
# =============================================
# 155399192255283200
# ['DISCOURSE']
# My cousin's wife just told me about a friend who was injured when an "IUD" exploded in Afghanistan.
# =============================================
# 392974329991790600
# ['DISCOURSE']
# I said I have the birth control implant in my arm and Petty Officer Burdette is like "what's that have to do anything w/your vagina?!"
# =============================================
# 964617929894527000
# ['PROVIDING INFORMATIONAL SUPPORT']
# Check out this interesting factoid from our friends at the Oral Contraception Over the Counter Coalition! #FreeThePill https://t.co/nncjs2Abe9
# =============================================
# 248648850909315070
# ['SEEKING INFORMATIONAL SUPPORT']
# So has anyone heard about the Mirena IUD Recall???
# =============================================
# 496393794137251840
# ['PROVIDING INFORMATIONAL SUPPORT']
# Best Birth Control Pill For Larger Breasts http://t.co/HKErJlcwSv
# =============================================
# 316960411381547000
# ['PROVIDING EXPERIENCES']
# Arm is sore but at least I dnt have to worry about remembering to take a birth control pill anymore #Nexplanon
# =============================================
# 438056262865915900
# ['PROVIDING EXPERIENCES']
# #birthcontrol (like paraguard) because...he don't like to wear #condoms
# =============================================
# 1032236018404139000
# ['PROVIDING INFORMATIONAL SUPPORT']
# The 3rd most popular contraceptive in Europe is the IUD. Effective for approx. 5 years, IUDs are a long-acting reversible contraceptive (LARC) - less risk of failure &amp; high satisfaction rates. #KnowledgeIsPower #FamilyPlanning #ReproRightsAreHumanRights #HumpDay https://t.co/6XGTRnK1XK
# =============================================
# 1047335830430388200
# ['PROVIDING EXPERIENCES']
# I keep thinking about this: I was lucky that my insertion was relatively easy, which is to say it hurt like hell but was over fast. I’m so conditioned to expect pain that it didn’t occur to me to ask for pain management. I love my IUD, but am dreading its replacement. https://t.co/71tENb6y0k
# =============================================
# 26244321958
# ['SEEKING INFORMATIONAL SUPPORT']
# Can a tatoo interfare with an Iud hormones - Can a tatoo interfare ... http://bit.ly/d4BeZZ
# =============================================
# 317482105301004300
# ['DISCOURSE']
# Kyleena ass got me rollin
# =============================================
# 106412467780993020
# ['PROVIDING INFORMATIONAL SUPPORT']
# Missed Period and Missed Contraceptive Pill - Two Common Occurrences in a Woman's Life: There are various reason... http://t.co/5S0KeYl
# =============================================
# 857955803826970600
# ['PROVIDING INFORMATIONAL SUPPORT']
# Efficacy of oral contraception may be impaired after gastric bypass surgery. #CWH2017
# =============================================
# 364749107547480060
# ['DISCOURSE']
# Y'all hoes would pop a Molly before y'all pop a Birth Control pill.. SMFH.
# =============================================
# 1157404122691309600
# ['DISCOURSE']
# Is post-audience Tinder the new chat bot is the only requirement for a birth control pill brand.
# =============================================
# 855136350378627100
# ['PROVIDING INFORMATIONAL SUPPORT']
# https://t.co/KZBZgT8lcB Statistically significant reduction in general well-being by a first-choice combined oral contraceptive pill (150 …
# =============================================
# 1145462618678689800
# ['PROVIDING INFORMATIONAL SUPPORT']
# Nexplanon.. it go in ya arm and it last for 4-5 years https://t.co/uqqUn0fmJ8
# =============================================
# 435970522598240260
# ['PROVIDING INFORMATIONAL SUPPORT']
# Re: Implanon Side Effect Report#3661 itching, redness &amp; swelling: ,,,,,,,,,,,,,,,, http://t.co/Cw5x27dNHB
# =============================================
# 1196381986786611200
# ['PROVIDING INFORMATIONAL SUPPORT']
# The Intra-Uterine Device or IUD method is a small, flexible plastic (or plastic and copper) device that prevents pregnancy for 5-10 years. It is is inserted in a woman’s uterus by a trained provider. IUDs are safe for breastfeeding women. #SRHR #FPMethods #GetItTogether https://t.co/DQFxNctuPo
# =============================================
# 194806465280737280
# ['SEEKING EMOTIONAL SUPPORT']
# Thank you Jesus no more implanon !! Bck to basic birth control !!*praise the lord I'm free*
# =============================================
# 664045128340869100
# ['PROVIDING INFORMATIONAL SUPPORT']
# Via @NPR: More Women Opt For IUD, Contraceptive Implant For Birth Control https://t.co/BzGwalg3VS
# =============================================
# 1167062701207691300
# ['PROVIDING INFORMATIONAL SUPPORT']
# Oral contraceptive pills and cancer risks https://t.co/I6KZddqCMH
# =============================================
# 704496575083470800
# ['PROVIDING INFORMATIONAL SUPPORT']
# reveals New, stronger FDA warning for Essure birth control implant: WASHINGTON (AP) -- Federal health r... https://t.co/1gYUX0rEkR
# =============================================
# 117435782037389310
# ['DISCOURSE']
# i dont think i was suppose to take that birth control pill with this liquor lol
# =============================================
# 565359201523105800
# ['PROVIDING INFORMATIONAL SUPPORT']
# Why the #contraceptive pill was a revolution for women and men | SBS News http://t.co/jZmp3awxC9
# =============================================
# 650475313365958700
# ['PROVIDING INFORMATIONAL SUPPORT']
# Researchers found a potential male birth control pill in an immunosuppressant drug http://t.co/iwpbmoi0qb http://t.co/tgOIA0OlJB
# =============================================
# 677175713032757200
# ['PROVIDING EXPERIENCES']
# That damn implanon blew me up!!
# =============================================
# 8880821828
# ['PROVIDING INFORMATIONAL SUPPORT']
# Marijuana Research Offers New Hope For Birth Control Pill: The male birth control pill has lingered for years tant... http://bit.ly/bzKVi8
# =============================================
# 82462030023491580
# ['DISCOURSE']
# Chuck Norris was born laughing with one fist closed. They found a birth control pill in Chuck's hand. NOTHING BEATS CHUCK NORRIS!
# =============================================
# 251098973929086980
# ['PROVIDING INFORMATIONAL SUPPORT']
# Doctor says push for teen IUD use brings health risks: Washington D.C., Sep 26, 2012 / 05:05… http://t.co/5ik6lorC
# =============================================
# 325252024797130750
# ['PROVIDING INFORMATIONAL SUPPORT']
# A Cu IUD that costs £10 in the UK, costs $500 in the US #FSRHASM #SaveTheNHS #contraception
# =============================================
# 435817025726738400
# ['DISCOURSE']
# The #ExecutiveOrder equivalency game: Obama 168; GW Bush 291; Reagan 381. Let's compare 2 other man-made devices: Is 1 IED equal to 1 IUD?
# =============================================
# 152126590900375550
# ['SEEKING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT']
# I'm at the lady doctor... Recommend some BC for me... I lowkey want the IUD or Mirena but, people scare me with their horror stories
# =============================================
# 308834398990635000
# ['PROVIDING INFORMATIONAL SUPPORT']
# Glenmark recalls oral contraceptive drugs in USA; stk down 2%: Shares of Glenmark fall 2% after the pharma com... http://t.co/f0xJO1oswP
# =============================================
# 297542390007341060
# ['DISCOURSE']
# Radio host: Women on birth control pill have wombs ‘embedded’ with ‘little tiny fetuses’ http://t.co/J2YgEWUG
# =============================================
# 1334185468217487400
# ['PROVIDING INFORMATIONAL SUPPORT']
# Take your birth control pill. https://t.co/SbOUpBfimH
# =============================================
# 8366306851
# ['PROVIDING INFORMATIONAL SUPPORT']
# Research shows new emergency contraceptive pill is effective in preventing pregnancies http://is.gd/7hGo1
# =============================================
# 21179957921
# ['PROVIDING INFORMATIONAL SUPPORT']
# Better, More Effective Contraceptive Pill To Hit US Market Soon http://bit.ly/b2s9iD http://bit.ly/joinMe
# =============================================
# 403249844200177660
# ['SEEKING EMOTIONAL SUPPORT']
# I'm so nervous to get this nexplanon put it 😰
# =============================================
# 557677829702553600
# ['PROVIDING INFORMATIONAL SUPPORT']
# Why gynecologists think IUDs are the best contraceptive http://t.co/mEL7LTFK2X via @sarahkliff
# =============================================
# 645962388412452900
# ['DISCOURSE']
# If you have the ability to suck an IUD out please stay away from me lol.
# =============================================
# 1104305233180672000
# ['PROVIDING INFORMATIONAL SUPPORT']
# I've just posted a new blog: Just How to Switch to a New Birth Control Pill https://t.co/HLFDl65pzY
# =============================================
# 1140717935759151100
# ['DISCOURSE']
# *checking into doctors office when i see a cute ass baby* me, to the check in lady: i’m not old enough to have a baby but man, they’re cute check in lady: i had my baby at 20 years old, your maternal instinct will kick in me: well i’m here for an IUD so... https://t.co/4HhasK7oWc
# =============================================
# 884834472847454200
# ['PROVIDING EXPERIENCES']
# IUD! I would highly recommend it bc I've had lots of cream pies https://t.co/gEuQUlC2x5
# =============================================
# 467138276432703500
# ['PROVIDING INFORMATIONAL SUPPORT']
# What is Mirena IUD Lawsuits? Visit this site to discover all information. #MirenaIUDLawsuits http://t.co/e0OtBJkJwB
# =============================================
# 225220888990191600
# ['PROVIDING INFORMATIONAL SUPPORT', 'DISCOURSE']
# There's talk of Truvada becoming the gay equivalent of the contraceptive pill. Studies show taking daily reduces chance of HIV transmitting
# =============================================
# 59856702421467140
# ['DISCOURSE']
# they act like a birth control pill...they have to argue at this exact time everyday
# =============================================
# 773190340874539000
# ['PROVIDING INFORMATIONAL SUPPORT']
# Why would you take the contraceptive pill 4 times a day? https://t.co/LClaqL3rXw
# =============================================
# 767162686241144800
# ['PROVIDING EXPERIENCES']
# When I was getting my IUD my gynecologist spent the entire time talking to me about how she wanted to learn the ukulele it was phenomenal
# =============================================
# 819207978037309400
# ['PROVIDING EXPERIENCES']
# I love my IUD! https://t.co/UY1WRGx8jW
# =============================================
# 1248634691118399500
# ['PROVIDING EXPERIENCES']
# The cramps I get due to having an IUD are worse than the cramps I had without an IUD.
# =============================================
# 889053735024025600
# ['PROVIDING EXPERIENCES']
# NEW BLOG POST: My time on the contraceptive pill 💊 @FemaleBloggerRT https://t.co/nA9zUKZQsP
# =============================================
# 1092869425638883300
# ['PROVIDING INFORMATIONAL SUPPORT']
# In Massachusetts, Planned Parenthood clinics reported a dramatic spike in IUD demand after Trump's election, from about 3 per day to closer to 50: https://t.co/B8grH4YDYe
# =============================================
# 8869098352
# ['DISCOURSE']
# RT @runwaytyp3: Omg they having a screaming contest with the baby *pops a birth control pill*&lt;lmfao!!
# =============================================
# 1125901878636761100
# ['DISCOURSE']
# No thanks ,as a woman I am insulted that you feel I am too dumb to take care of my productive rights by myself by taking the pill,iud,implant,spermicide and condom.I am not stupid enough to commit murder! https://t.co/pclu2iDMc3
# =============================================
# 1166077760932126700
# ['DISCOURSE']
# Is that a fuckin IUD https://t.co/DZwtxJGq0z
# =============================================
# 1114685618976464900
# ['PROVIDING EXPERIENCES', 'DISCOURSE']
# new hobbies include: writhing in pain caused by a misplaced iud while thinking every sound in my apartment is the rat that apparently has been raiding my garbage
# =============================================
# 553386761720582140
# ['DISCOURSE']
# The Fluke/Dunham IUD/coat hanger stabbing 😂 😂 😂
# =============================================
# 677041481920749600
# ['DISCOURSE']
# In the news - @PJOnline_News: "Contraceptive implant linked to repeat abortion" https://t.co/CorJFPCTwy
# =============================================
# 1073094616059125800
# ['PROVIDING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT']
# Ok so I’m having really bad cramps Rn and i JUST got off my period. If having the iud is just constant cramps idk if i can do this shit
# =============================================
# 913474370298945500
# ['DISCOURSE']
# Just saw a baby so cute I almost popped out my IUD on the spot
# =============================================
# 838087975250636800
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EMOTIONAL SUPPORT']
# The IUD goes where you go, doing its thing safely + effectively. As for you? You can concentrate on everything else. https://t.co/k4mpLQIDBN
# =============================================
# 916805322349703200
# ['PROVIDING INFORMATIONAL SUPPORT']
# @ ALL THE LADIES WITH IUD IMPLANTS (more specifically the copper Mirena)!!!!!!!!!!!
# =============================================
# 398908986256146400
# ['PROVIDING INFORMATIONAL SUPPORT']
# Oral contraceptive pills and hormone replacement therapy both contain estrogen, which lowers protein S levels and promotes thrombosis.
# =============================================
# 92527535266598910
# ['PROVIDING INFORMATIONAL SUPPORT']
# Is Your Generic Birth Control Pill Really the Same as the Brand Name Version? Below the Belt: Womens Health #birth http://t.co/znZ4434...
# =============================================
# 848853084897988600
# ['DISCOURSE']
# But nah i need a new IUD before something tragic happens to PP
# =============================================
# 999106591935946800
# ['PROVIDING EXPERIENCES']
# Ovulation cramps with my IUD are no joke 😅
# =============================================
# 1231476660882563000
# ['DISCOURSE']
# Its 2020 and I’m tired of hearing the term “pussy” be used to define weakness. Female genitalia is STRONG! Push a watermelon through a dick without it rupturing and we can talk. But after my IUD mishap for the past 2 years my genitalia will now only answer to the name John McCain
# =============================================
# 1060136309422022700
# ['PROVIDING INFORMATIONAL SUPPORT']
# Birth control pill recalled over incorrect dispenser instructions https://t.co/sCX5miiIkE https://t.co/5EzQ3F8Q7p
# =============================================
# 1154095232620744700
# ['DISCOURSE']
# Jane and her IUD loved their visit to Vermont! https://t.co/DF0BI4qpnF
# =============================================
# 1182333830176411600
# ['DISCOURSE']
# Y’all better leave these IUD’s alone 😩😩😩
# =============================================
# 976578908094001200
# ['DISCOURSE']
# every birth control pill sounds like an up and coming pop star https://t.co/P6fD7deIQc
# =============================================
# 252431127720116220
# ['DISCOURSE']
# "A contraceptive pill is to be considered an essential medicine. If it is a medicine, what sickness is it curing? Is pregnancy a sickness?"
# =============================================
# 402507800829386750
# ['PROVIDING INFORMATIONAL SUPPORT']
# Long-term contraceptive pill use doubles glaucoma risk, research finds http://t.co/Qj0kRNSQWf
# =============================================
# 1329163892694667300
# ['PROVIDING EXPERIENCES']
# My dr reassured me that I wouldn’t get pregnant with the nexplanon ✨ love it 😂😂
# =============================================
# 286235301272231940
# ['DISCOURSE']
# Does any1 care that @HobbyLobbyStore doesn't know that Plan B/BC Pill R the same? #boycott #hobbylobby (cont) http://t.co/gEcc9mxk
# =============================================
# 407704705943765000
# ['PROVIDING INFORMATIONAL SUPPORT']
# Male contraceptive pill a step closer http://t.co/gEfiJfmi7C
# =============================================
# 626085045258731500
# ['PROVIDING EXPERIENCES']
# Praising the iud every day. Without it Larry and I would be expecting. 😂😂
# =============================================
# 870086450238427100
# ['DISCOURSE']
# Her - "I'm not on the pill." Me - "Oh, it's no big deal. Condoms are fine w..." Her - "I have an IUD." Me: https://t.co/sQivgiDcaW
# =============================================
# 220403094440259600
# ['PROVIDING INFORMATIONAL SUPPORT']
# Lupin (LPC): Copy of J&amp;J birth control pill Ortho Tri-cyclen Lo cleared by FDA
# =============================================
# 319207933743333400
# ['PROVIDING EXPERIENCES']
# Implanon is the best birth control ever!!! Nothing to take everyday and no side effects 😬 highly suggest it to u ladies ;)
# =============================================
# 14714859452
# ['DISCOURSE']
# #Hustla =»=» RT @NOLABelle83: New birth control pill prescribed sooo I got PACKS of the others if anyone want them...Small fee of course
# =============================================
# 212576548665040900
# ['DISCOURSE']
# roles. Introduction of the birth control pill and demand for women to enter the workforce allowed women to enter into the public sphere
# =============================================
# 407969877459099650
# ['DISCOURSE']
# Male contraceptive pill on the horizon. "Relax babe I'm on the pill" ... And everyone gets herpes
# =============================================
# 12742469049
# ['SEEKING INFORMATIONAL SUPPORT']
# A birth control pill least likely to have depression as a side effect?: I’ve been depressed… http://goo.gl/fb/5kwwX
# =============================================
# 896623648878067700
# ['SEEKING INFORMATIONAL SUPPORT']
# Ok so I heard that after you have one iud you shouldn't get another one.....is that true??
# =============================================
# 1292267928134586400
# ['PROVIDING EXPERIENCES']
# is this tmi idk but my iud strings are finally soft it is a miracle
# =============================================
# 844593450007826400
# ['PROVIDING INFORMATIONAL SUPPORT']
# #Science https://t.co/KvQYhDC9HK Contraceptive pill protects women against cancer for many years after stopping taking it, major study sug…
# =============================================
# 267063796156219400
# ['PROVIDING EXPERIENCES']
# Ok so I just went off birth control pill about 2 months ago and i haven't gotten ... Absolutely. Sign in to report... http://t.co/j9bQvp2m
# =============================================
# 8408606017
# ['PROVIDING INFORMATIONAL SUPPORT']
# Contraceptive pill effective even 5 days after intercourse - The Money Times: eFitnessNowContraceptive pill effective e http://url4.eu/1GxvO
# =============================================
# 1059245528972738600
# ['PROVIDING EXPERIENCES']
# I swear to god I have every sign of being pregnant... while not pregnant. Between being always tired puking getting sick over smells all that. Thankfully I have an IUD and Aunt Flo still comes or I’d be hella worried!!
# =============================================
# 753600955912949800
# ['PROVIDING INFORMATIONAL SUPPORT']
# Does taking an oral contraceptive impair a woman's ability to be empathetic? Study suggests yes, on pill-free weeks: https://t.co/UKf3HAJVDj
# =============================================
# 1208103316531617800
# ['PROVIDING INFORMATIONAL SUPPORT']
# My research lab just published a new paper looking at birth control pill use and perseverance. See the link below to check it out. https://t.co/LL7ALJT8Hc https://t.co/rNHA3SbIjK
# =============================================
# 648659168711286800
# ['DISCOURSE']
# I'm hardheaded. I need to get my implanon back 😩
# =============================================
# 265979763796111360
# ['DISCOURSE']
# If things don't go the way I'm praying I better get a new IUD next week, last me clear thru a #Mittens presidency
# =============================================
# 78421488746758140
# ['PROVIDING INFORMATIONAL SUPPORT']
# Birth Control Pill for Men: Would You Count On It? http://abcn.ws/jIn4rE /via @ABC
# =============================================
# 589019386872254500
# ['DISCOURSE']
# And take a birth control pill, i dont want no mini me at this stage — Ill see if i can find any c: http://t.co/3WeH7Bgzjr
# =============================================
# 775458568015228900
# ['PROVIDING INFORMATIONAL SUPPORT']
# Levonorgestrel IUD potentially cost-effective in obese women https://t.co/ifghsX32bb
# =============================================
# 975503487680307200
# ['PROVIDING INFORMATIONAL SUPPORT']
# Dimethandrolone undecanoate shows promise as a male birth control pill - Medical Xpress https://t.co/44U7t1KgKM
# =============================================
# 561784082070118400
# ['DISCOURSE']
# Carl Djerassi, chemist behind birth control pill, dead at 91 http://t.co/w4LTFQZSuq
# =============================================
# 376011702292074500
# ['PROVIDING INFORMATIONAL SUPPORT']
# "...a massive recall of generic birth-control pill..."... http://t.co/JctP2FtycZ
# =============================================
# 635039745605812200
# ['SEEKING EXPERIENCES']
# --&gt; Tell us what you love and hate about #contraception in our 3 minute #PrescribeDesign Survey http://t.co/7s7edQ6CVj #pills #IUD #implant
# =============================================
# 103561662220611580
# ['SEEKING EXPERIENCES']
# Contraceptive implant: Does anyone use this?. I would like to avoid periods! Do you still bleed with this xxx http://t.co/FQTEhpp
# =============================================
# 84053212079992830
# ['DISCOURSE']
# Why? You have sex w/ men. They don't get pregnant. RT @lilduval: if they approve this male birth control pill im gon be the 1st in line...
# =============================================
# 131780867990368260
# ['PROVIDING INFORMATIONAL SUPPORT']
# How Does the Birth Control Pill Affect Menstruation? : http://t.co/kQHWMP39 #p
# =============================================
# 1341278308000907300
# ['PROVIDING EXPERIENCES']
# I feel bad for y’all bc I actually kinda like this nexplanon
# =============================================
# 489404387874193400
# ['DISCOURSE']
# Define contraceptive pill? It's the second best thing that a women can keep in her mouth to avoid pregnancy.
# =============================================
# 334126783588880400
# ['SEEKING EXPERIENCES']
# BC Question from a fan Has anyone used the implanon (nexplanon) for birth control? What did you think bout it?
# =============================================
# 1303379677952737300
# ['DISCOURSE']
# Me: *Casually looking up IUD’s while my friend argues with her son who’s doing 2nd grade online this semester*
# =============================================
# 1242453401792909300
# ['PROVIDING EXPERIENCES', 'DISCOURSE']
# Since I'm not on the birth control pill anymore my period cramps are coming back. I took a shower, laid in bed and my bf was like "u okay" and I teared up a little, saying that my uterus hurts and he was like "hell nah, gonna cuddle the pain away"
# =============================================
# 1331422528871522300
# ['PROVIDING EXPERIENCES']
# Finally able to get this nexplanon removed as of tomorrow!!!
# =============================================
# 153929524088803330
# ['DISCOURSE', 'PROVIDING INFORMATIONAL SUPPORT']
# WTF? U gatta be joking RT @WTFuckFacts: The Birth Control Pill fails 6.2% of the time.
# =============================================
# 654081876693422100
# ['PROVIDING INFORMATIONAL SUPPORT']
# Women With Essure Contraceptive Implant Needed More Surgeries, Study Finds: Women who sought sterilization thr... http://t.co/LvRI2QSu5F
# =============================================
# 845359559644373000
# ['PROVIDING EXPERIENCES']
# Ok nexplanon is really terrible
# =============================================
# 1128313250360299500
# ['DISCOURSE']
# Jeremy Hunt: Ban the contraceptive pill Ridgevidon in the UK - Sign the Petition! https://t.co/vuvjFLUb6g via @UKChange i didn’t even know the side effects of this pill but pls help ppl become aware and get it banned !!
# =============================================
# 441141465482526700
# ['PROVIDING INFORMATIONAL SUPPORT']
# New under the skin Contraceptive implant for women in the public health facilities - @RediTlhabi @Radio702 talking to Dr Howard Monyanga
# =============================================
# 891467882432999400
# ['DISCOURSE']
# I just took my birth control pill with my margarita because they was taking too long with the water 🤷🏾‍♀️😂
# =============================================
# 1261998184877998000
# ['DISCOURSE']
# I'm just saying, the fact that there's no standard for pain relief for an IUD is barbaric. Ibuprofen really isn't enough for something routinely described as "blindingly painful." Just another example of how medicine doesn't take women's pain seriously 🤓
# =============================================
# 338361453943865340
# ['PROVIDING INFORMATIONAL SUPPORT']
# Bleeding after a Mirena IUD insertion, what to expect http://t.co/AALb10GyRZ via @wordpressdotcom
# =============================================
# 804534043438174200
# ['DISCOURSE']
# #IUD appointments up 82% after Trump's win. Reported by #PlannedParenthood of #Illinois . Read… https://t.co/szVhUfpcCl
# =============================================
# 767775770865377300
# ['PROVIDING EXPERIENCES', 'DISCOURSE']
# I'm anti BC but WHO AINT GETTING AN IUD ON SEPT 5th???????? THIS GIRL IS!!!
# =============================================
# 689772847942746100
# ['DISCOURSE']
# Father demands changes after daughter dies from clot caused by contraceptive pill https://t.co/zOjSh71Tu0 https://t.co/RFzgsFeUiI
# =============================================
# 855162301070151700
# ['PROVIDING EXPERIENCES']
# And then mi go fuck with depo-provera which was like poison. Never again lol I'm anti-birth control pill oral or injections
# =============================================
# 1288603413006241800
# ['PROVIDING EXPERIENCES']
# Get off hormones Lose my shiiiit, depressed, cry everyday Get on blood thinners Have a period for a million weeks Become anemic Get an IUD to slow down bleeding Cramps every day I mean... at this point. Idk how lucky I am to be alive in misery.
# =============================================
# 164740016805904400
# ['PROVIDING INFORMATIONAL SUPPORT']
# Thx. Read @NPRHealth Birth Control Pill Mix-Up Leads To Pfizer Recall: Pfizer is recalling 1 million packages of... http://t.co/yKFWLthC
# =============================================
# 236169462859046900
# ['PROVIDING INFORMATIONAL SUPPORT']
# New cancer drug affects sperm, study shows. Finally, a male birth control pill? - http://t.co/ElWBOZmt: Daily Mai... http://t.co/YyzXcf1V
# =============================================
# 1191174702087061500
# ['PROVIDING EXPERIENCES']
# i feel icky af like i keep getting with waves of dizziness while just sitting and doing a puzzle and i want nothing but junk food so i think my body is adjusting to the iud well lmao
# =============================================
# 48252557231009790
# ['SEEKING EXPERIENCES']
# is #this a #normal #reaction to #implanon #contraceptive #implant? http://goo.gl/fb/yJrmF
# =============================================
# 466865480653754400
# ['PROVIDING INFORMATIONAL SUPPORT']
# Contraceptive pill doesn't kill sex drive That contraceptive pill has a secret to share. According to r #WorldNews http://t.co/LoUPlfeWlO
# =============================================
# 964277082179166200
# ['DISCOURSE']
# Nexplanon is such a cock block man
# =============================================
# 942582974905598000
# ['PROVIDING EXPERIENCES']
# ICYMI: the IUD horror stories. https://t.co/W24ILWCHc7
# =============================================
# 973625961605423100
# ['PROVIDING INFORMATIONAL SUPPORT']
# Keep an eye out for my interview with @nickyKfitness which will be on @FastRunning_ at the end of the week. Dr Keay gives her fascinating expertise on periods, hormones and the contraceptive pill in athletes. https://t.co/DKYfxDQMhN
# =============================================
# 163071762282717200
# ['PROVIDING INFORMATIONAL SUPPORT']
# The Birth control pill as a type of contraception http://t.co/I6c2WZnx
# =============================================
# 582277387292958700
# ['PROVIDING INFORMATIONAL SUPPORT']
# 5 Things You Need to Know about IUDs - Especially #5! http://t.co/hmsTpruSM3 http://t.co/0vlvNS9uGG
# =============================================
# 864486006275395600
# ['PROVIDING EXPERIENCES']
# Was on depo two years ago missed one shot had twin girls got the birth control implant that last 3 years took it out after 2 years now
# =============================================
# 969949379418353700
# ['DISCOURSE']
# 😂😂😂😂😂 RT @ImJustErnest: Fuckin a chick with an IUD feels like the pussy got teeth.
# =============================================
# 411661078238478340
# ['PROVIDING INFORMATIONAL SUPPORT']
# A male birth control pill? A male birth control pill. http://t.co/iCCRx6vmuj
# =============================================
# 500296424081600500
# ['PROVIDING INFORMATIONAL SUPPORT']
# http://t.co/QS30xaAcCQ - see this article - takes birth control pill
# =============================================
# 657372510602842100
# ['DISCOURSE']
# In other news, ladies, ya'll better not use #nexplanon. Did you see how long that commercial was?/
# =============================================
# 1087040099567763500
# ['PROVIDING EXPERIENCES']
# Getting an iud is top 3 worst decisions I’ve ever made
# =============================================
# 997596260549865500
# ['PROVIDING INFORMATIONAL SUPPORT']
# FDA restricts use of birth control implant Essure https://t.co/UhsfAsk6D7 https://t.co/zAntdlKsUp
# =============================================
# 321745283274911740
# ['PROVIDING INFORMATIONAL SUPPORT']
# Alert: Alysena-28 Birth Control Pill recalled due to problem with placebo pills. For more info visit our latest news: http://t.co/mmxfiOwpTu
# =============================================
# 1254437036494332000
# ['PROVIDING EXPERIENCES']
# I just remembered that when I was taking the birth control pill my prescription didn’t have a placebo week and no one told me I was supposed to skip so I just kept taking them through and I didn’t find out until I switched to an IUD
# =============================================
# 634144072727425000
# ['PROVIDING INFORMATIONAL SUPPORT']
# Contraceptive Pill 'Cuts Womb Cancer Risk' http://t.co/IbVb672SRO
# =============================================
# 391025354116460540
# ['SEEKING INFORMATIONAL SUPPORT']
# FQ Ok I've got a question I've had the nexplanon implant since March and I didn't bleed at all for several months... http://t.co/pDtJGhHUYO
# =============================================
# 1070468029711032300
# ['DISCOURSE', 'PROVIDING EXPERIENCES']
# After completing my IUD insertion, the Dr goes “congratulations, you have an IUD!” just how the delivery doctors say “congratulations, you have a baby girl” after you give birth and honestly I don’t think I want to hear either of those things ever again.
# =============================================
# 414607274473447400
# ['PROVIDING INFORMATIONAL SUPPORT']
# "Researchers Create First Male Birth Control Pill. Here’s How It Works" http://t.co/hkijEDU8MJ BS!
# =============================================
# 1220168318046429200
# ['DISCOURSE']
# Let’s just say me wee wee made acquaintance with an IUD https://t.co/n1m2eMSgdS
# =============================================
# 1286541758533259300
# ['SEEKING EMOTIONAL SUPPORT']
# i hope this IUD doesn’t fuck up my body
# =============================================
# 1320958730825990100
# ['DISCOURSE']
# ahhh feels so good to be a woman who cant get an IUD or implant right about now
# =============================================
# 213850039997579260
# ['PROVIDING EXPERIENCES']
# ok first off i want to say i have paraguard (copper iud) and ive had it since last septemeber. ok so me and my b... http://t.co/DSju7Ze3
# =============================================
# 543506856208265200
# ['PROVIDING EXPERIENCES']
# Day 1 - Tuesday December 9, 2014 - Day of Paragard Insertion Two weeks until next period. 9:45 AM :... http://t.co/v449js6EwT
# =============================================
# 728872012572065800
# ['PROVIDING INFORMATIONAL SUPPORT']
# If you would like to have an IUD fitted, kindly watch this short video, as it gives you all the information you... https://t.co/FZT5JzrhFB
# =============================================
# 1325963211405987800
# ['PROVIDING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT']
# my body is literally going to be in so much pain this week😭 i get my teeth pulled tmrw i just got my implant out so my arm is sore n this iud is giving me hell
# =============================================
# 295034447991029760
# ['DISCOURSE']
# I need to take my birth control pill tonight cause I finna turn up . . Lol
# =============================================
# 955816312122601500
# ['DISCOURSE']
# my iud isn't going anywhere uterus so quit being a bitch thank you
# =============================================
# 125234477743087620
# ['PROVIDING INFORMATIONAL SUPPORT']
# On October 15th 1951, the first oral contraceptive pill (steroid hormone, norethindrone) was developed by Carl Djerassi #todaychem #scichat
# =============================================
# 430675592862650400
# ['PROVIDING INFORMATIONAL SUPPORT']
# Blood clot warning for 1m contraceptive pill users | via @Telegraph http://t.co/vSzO6hmSeQ 1/2
# =============================================
# 1165744046133915600
# ['SEEKING INFORMATIONAL SUPPORT']
# Soooooo.. does the IUD not work for some women or did it just not do its job?! https://t.co/hgax0LqlEK
# =============================================
# 1073925477000192000
# ['DISCOURSE']
# Intrusive thoughts are weird, just got a massive urge to rip my contraceptive implant out my arm because ITS RIGHT THERE
# =============================================
# 138742006137622530
# ['DISCOURSE']
# Messing with a IUD is like messing with my child lol i love it to death lol RT @Eribeauty_7: Lmfaooooo #deadRT @fAMBINO_LeFTY: Nigga
# =============================================
# 1125042832723591200
# ['SEEKING INFORMATIONAL SUPPORT']
# #pcosaa #cyster question- I have # pcos and #endometriosis I've had miscarriages with 1 successful pregnancy. I've been on nexplanon for 1.5 years and my husband and I want to try again starting in September.... https://t.co/cywOGI1W1f
# =============================================
# 880269916271726600
# ['SEEKING EXPERIENCES']
# Women with first hand experience getting a copper IUD: Tell me about it, please! Side effects? Love it or hate it?
# =============================================
# 888296554120925200
# ['DISCOURSE', 'PROVIDING INFORMATIONAL SUPPORT']
# CNN: Inmates in one Tennessee county can reduce jail time with birth control -- implant for females, vasectomy for… https://t.co/IbtcLS2ezs
# =============================================
# 725700075767345200
# ['PROVIDING INFORMATIONAL SUPPORT']
# 'Seaweed beads' could replace the contraceptive pill | via @TeleWonderWomen https://t.co/A5CVyCiwzF
# =============================================
# 567664676327002100
# ['DISCOURSE']
# #TopClassActions Calif. Couple Sues Bayer over Mirena IUD Brain Injuries: The post Calif. Couple Sues Bayer ov... http://t.co/z80jSe5YjF
# =============================================
# 237522832408600580
# ['DISCOURSE']
# kennethroary: A male birth-control pill... that doesn't kill sex drive?
# =============================================
# 187804226552999940
# ['PROVIDING EXPERIENCES']
# Sooo idk why but I'm just realizing I haven't had hardly a period in the past few months, I got implanon in my a... http://t.co/DSjyFzeX
# =============================================
# 908684129390268400
# ['DISCOURSE']
# This damn IUD need to get to getting
# =============================================
# 574543272707821600
# ['PROVIDING INFORMATIONAL SUPPORT']
# 14 Ways Birth Control Pills Rob Us Of Our Health... http://t.co/nX651IMdg7
# =============================================
# 1340124594787610600
# ['PROVIDING INFORMATIONAL SUPPORT']
# The pill, IUD and implant are all available in Australia but GPs are over-prescribing one, expert says https://t.co/7ymkQnoUBc
# =============================================
# 243428733967552500
# ['PROVIDING INFORMATIONAL SUPPORT']
# Guys, Take Note: Male Birth Control Pill May Be Ready Soon, Says Texas A&amp;M Prof http://t.co/DKUjVcaX #pharma
# =============================================
# 836672178720505900
# ['PROVIDING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT']
# I made my appointment to possibly get my iud im so excited. I hope this will help me shed this intense weight
# =============================================
# 1221861190797799400
# ['PROVIDING INFORMATIONAL SUPPORT', 'DISCOURSE']
# These are not your #Mother or Grandmothers #IUD’s anymore!!! #women have many forms of #contraceptives at their disposal so that they can choose one that works best for their individual health and needs. But some… https://t.co/WiBHR1lcDp
# =============================================
# 483697468786233340
# ['DISCOURSE']
# I am trying really hard to figure out how my having an IUD infringes on your religious freedom. #HobbyLobby
# =============================================
# 1046501054504792000
# ['DISCOURSE']
# has anyone else noticed that teslas logo is an IUD
# =============================================
# 150024751375581200
# ['DISCOURSE']
# No! Lol RT @KAKAV0YE: @FaithIsHer look what you've done started w/ this #IUD shit
# =============================================
# 663948231911407600
# ['PROVIDING INFORMATIONAL SUPPORT']
# More Women Opt For IUD, Contraceptive Implant For Birth Control: Contraceptive implants and IUDs are very effective… https://t.co/YWLEHHkdSj
# =============================================
# 1227584349270421500
# ['PROVIDING INFORMATIONAL SUPPORT']
# Contraceptive pill: interrupted supply is a bigger problem than it might appear https://t.co/pY23TeG8EU via @ConversationUK
# =============================================
# 684933166855880700
# ['PROVIDING INFORMATIONAL SUPPORT']
# No link between contraceptive pill and birth defects: study: PARIS: Oral contraceptives taken ju... https://t.co/GSrOBBSoxH &lt;--Full Story
# =============================================
# 200639282350784500
# ['PROVIDING INFORMATIONAL SUPPORT']
# IUD use tied to modest weight loss http://t.co/2UEWoCrc
# =============================================
# 660208958129344500
# ['SEEKING EXPERIENCES']
# Do any women use Nexplanon?
# =============================================
# 1237586602890653700
# ['DISCOURSE', 'SEEKING EMOTIONAL SUPPORT']
# That voice in the back of my head that likes babies is trying to convince me that when my nexplanon gets removed in 2021 that I will definitely want another kid. Legit. Shoot me before I multiply 😂
# =============================================
# 961048239897067500
# ['DISCOURSE']
# GESTATED SUICIDE: two thoughts from my view; 1. LIFE takes place as soon as the sperm and egg connect. YEARS ago Religous Commuities in somewhere, fought against the BIRTH CONTROL PILL. I don't agree with this thinking TM. IF the egg is 'Prevented' from being fertilized, it's ok
# =============================================
# 768944816659071000
# ['PROVIDING EXPERIENCES', 'PROVIDING INFORMATIONAL SUPPORT']
# If any of my friends come to me abt birth control, I ALWAYS ALWAYS ALWAYS recommend the IUD. Best thing ever.
# =============================================
# 980961230788616200
# ['PROVIDING EXPERIENCES']
# I’m crampy today so it’s either my vagina is expelling my IUD, or my IUD has migrated, or I’m ovulating, or my body’s just saying fuck you you’re not allowed to forget you can bear children even if you don’t want to. It’s a toss up, really.
# =============================================
# 1231396143508136000
# ['SEEKING EXPERIENCES']
# If you on the birth control pill plsss dm me
# =============================================
# 1238838711799906300
# ['DISCOURSE']
# Md. lawmaker proposes bill after teen given contraception implant in school https://t.co/Ez2MRt15Mx
# =============================================
# 1123922963131183100
# ['PROVIDING EXPERIENCES', 'DISCOURSE']
# I went through an IUD stuck in my side wall, and shots in my ass every damn three months. So much pain with different birth control and men get gel? lmao https://t.co/ktZeie7QKl
# =============================================
# 943617230658592800
# ['PROVIDING INFORMATIONAL SUPPORT']
# #Weightgain is one of the most common complaints associted with #birthcontrol. Learn how to keep the pounds off: https://t.co/QAX7QDjxGq Whether you choose IUD, pills, implants, or other alternatives, Dr. Yu will take care of your #contraception needs. https://t.co/iunsXHPf4x https://t.co/j5SwMgLNGv
# =============================================
# 13553286252
# ['PROVIDING INFORMATIONAL SUPPORT']
# FDA approves new birth control pill Natazia http://bit.ly/cqgAhm
# =============================================
# 1143746162471645200
# ['PROVIDING EXPERIENCES']
# it’s not the same experience for everyone but the copper iud for me is good. no hormones and Testosterone keeps my period away. and i won’t get pregnant. i gotta be diligent abt my T shot and not miss any, bc i did have my period come back in Feb. :/
# =============================================
# 1202576642729750500
# ['PROVIDING INFORMATIONAL SUPPORT']
# Delighted by this particular application of Traverso’s extended release oral delivery technology. | A once-a-month oral contraceptive | Science Translational Medicine https://t.co/r7asaDsukK
# =============================================
# 1115072774203158500
# ['PROVIDING INFORMATIONAL SUPPORT']
# Concerns, downsides, and how it gets in there: Here's what to know about IUDs https://t.co/W51YzROkO5 https://t.co/uqD1Fh50Qb
# =============================================
# 1259335784437604400
# ['PROVIDING EXPERIENCES']
# IUD insertion is the most pain I have ever been in in my entire goddamn life https://t.co/k99USJHdhM
# =============================================
# 164664338064482300
# ['PROVIDING INFORMATIONAL SUPPORT']
# http://t.co/cilg8rAc Contraceptive pill recalled in US http://t.co/ztYgpzD0 http://t.co/cilg8rAc
# =============================================
# 1201959436165746700
# ['DISCOURSE']
# graduating from iub in ‘23, graduating from my iud in ‘24
# =============================================
# 709291386168746000
# ['PROVIDING INFORMATIONAL SUPPORT']
# Medical News Today: Birth control pill for men steps closer: There are a number of major hurdles scientists ne... https://t.co/xV2O1YTypu
# =============================================
# 647790064672477200
# ['PROVIDING EXPERIENCES']
# I've had more orgasms in the last month since i got my IUD out than I had in the 6 months before.
# =============================================
# 1104083124697395200
# ['DISCOURSE']
# Nexplanon is the WORST birth control and I am so so so sorry if I ever recommended it to you.
# =============================================
# 1020692418700763100
# ['PROVIDING INFORMATIONAL SUPPORT']
# How long can you safely take the contraceptive pill for? #WomenNowForum - Ask any question absolutely anonymously and get answered by community experts and other members.. https://t.co/KBk7DTOYI5
# =============================================
# 438520310938501100
# ['DISCOURSE']
# Lol oh. Well when I get back in the gym I'll send u my workout I make RT @FormerlyYouKnow: @damnit_mannn I have no kids .. Got a IUD
# =============================================
# 1155003737707954200
# ['DISCOURSE']
# I didnt get this birth control implant in my arm just for you to not text back bitch cum in me
# =============================================
# 818741018686263300
# ['PROVIDING INFORMATIONAL SUPPORT']
# I liked a @YouTube video https://t.co/Mh5uFRt0pJ Does The Birth Control Pill Cause Depression?
# =============================================
# 78328065104674820
# ['SEEKING INFORMATIONAL SUPPORT']
# Someone should explain this Plan B contraceptive pill to me. It doesn't terminate or abort any pregnancy. So what does it do? #antiabortion
# =============================================
# 236210298934132740
# ['DISCOURSE']
# Male Birth Control Pill coming soon! Gentleman tell what you think? http://t.co/TRc8VOzd #malebirthcontrol #themancaveprohq
# =============================================
# 1314681675062878200
# ['PROVIDING EXPERIENCES']
# They were the only ones who said yes to removing my problematic IUD for FREE. when I was between insurances. They saved me big time. They also offer STD testing https://t.co/xYvfAyz5yY
# =============================================
# 408666838932152300
# ['PROVIDING INFORMATIONAL SUPPORT']
# Australian Researchers Developing Male Birth Control Pill With Virtually No Side Effects http://t.co/UeQksKEHuj
# =============================================
# 647414742869389300
# ['DISCOURSE', 'PROVIDING INFORMATIONAL SUPPORT']
# NY Business F.D.A. Panel Weighs Complaints on Essure Contraceptive Implant: The public meeting was called afte... http://t.co/KHyJEup5yv
# =============================================
# 1129645295275585500
# ['SEEKING INFORMATIONAL SUPPORT']
# Is it possible for a minor to get an IUD without their parents knowing about it if they're on their parent's insurance? medics https://t.co/NwKLtMY4Kj https://t.co/bOjeWaVWok
# =============================================
# 136313428733202430
# ['PROVIDING INFORMATIONAL SUPPORT']
# Another instance that there is no short cut in life: Is oral contraceptive pill fuelling prostate cancer? http://t.co/ycHY4aLA
# =============================================
# 259003689614852100
# ['PROVIDING INFORMATIONAL SUPPORT']
# IUDs Increasingly Popular Form of Birth Control: While the use of long-acting intrauterine devices (IUDs) is inc... http://t.co/CRwdWBgv
# =============================================
# 1245528059761119200
# ['DISCOURSE']
# After a nigga get done fucking you, do he be telling you to take yo birth control pill? I wanna know something.. 🤣🤣🤣🤣🤔
# =============================================
# 943460509273219100
# ['PROVIDING INFORMATIONAL SUPPORT']
# “At a time when the popularity of the birth control pill is waning, the European health regulator has just approved a contraceptive app that pairs technology with the age-old rhythm method.” #LifeSci4X03 https://t.co/yyS7Z28TLQ
# =============================================
# 849446577936752600
# ['DISCOURSE']
# IS THERE AN IUD THAT CAN STOP THE IMAGE OF YOU AND MEEE
# =============================================
# 383544680647901200
# ['SEEKING INFORMATIONAL SUPPORT']
# Can you have Implanon changed early? I know you can have it taken out, but will they replace it if it's not 3 years?
# =============================================
# 304707700556693500
# ['PROVIDING INFORMATIONAL SUPPORT']
# #health Most women misunderstand IUD birth control: NEW YORK (Reuters Health) - In a new survey, most women ha... http://t.co/qOoOkbM4d1
# =============================================
# 308442005975998460
# ['DISCOURSE']
# Kyleena is messing up.
# =============================================
# 726995085477310500
# ['DISCOURSE']
# accidentally dropped my birth control pill in the trash yesterday so my mood is fucked to shit lmao
# =============================================
# 342298384817860600
# ['DISCOURSE']
# I've spent my afternoon.. Crushing up the contraceptive pill and putting them in 17 bamboo plants #imgettingpaidforthis 😶
# =============================================
# 1023664593221165000
# ['DISCOURSE']
# Yo shorty at the bbq said she take her birth control pill with a shot of brugal 🇩🇴🇩🇴🇩🇴🇩🇴
# =============================================
# 1053950548863582200
# ['PROVIDING INFORMATIONAL SUPPORT']
# Contraceptive pill available over the counter for Victorian women under Coalition plan https://t.co/RGsbSeSkzn #doctorsjobsnz
# =============================================
# 905056651593568300
# ['PROVIDING INFORMATIONAL SUPPORT']
# Currently Reading: New article shows immediate placement of hormonal IUD is not inferior to delayed placement... https://t.co/kFiAOZn6Dq
# =============================================
# 16221698519
# ['PROVIDING INFORMATIONAL SUPPORT']
# newStream ©: Christiane Northrup, MD: Ella, Week After Birth Control Pill: A Boon for European Women, But Will It... http://huff.to/9x5UV8
# =============================================
# 416825008624001000
# ['PROVIDING INFORMATIONAL SUPPORT']
# This site will give information about Mirena IUD. http://t.co/W48F57Iwyo
# =============================================
# 268132636734677000
# ['PROVIDING INFORMATIONAL SUPPORT']
# Tags: Contraceptive pills, Dementia, Oestrogen. Contraceptive pills can help stave off dementia London:... http://t.co/51hfGDw8
# =============================================
# 1200026120969580500
# ['PROVIDING INFORMATIONAL SUPPORT']
# Gynaecologists debunk myths surrounding the contraceptive pill acne, weight gain, moodiness, cancer - Daily Mail https://t.co/7cWLOibT4W
# =============================================
# 913813680206209000
# ['PROVIDING EXPERIENCES']
# I got an IUD yesterday and I feel like steaming shit
# =============================================
# 326339518280126460
# ['DISCOURSE']
# Whenever you're having a bad day just remember- your human didn't name you after an IUD that was later recalled #Mirena
# =============================================
# 990963059417059300
# ['PROVIDING EXPERIENCES']
# Wow I have the iud and now I’m ready to take this shit out because no ma’am I’m not going through that shit .
# =============================================
# 1121327254896648200
# ['DISCOURSE']
# random thought (okay fine, fueled by free wine and in-flight wifi) but who else starts to have a straight up fucking stroke when they realize it's 2019 and there is no male birth control pill
# =============================================
# 25692748551
# ['PROVIDING INFORMATIONAL SUPPORT']
# Folate-Fortified Birth Control Pill Approved: The Yaz product is approved for preventing pregnancy and treating sy... http://bit.ly/cCzMpX
# =============================================
# 882016963123449900
# ['DISCOURSE']
# Fish Becoming Transgender From Contraceptive Pill Chemicals Being Flushed Down Household Drains https://t.co/JDMU6CTl6A #news #health
# =============================================
# 1169669179466834000
# ['PROVIDING EXPERIENCES']
# Hey Lila Rose, I just wanted to inform you that I went to my OBGYN for my annual check up and my doctor said my uterus and IUD are working harmoniously. You’re welcome. https://t.co/XTNvY4ublW
# =============================================
# 829188935167385600
# ['PROVIDING INFORMATIONAL SUPPORT', 'DISCOURSE']
# This is the wave! RT @TheCut: This new male birth-control method is like an IUD for guys https://t.co/PtqRNq3O2q
# =============================================
# 646021814234312700
# ['PROVIDING INFORMATIONAL SUPPORT']
# New post: "FDA experts to review safety of Essure birth control implant" http://t.co/5B7wxKs5MX
# =============================================
# 1164552022802272300
# ['SEEKING EXPERIENCES']
# Any other uterus equipped humans with an IUD get horny-monal? I don't have a period anymore so it's not that. But on occasion I'll get very grumpy, hungry, and insatiably horny. No? Just me? Okay.
# =============================================
# 735009829652140000
# ['PROVIDING INFORMATIONAL SUPPORT']
# New contraceptive pill takers aren't being told about the higher risk of blood clots … https://t.co/UYAwzYvcrM
# =============================================
# 671585365573152800
# ['DISCOURSE']
# IUD use attracts new opposition from anti-abortion groups
# =============================================
# 722787215559012400
# ['PROVIDING INFORMATIONAL SUPPORT']
# Why is it so difficult to make a contraceptive pill for men? https://t.co/YmsbIVmwM1 https://t.co/w79bsPWTi9
# =============================================
# 237677659985952770
# ['DISCOURSE']
# RT "@Fun: A birth control pill for men.. It makes more sense to pull the bullets out of a gun than to wear a bulletproof vest."
# =============================================
# 778021276854132700
# ['PROVIDING INFORMATIONAL SUPPORT']
# Birth control's got a lot! Here's a roundup of the birth control pills that are available in the US: https://t.co/TNQfTuCpMP
# =============================================
# 1266333099463512000
# ['DISCOURSE']
# Anyone else always think of an IUD when they look at the #Tesla logo? 🤔 #orisitjustme
# =============================================
# 1241409004921852000
# ['SEEKING EMOTIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# heres a summary of how my week is going: my boyfriend tells me he thinks it better if we split, my contracted hours at work are cut, i am told i can't have my iud re-fitted or removed because of the virus, my dad has told me hes coughed up blood, i gained 4lbs👍👍👍
# =============================================
# 930616593339568100
# ['PROVIDING INFORMATIONAL SUPPORT']
# What makes the Liletta IUD different from Mirena? @Bedsider https://t.co/Juj5GpVVSX
# =============================================
# 1110715352709623800
# ['DISCOURSE']
# I would NEVER take a male birth control pill. EVER. https://t.co/FxbCki5uq8
# =============================================
# 1273989375202861000
# ['DISCOURSE', 'PROVIDING EXPERIENCES']
# I’m like 99% positive my IuD is trying to kill me
# =============================================
# 368925334474723300
# ['DISCOURSE']
# the fucking CREATOR of the birth control pill is a professor at Stanford. my goodness
# =============================================
# 161793791773253630
# ['PROVIDING INFORMATIONAL SUPPORT']
# What Are The Chances Of Getting Pregnant With An Iud In http://t.co/xy6POi8i
# =============================================
# 220005325330333700
# ['PROVIDING INFORMATIONAL SUPPORT']
# RT @passport_cutty: I forgot you can't get the IUD if you don't have any kids.* yes you can. I have the 5 yr IUD and no kids :)
# =============================================
# 164670760080769020
# ['PROVIDING INFORMATIONAL SUPPORT']
# Contraceptive pill recalled in US: Around one million packets of birth control tablets are being recalled in the... http://t.co/y4BxoLDA
# =============================================
# 1286657610062745600
# ['PROVIDING EXPERIENCES', 'PROVIDING INFORMATIONAL SUPPORT']
# Is your gyno saying that in the 57 yrs since legal, that she has not discovered other methods of birth control besides medication, to give to gals who get depressed? My daughter is a depressive, has an IUD. There are implants for the arm, etc. Ask her. https://t.co/nMHFJeakY8
# =============================================
# 418554767502094340
# ['PROVIDING INFORMATIONAL SUPPORT']
# Contraceptive Pill Developing Breast Cancer http://t.co/medioqM4Fn
# =============================================
# 1092961531401187300
# ['DISCOURSE']
# IUD and implant insertions jumped 22% after Trump's election in 2016, and it may not be a coincidence https://t.co/0b9sfZSKJr https://t.co/sT56pe2PWU
# =============================================
# 1310571088686899200
# ['PROVIDING EXPERIENCES']
# Working half a day today because I woke up with a migraine and period cramps from hell. Getting a iud was a good idea but holy fuck do these cramps hurt 😭
# =============================================
# 1305054620100616200
# ['DISCOURSE']
# *schedules IUD appointment for next week*
# =============================================
# 989176529711194100
# ['DISCOURSE']
# Bedsider: RT vicbaer: You never realize how fast a month goes by until you’re taking your last birth control pill in the pack
# =============================================
# 749250024429813800
# ['SEEKING INFORMATIONAL SUPPORT']
# Idk how to ask the medical dude for a contraceptive pill. I heard it helps with cramps.
# =============================================
# 36968478040662020
# ['DISCOURSE']
# #thanksppfa for helping my husband help me get through my IUD insertion.
# =============================================
# 1193982135046213600
# ['DISCOURSE', 'PROVIDING INFORMATIONAL SUPPORT']
# Mom loses ovaries, uterus and toes after IUD ends up in stomach https://t.co/FEK62ynWwn
# =============================================
# 689099433695424500
# ['PROVIDING INFORMATIONAL SUPPORT']
# #news Thinking of Getting an IUD? Here's What to Expect - https://t.co/y8mASRa9dS
# =============================================
# 132308461177413630
# ['DISCOURSE']
# “@iSpeakComedy: What's a birth control pill? : It's the second best thing a woman can put in her mouth to prevent pregnancy.” HEHEHEH.
# =============================================
# 1146888835206434800
# ['SEEKING EXPERIENCES']
# Does anyone have an IUD? Have y’all ever couldn’t find your strings? Google is scaring me 😒😩
# =============================================
# 633553996599291900
# ['DISCOURSE', 'PROVIDING INFORMATIONAL SUPPORT']
# #California #Job Copper Intrauterine Device (IUD) Study -- Receive up to $800: Our non-profit research group i... http://t.co/PU98vd44Ks
# =============================================
# 6843966177
# ['DISCOURSE']
# RT @OTOOLEFAN Always laugh when I hear the term "oral contraception." Is that when a woman says "No."? (I thought it was a BJ)
# =============================================
# 803761473537409000
# ['DISCOURSE']
# "With my questions answered, I chose the IUD because it’s so effective." #8 reason to support PPDE on #GivingTuesday https://t.co/8O9USquOsd https://t.co/lz78V0khyR
# =============================================
# 296112566458011650
# ['DISCOURSE']
# 👀👀👀 RT @KHOU: Birth control pill for men? Researchers say yes: What would you say to a (cont) http://t.co/N4oRZzsQ
# =============================================
# 1092790518747201500
# ['PROVIDING EXPERIENCES']
# Hi I love my iud. I used to have cramps that would incapacitate me for hours at a time, i even passed out once or twice on the bathroom floor. Now? Cramps? Aunt Flo? I haven’t seen her in a loooong time https://t.co/F9OIvVk3bg
# =============================================
# 1044621052813295600
# ['DISCOURSE']
# You ever went so deep in a girl that her IUD birth control pokes your dick.
# =============================================
# 1299302125382635500
# ['SEEKING EMOTIONAL SUPPORT']
# Getting my nexplanon replaced 🥴 I’m so nervous
# =============================================
# 990383424304279600
# ['PROVIDING INFORMATIONAL SUPPORT']
# I liked a @YouTube video https://t.co/9iViQPKBiS Why Is It So Hard to Make a Male Birth Control Pill?
# =============================================
# 85945525165228030
# ['PROVIDING EXPERIENCES']
# RT @Lucy_Lu11 @YoungHarlem__10 ctfuuuu neither I got that iud put in and my stomachs been fukn up..wats iud??
# =============================================
# 630557087769100300
# ['PROVIDING INFORMATIONAL SUPPORT']
# Contraceptive pill cuts uterine cancer risk as benefits of drug outweigh risks http://t.co/BZOQ9SXcwd
# =============================================
# 127364992021430270
# ['SEEKING EXPERIENCES']
# Question for the ladies (health feature (research): How do you find the procedure for getting the contraceptive pill from your GP?
# =============================================
# 564815452539322400
# ['PROVIDING EXPERIENCES', 'DISCOURSE']
# Going to get my IUD taken out... If this hurts as bad as putting it in I will no longer be here k thanks
# =============================================
# 1098949375273979900
# ['DISCOURSE']
# lmao i’m in the bathroom and these girls are flipping out bc one of their friends got a the birth control implant 💀
# =============================================
# 421698798851604500
# ['PROVIDING EXPERIENCES']
# Ugh! It's not like I'm here for a huge appointment. I just want my effing iud checked so I can get on with my baby-free life!
# =============================================
# 305006771410456600
# ['PROVIDING INFORMATIONAL SUPPORT']
# What women need to know about the new IUD http://t.co/EKJjrtSWTL via @todayshowhealth
# =============================================
# 403564435349848060
# ['DISCOURSE']
# IUD RT @ImSo_ThickWitIt: My stomach hurt RT @HezSoKrayzee: RT if you ever fucked the NuvaRing out a chick"
# =============================================
# 508063879277326340
# ['DISCOURSE']
# WTF IS THAT? RT @ThisIs_Eve: VICKtorious_1 no Team Implanon 🙌 😉
# =============================================
# 703146236266721300
# ['DISCOURSE']
# UPDATED: #Catholic school hosting #PP doctor, uses #Rosary with IUD 2 advertise. So #SpeakOut! https://t.co/UF29T1scgb via @Students4LifeHQ
# =============================================
# 157156497187553280
# ['PROVIDING INFORMATIONAL SUPPORT']
# “@IdaEsquivelXo: Ladies please remember take your birth control pill & make sure that dude wears a condom at all times!!!”
# =============================================

# %%
final_dicts = []
for _id, _labels in id_majority_labels_dict.items():
    for _label in _labels:
        final_dicts.append({'ID': _id,
                            'Label': _label,
                            'Text': id_text_dict[_id],
                            'Source': 'twitter-posts',
                            'Decision': 'two or more'})
final_df = pd.DataFrame(final_dicts)
final_df.to_csv(data_directory_path + '/labeling/majority.twitter_posts.csv')

# %% [markdown]
# <br><br>
#
# # Get majority labels for TWITTER COMMENTS

# %%
target_df = combined_df[combined_df['Source'] == 'twitter-replies']

# %%
id_text_dict = {}
for i, r in target_df.iterrows():
    id_text_dict[r['ID']] = r['Text']
len(id_text_dict)
# Out:
# 502

# %%
ids_labeled_by_roz = list(set([r['ID'] for i, r in target_df.iterrows() if r['Labeler'] == 'Roz']))
len(ids_labeled_by_roz)
# Out:
# 284

# %%
id_labeler_labels_dict = defaultdict(lambda: defaultdict(list))
for i, r in target_df.iterrows():
    if r['ID'] in ids_labeled_by_roz:
        id_labeler_labels_dict[r['ID']][r['Labeler']].append(r['Label'])
len(id_labeler_labels_dict)
# Out:
# 284

# %%
id_majority_labels_dict = {}
for _id, _labeler_labels_dict in id_labeler_labels_dict.items():
    _label_count_dict = defaultdict(int)
    for _labeler, _labels in _labeler_labels_dict.items():
        for _label in _labels:
            _label_count_dict[_label] += 1
    _majority_labels = [_label for _label, _count in _label_count_dict.items() if _count >= 2]
    if _majority_labels:
        id_majority_labels_dict[_id] = _majority_labels
len(id_majority_labels_dict)
# Out:
# 283

# %%
for _id, _labels in id_majority_labels_dict.items():
    print(_id)
    print(_labels)
    print(id_text_dict[_id])
    print('=============================================')
# Out:
# 1306801969118445600
# ['PROVIDING EXPERIENCES']
# @roxiqt Had severe panic attacks after getting an IUD so I had to have it removed, was on hormonal bc for so long that I had swelling of the brain, and now I get a shot every 3 months so a man can cum in me… fuck being female
# =============================================
# 473233002987020300
# ['PROVIDING INFORMATIONAL SUPPORT']
# @NinoDemayo plan b is hormones, usually a higher dosage than in birth control, if it's toxic after a while birth control pill wld b deadly
# =============================================
# 1160981232349528000
# ['PROVIDING EXPERIENCES']
# @IvetteBrianna_ it’s soo convenient! i’ve been on it for a few months now. it’s called the depo shot. i didn’t want an IUD or implant and i’m too forgetful for the pills lol
# =============================================
# 664898788327206900
# ['DISCOURSE']
# .@absmom1 I do know that. You cannot force every woman in the country to take a hormonal pill/get an IUD against her will or her family's
# =============================================
# 1223701281417695200
# ['PROVIDING EXPERIENCES']
# Anyways, I’m coming up on my IUD’s third birthday next month and I’d like to report that I have suffered no complications, have had zero babies and I am not dead. Couldn’t recommend it more
# =============================================
# 916797265767026700
# ['PROVIDING EXPERIENCES']
# Like, my coworker after years of trying finally got pregnant, I was so happy and excited for her It motivated me to get an IUD
# =============================================
# 555128017270210560
# ['PROVIDING EXPERIENCES']
# “@kay_slays: Just got my IUD inserted and I am ready to get the club shot up. #tmi #dontcare #ifeelfree” lmfaooooooooooooooooooo
# =============================================
# 1232231832881635300
# ['PROVIDING EXPERIENCES', 'PROVIDING INFORMATIONAL SUPPORT']
# @tugengirl An IUD at Marie stops is 1500 I found out after I had gone to agha khan and the price was ridiculous
# =============================================
# 577542545321771000
# ['DISCOURSE']
# @TeamShieldBSC @BlueShieldCA Paragard should be defined as a prescription like Mirena not a medical device! Not fair to pts who need it
# =============================================
# 1333193379233017900
# ['PROVIDING EXPERIENCES']
# @MonashUni @Monash_FMNHS @Danielle_Mazza @triplejHack More “people”?!? My partner tried an IUD, he didn’t like it.
# =============================================
# 1225219656325177300
# ['PROVIDING EXPERIENCES']
# @SENTfrm_heaven That’s how the pill did me. Terrible mood swings too. I have the Kyleena &amp; I love it. I haven’t had any issues. It’s all really unhealthy, truthfully.
# =============================================
# 1020491058008842200
# ['DISCOURSE']
# @svndrvg_ Wishing twins in you, you hyper ovulate after the IUD
# =============================================
# 434504395095420900
# ['PROVIDING EXPERIENCES']
# @sarcasticpandas like u know how when u go to a dentist and they can take xrays &amp; see through ur mouth? He takes pics of my IUD &amp; Shows me
# =============================================
# 1017161722170245100
# ['PROVIDING EXPERIENCES', 'DISCOURSE']
# @kirstin_bond @e_kenzzz Oh fam I could pretty much make commission off of how much I love my IUD. Like anything, people more often complain about things than talking about good things 🤷🏼‍♀️
# =============================================
# 3481418149
# ['PROVIDING EXPERIENCES', 'PROVIDING EMOTIONAL SUPPORT']
# @Okeyj I feel your Grrr, lol. I don't miss Aunt flo..Thank goodness for IUD's
# =============================================
# 1031741418858078200
# ['PROVIDING EXPERIENCES']
# @catholicnun420 birth control pill &amp; IUD both fucked me up in uniquely shitty ways
# =============================================
# 1277011582267129900
# ['PROVIDING INFORMATIONAL SUPPORT']
# @Deshagaston @ClassyEquestria But the other options are either a shot or the IUD and both are a huge no
# =============================================
# 1232575979555606500
# ['PROVIDING INFORMATIONAL SUPPORT']
# @torrensside @WilTalbert @Asher_Wolf The contraceptive pill is free in the UK.
# =============================================
# 987416394970083300
# ['DISCOURSE']
# @Ask__me__why @NataliaAntonova Why? Except in cases of rape(which is a crime), the woman consented to the act that produced the child. Shouldn't we also say all women should have Nexplanon injected compulsorily if you want to force vasectomies? Also, what if I don't want my genitals mutilated?
# =============================================
# 858832058172325900
# ['SEEKING EXPERIENCES']
# @omfgwhateveretc Ok I might enquire. Do you have the IUD that releases hormones?
# =============================================
# 402729176991817700
# ['PROVIDING INFORMATIONAL SUPPORT']
# Long-term contraceptive pill use doubles glaucoma risk, research finds http://t.co/f5qDtKO1JL via @mailandguardian
# =============================================
# 1256654329139695600
# ['PROVIDING EXPERIENCES']
# @Amy_Hupe I was asked if I was on the pill (which I was). She told me to get off of it immediately because it can cause blood clots which is dangerous for migraine-prone people. So I stopped the pill. Got an IUD instead. And never had a headache like that again.
# =============================================
# 1262757197978599400
# ['PROVIDING INFORMATIONAL SUPPORT']
# @SotheranL @Liz_Chiarello @UCSDSkaggsSOP In addition, there’s a newer emergency contraceptive pill ella, containing ulipristal acetate. This one is more effective in some cases (higher body weight, longer time since sex) but available by prescription only. Trained California pharmacists can prescribe this!
# =============================================
# 1280887584269500400
# ['SEEKING EMOTIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# @saadiegu it’s so annoying!!! my nexplanon is a really good fit for me and i have had so many girls be like “no it’s bad” like okay i’m sure it was bad,, FOR YOU and that sucks and i’m sorry but i’m gunna keep doing what works for me??
# =============================================
# 723516953072115700
# ['PROVIDING EXPERIENCES', 'DISCOURSE']
# @bonster617 @boneshamiltonsc I don't agree with the IUD either, I'm perfectly fine with condoms.
# =============================================
# 1334665608177348600
# ['PROVIDING EXPERIENCES']
# @tbydaydreamin I have it scheduled cuz stupid acne pills who also work as a birth control pill 💀
# =============================================
# 1189995998443196400
# ['PROVIDING EXPERIENCES']
# @MK_McMaster @aBigMess you are not the only person i know who's done this but SHIT, i had an iud out last friday and my guts STILL hurt
# =============================================
# 1246133706160390100
# ['PROVIDING EXPERIENCES']
# @rachelwalexande it is!!! also, fwiw, mine definitely got thicker after I got my first IUD. But it's also slowly been getting thicker for... forever, so it's hard to know who to blame (thank???)
# =============================================
# 35551307871813630
# ['SEEKING INFORMATIONAL SUPPORT']
# @iAmMissKarma whats IUD?
# =============================================
# 401645920002916350
# ['DISCOURSE']
# @rmi Yeeeeeeeeeep. Too young to know what an IUD was (the word "insertion" was sufficient!) but goddamn that was a wake-up moment in my life
# =============================================
# 957870938338611200
# ['DISCOURSE']
# @FireCap203 @SlythSeeker2017 @DaddyLou13 @JohnRowlette @Alyssa_Milano Where on the internet can you get an iud inserted? Sit the fuck down if you don't know what you're talking about.
# =============================================
# 1028420562421469200
# ['PROVIDING INFORMATIONAL SUPPORT', 'DISCOURSE']
# &amp; Margaret Sanger... someone else I'd never heard of lived a very fulfilling life. Eventually seeing the sum total of her dreams in the contraception pill! Remarkable considering when she came of age contraception was illegal! https://t.co/uCSyC9UwUe
# =============================================
# 1264215447353737200
# ['PROVIDING EXPERIENCES']
# @CassandraTrill I bled constantly with an IUD.
# =============================================
# 1152384546077323300
# ['DISCOURSE']
# @Miss_Leeze @Ofthelot @gordon_struth @MumofC @RedQueenRising @maitlis If a man (AMAB - ie not a trans man) says to an obgyn “I would like an IUD”, do you think the obgyn should have to insert that medical device in him?
# =============================================
# 1117126473071177700
# ['DISCOURSE', 'PROVIDING EXPERIENCES']
# @politasports2 @MiserMayor @1963belinda @NBCNews Oh, because pulling out works? Lol I said 15-50$. Are you saying that everyone is insured? What is the deductible? I’m in Canada, an IUD is about 400$. In the US, 0-1300$. Again, an IUD is not for everyone, I can’t have one, it releases hormones that could make me have a stroke.
# =============================================
# 1010606374550687700
# ['PROVIDING EXPERIENCES']
# @maceyyperryyyy I think mine is a combination of stress and I have the nexplanon birth control. Although I don’t have my period anymore It’s giving me bad acne. I pick at my skin also 😅
# =============================================
# 1195888882048471000
# ['PROVIDING EXPERIENCES']
# @BirthControlDoc @JFacog My gyne did mention that he touched the top of my uterus, so I guess that was it. I want an oopherectomy due to genetic risk of ovarian cancer, so hoping I can get one and remove IUD while I'm under. I have stable mets breast cancer so low priority right now though.
# =============================================
# 1196486561459626000
# ['PROVIDING INFORMATIONAL SUPPORT']
# In this instance, the hospital's policies would have allowed the removal of a dislodged IUD, but the doctor thought the policies wouldn't, and refused care. https://t.co/BWt9gEkHQy
# =============================================
# 319863530545365000
# ['PROVIDING INFORMATIONAL SUPPORT']
# @Halawia Also when you're feeling better, remind me to tell you about implanon, if you don't know about it already.
# =============================================
# 1318968136062791700
# ['DISCOURSE']
# @_j_cum Oh absolutely but I’d also be so paranoid, she got it tangled in her fucking IUD string 🥵
# =============================================
# 1192228267388014600
# ['PROVIDING EXPERIENCES']
# @oxirb @valexyagomez My IUD hurt really bad to put in though &amp; also to replace. Just an FYI &amp; something you have to go through like getting a tattoo. It hurts but it’s worth it lol the one I use is good for 3 years
# =============================================
# 953391253093314600
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# @yasssqueeen @somexsangrybw @bellofthebpoint Most cups hold like, twice as much as a Super tampon. And if they're inserted properly, they have to be REALLY full to leak, because it sort of forms a seal inside you to keep everything in place. Like, when I had the copper IUD I had some times where I went to change it and it
# =============================================
# 1215842598117499000
# ['PROVIDING EXPERIENCES']
# @MavenOfMayhem I love having an iud. the ‘it’s so painful’ horror stories are incredibly misleading imo. The insertion doesn’t hurt one bit. I took Advil the first time &amp; it didn’t hurt, the second time I didn’t take an Advil &amp; I was still fine. my periods are lighter &amp; shorter w/the mirena
# =============================================
# 1012097892503474200
# ['PROVIDING INFORMATIONAL SUPPORT']
# @_biscottipippen @PPFA Long acting reversible contraception implanted in your arm instead of an IUD, lasts for 3 years. Learned how to place them in residency to try and stay out of the teen pregnancy business. https://t.co/ai0aG6vekD
# =============================================
# 1204498214407114800
# ['PROVIDING EXPERIENCES', 'DISCOURSE']
# @riathepixie @PPFA MY SAME POINT ! on this IUD till the day I die lmao
# =============================================
# 1285924521258688500
# ['PROVIDING EXPERIENCES']
# @MamaDoctorJones Agreed. Luckily, where I live we have a family planning clinic and it’s without any appointment. It’s where I got my IUD installed (almost fainted due to the pain too 😩) then removed. It should be like that everywhere at least.
# =============================================
# 506864575967289340
# ['DISCOURSE']
# Pay my student loans. “@AsaAkira: Cum in my pussy when I've forgotten to take my birth control pill for a week straight so I know it's real”
# =============================================
# 1309676603652399000
# ['PROVIDING EXPERIENCES', 'DISCOURSE']
# @LeaverBeee @DrJenGunter I destroyed more underwear after turning 35 than I ever did as a clueless menarche tween. #TeamMe peeps have been calling it “Operation YEETerus.” It tried to eat the last IUD. 😡
# =============================================
# 807416451879440400
# ['PROVIDING EXPERIENCES']
# @viri_estrada paraguard. It's an IUD😬 I've had 2. The Mirena &amp; this one but I didn't like the Mirena at alll
# =============================================
# 63386560174891010
# ['DISCOURSE', 'PROVIDING INFORMATIONAL SUPPORT']
# @RealAge Alot of meds r in our water supply. Many should not be flushed down toilet. From birth control pill we have hormones in our water.
# =============================================
# 1259415646774923300
# ['PROVIDING EXPERIENCES']
# just to confirm i'm still pro iud, insertion sucks n cramps can b worsened but one of the best things i've done for my health overall is ditching the pill x
# =============================================
# 1334368472265068500
# ['DISCOURSE']
# @LikeTheMountain Yes but IUD should be free to any gal who wants one.
# =============================================
# 24402675083
# ['DISCOURSE']
# @MsForbiddenC Lol mad woman, u better be on that birth control pill
# =============================================
# 987878921730449400
# ['SEEKING EMOTIONAL SUPPORT']
# @PikaChulita Paragard is the only one and Idk because I read a lot of bad reviews so I'm scared lol
# =============================================
# 349406774643789800
# ['DISCOURSE']
# @wmyeoh or the IUD against the overall modern method rate. It's rather distressing. /nerdy contraceptive prevalence data sets.
# =============================================
# 1184320083893444600
# ['PROVIDING EXPERIENCES']
# @lyciafaith The IUD makes me wanna cry once a month but other than that I like it! The insertion was hell though
# =============================================
# 359379763728621600
# ['PROVIDING EXPERIENCES']
# @lexxaye That's why I'm looking at Implanon. I suck at remembering pills too.
# =============================================
# 4502098448228354
# ['PROVIDING EXPERIENCES']
# @Winchesterific Well I had an IUD put in in oct so I thought no more...but oh well..what do you do.
# =============================================
# 483618075741147140
# ['DISCOURSE']
# @missafayres This is a really great comment. I couldn't have said it better. Hobby Lobby is even against IUD's!!!!
# =============================================
# 202446977382875140
# ['PROVIDING INFORMATIONAL SUPPORT']
# @FDA issues #birth-control pill safety warning: http://t.co/7TJuNCcf
# =============================================
# 1132821475650691100
# ['PROVIDING EXPERIENCES']
# @epictetus_says I'm 40. I've known since I was 20 that I don't want kids. Haven't wavered for a moment in 20 years. They don't want to perform elective surgery for "no reason". Even had a Catholic health system push back on long term BC like IUD or implant. Luckily I found a secular OB for that.
# =============================================
# 304948600482451460
# ['PROVIDING EXPERIENCES']
# @oerbadianikki Yes! I &lt;3 my copper IUD. They tell you you may have heavier cramps/bleeding but I haven't even had that problem.
# =============================================
# 557230196625920000
# ['DISCOURSE']
# All forms,choices of contraception should be offered &amp;covered including the pricey &amp;sometimes only viable alternative the #IUD @CharlesMBlow
# =============================================
# 874648360652648400
# ['PROVIDING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT']
# @ashleycinamon Yeah I'm worried about that too. IUDs and nexplanon scare me so I may ask about the shot, but I'm not willing to risk my milk supply
# =============================================
# 1276256141815791600
# ['DISCOURSE']
# @pattypooty @divine_harm0ny My iud says ‘not today, or for the next 5 years bitch’
# =============================================
# 613011080986656800
# ['PROVIDING INFORMATIONAL SUPPORT']
# @FikaFiasco and also the IUD sometimes gets pushed out the way and you get pregnant anyway
# =============================================
# 686550317471809500
# ['PROVIDING INFORMATIONAL SUPPORT']
# @fit_with_hips you should try paraguard! no hormones
# =============================================
# 762025831313072100
# ['PROVIDING EXPERIENCES', 'PROVIDING EMOTIONAL SUPPORT', 'PROVIDING INFORMATIONAL SUPPORT']
# @redheaded_wreck IUD is awful &amp; was so painful. I know you and that you'll faint for sure getting one. I'd got for the implant or shot.
# =============================================
# 1093900266183819300
# ['PROVIDING EXPERIENCES']
# @Cadistra It's interesting that my doc didn't bring it up as a possibility before when we were first discussing the IUD. I've had some weird hormonal issues before with my period too when I was a teen, so who knows what else could be wrong with me. :v
# =============================================
# 1276150401503580200
# ['SEEKING EXPERIENCES', 'PROVIDING EXPERIENCES']
# @daniellaxhj After you got ur IUD was it painful?? i know one girl who bled for like 4 months straight after...
# =============================================
# 889850744962256900
# ['PROVIDING EXPERIENCES']
# @ragesinggoddess it's gotten harder for me to tell bc of my IUD which is GOOD because everything is very muted compared to before BUT it's confusing
# =============================================
# 1241381120110760000
# ['PROVIDING INFORMATIONAL SUPPORT', 'DISCOURSE']
# @TheLazyAnole @Kstickk Absolutely true. But IUD isn't an option for everyone so this is why the key is choice, to always have access to what works for you and your body.
# =============================================
# 1288128202687144000
# ['DISCOURSE']
# @AmazingE__ Just don’t get no IUD ... shit just be free of all of it 💯
# =============================================
# 1276253702173704200
# ['SEEKING INFORMATIONAL SUPPORT']
# @fanxybean WTF IS A KYLEENA?!!?! https://t.co/zMSLGkNk0o
# =============================================
# 1275532878919671800
# ['PROVIDING INFORMATIONAL SUPPORT']
# They also told me, as Mirena (the IUD brand) has on their website, that the IUD works primarily by releasing hormones into the body.
# =============================================
# 1339365023676833800
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# @annabellekatee I just got the copper IUD- it’s completely hormone free &amp; doesn’t give me mood swings or acne. I just kinda got a lil headache lol
# =============================================
# 59009287917281280
# ['PROVIDING INFORMATIONAL SUPPORT']
# @bellawrites Yes, Mirena is an IUD which also makes use of hormones. In smaller quantities than the pill though. Info www.mirena-us.com/
# =============================================
# 862839709239828500
# ['PROVIDING INFORMATIONAL SUPPORT', 'DISCOURSE']
# @ChitquitaBanana @ReaverBait @KatherineFento2 @MadFiest @TueborFrog @LisaWinslow You need an RX for the birth control pill as well and your point is .......
# =============================================
# 1225092146312700000
# ['PROVIDING EXPERIENCES']
# @Cass_eroll i have IUD now! i did have the nexplanon (the one in your arm) right after brax and it worked PERFECT. then i got it taken out bc my 5 years was up and got on the stupid pill 🤣 and kinzler is here 😂😂
# =============================================
# 1272827296643272700
# ['PROVIDING EXPERIENCES']
# @SzM8s I mean the one thing that made that happen was coming off the contraceptive pill. It was causing very bad water retention 😬
# =============================================
# 1169519903755448300
# ['PROVIDING EXPERIENCES']
# @BWiseHealth I am on the implanon nxt. I love it because I will take it out in 3yrs time. it saves me transport money for going to the clinic. I love it cause It has reduced my period flow&amp; period pains. It wasn't painful when it was inserted &amp;my arm doesn't feel weird as I thought it would
# =============================================
# 810388634134343700
# ['PROVIDING INFORMATIONAL SUPPORT', 'DISCOURSE']
# @SheisBoki I don't think many men use condoms though.The people I know are idiots about this. The Iud or depo shot is best for pregnancy tho
# =============================================
# 1223376641361088500
# ['PROVIDING EXPERIENCES']
# @BernieSanders Yes! I got an IUD because my body couldn’t take hormonal birth control. About 2 months later I got a bill for $800. I was 22, a single mom, and on Medicaid. Nobody told me I would have to pay for it. I didn’t know to ask.
# =============================================
# 485614902522826750
# ['PROVIDING INFORMATIONAL SUPPORT']
# @caitlyn_fennell less than 9% of US women use IUD and it equates to less than $8/month @10yrs and $16 @5years Not unaffordable
# =============================================
# 1270754121130422300
# ['DISCOURSE']
# @hels It looks like a mini IUD for Monopoly: Contraception Edition.
# =============================================
# 202127334168465400
# ['PROVIDING EXPERIENCES']
# @iloveemyah iud? I have it I swear i have the shortest periods ever. I use to have the worst cramps and heavy period now i only spot lol
# =============================================
# 138682701065621500
# ['DISCOURSE']
# @dat_LILThug hell yea in here talkin bout how he took a birth control pill. WTF
# =============================================
# 3818206311
# ['PROVIDING EXPERIENCES']
# @graciekate my sis hasn't had one in 3 years. i want IUD but OB says I have to have a baby first. its almost worth it!!
# =============================================
# 1307505152090349600
# ['PROVIDING EXPERIENCES']
# @TheCurvyRN_ I took my Mirena iud out this month after I had a large hemorrhaging cyst on my ovary as soon as I could I took that thing out !
# =============================================
# 604093645118148600
# ['DISCOURSE']
# @avantgardea Something something IUD joke #DriveInMob
# =============================================
# 573716250712408060
# ['PROVIDING INFORMATIONAL SUPPORT']
# @JAZonyaMINE If you go for the IUD, I'd wait for a bit (2 months?) to let minipill clear some then do it. Lots of ibuprofen b4 insertion.
# =============================================
# 738340965543350300
# ['PROVIDING EXPERIENCES', 'DISCOURSE']
# @clinicboss @VICE @DrJenGunter The IUD works great for like 10 of my friends, but women need to be taken seriously if something isn't right.
# =============================================
# 1330127753962803200
# ['PROVIDING INFORMATIONAL SUPPORT', 'DISCOURSE']
# @DoppelMark @BeigeShiba @stillgray A real interesting research topic, look up this fine Mexican Scientist George Rosenkranz, the so called father of the birth control pill and made his fortune through his company Syntex which pioneered one of the first mass produced birth control pills. https://t.co/uEUUkCP1Jr https://t.co/XMrvS8dDEe
# =============================================
# 882246116930093000
# ['PROVIDING EXPERIENCES', 'PROVIDING EMOTIONAL SUPPORT']
# @warrismyown I changed pill a few months ago so I feel this tweet so much 😩 thinking about getting an IUD or injection tbh
# =============================================
# 689232070116159500
# ['DISCOURSE']
# @meowllorylynn you: no sweat, this iud is no pain at all you: FFFFFFFFs this iud pain
# =============================================
# 1141595120942194700
# ['PROVIDING EXPERIENCES']
# @karakaiwohi IUD honestly! Really convenient not having to worry about it even there, and the insertion of it is not actually as bad, just slight pressure. only thing is the random bad cramps and weird random bleeding the first few months on it . But it goes away slowly , would recommend
# =============================================
# 1308856733041860600
# ['PROVIDING EXPERIENCES']
# @quietcoolkid Not an iud but I have nexplanon and absolutely love it!
# =============================================
# 1305655748395851800
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EXPERIENCES', 'PROVIDING EMOTIONAL SUPPORT']
# also !!!! birth control changes ur body &amp; how u put on weight sooo much too! my iud was a big part of me gaining weight recently- but my nexplanon made me loose a ton of weight! so be kind to ur bodies &amp; appreciate how many things go into weight change! it’s ok &amp; normal !!
# =============================================
# 1336757884743536600
# ['DISCOURSE']
# @podgie_TV i haven't had a nasal swab yet but i can't imagine it's more intense than getting an IUD shoved up your vagina.
# =============================================
# 1007455163068477400
# ['PROVIDING EXPERIENCES']
# okay i didn’t wanna scare potential IUD getters but also • came really close to puking a couple minutes after the procedure was over
# =============================================
# 912108367660802000
# ['PROVIDING EXPERIENCES', 'DISCOURSE']
# Or better contraceptive (see: IUD) has been more useful of an investment in our eyes
# =============================================
# 1216176663630942200
# ['PROVIDING EXPERIENCES']
# @zibukins @sindivanzyl I have the IUD removed and now using evra patch. It's over a year now, the flow has reduced drastically and no more period pains
# =============================================
# 774038686363115500
# ['PROVIDING EXPERIENCES', 'DISCOURSE']
# @A_NurSedative I have no idea but my uterus is holding on to my IUD now more than ever
# =============================================
# 1293680971896598500
# ['PROVIDING EXPERIENCES']
# @lilymckel The IUD was perfect because I had it and didn't have to worry about dealing with stupid insurance. The only downside is that the IUD was the worst experience of my entire life. And I've only had problems since I switched jobs 🙄
# =============================================
# 767533343063810000
# ['DISCOURSE']
# @allysonkate all hail the IUD
# =============================================
# 1216931806316023800
# ['DISCOURSE']
# @anashedidnt @Calligulump Took her to talk to the Doctor about an IUD. Came home with a vasectomy instead.
# =============================================
# 235913146106273800
# ['PROVIDING EXPERIENCES']
# @christinazhine it's getting a nexplanon inserted into my arm. The nexplanon is covered by my rx (cont) http://t.co/XF5oplT
# =============================================
# 384736705892204540
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# @residekelsey @sierraantee Just don't get the merina Iud, it has been recalled and I know some girls who didn't like it
# =============================================
# 971498429745569800
# ['PROVIDING EXPERIENCES']
# @momma_ky_ @krin_clev I had an IUD so now I pretty much have no idea what birth control I am gonna get after I have the baby.
# =============================================
# 1320898051855294500
# ['DISCOURSE']
# @GatorHunter73 @JKoBBs125 @Johndavidkenned @washingtonpost Lol it's like even if you have an iud or use condoms they can break😉 so I should be able to tie my tubes right? But I can't without a husband/already having 2 kids/can't be under a certain age. Hmmm it's almost like even if I'm responsible it could still happen🤔
# =============================================
# 1120536948978921500
# ['DISCOURSE', 'PROVIDING EXPERIENCES']
# @jkwillettmd No way would I let that gyn dilate my cervix. If you can't manage to not be a dick during a discussion, there is no way I'm trusting you to be decent while putting in an IUD. That was painful AF; my nurse midwife's patience during it is the only thing that made it bearable.
# =============================================
# 1259215889116905500
# ['PROVIDING EXPERIENCES']
# @GirlChildOfOden @lukeyism Try getting an iud, I was like this and mine helped LOADS
# =============================================
# 826627942734299100
# ['DISCOURSE']
# @Raamlife @nytimes blood disorders. Something I don't see anyone talking about, but is a real need for the birth control pill.
# =============================================
# 1138889678566940700
# ['PROVIDING EXPERIENCES']
# @inuyaunie @Just_Jass__ @KuminBack I have Nexplanon and I haven’t had one in months
# =============================================
# 1270469913468194800
# ['DISCOURSE']
# @cat_swings @shereeserenee I need to make some art of some sperm, wearing helmets and carrying rifles, running from one of these like "IUD! IUD!"
# =============================================
# 1253107112240169000
# ['SEEKING EMOTIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# @TeamPulte I got an IUD yesterday and it has me super emotional and wanting comfort food but I’m too shy to speak up. How’s your day?
# =============================================
# 377805244337770500
# ['PROVIDING INFORMATIONAL SUPPORT']
# @meggzzie seems the best way to go is IUD, but I was told it’s not considered effective until 90 days after placement!
# =============================================
# 1131396374124257300
# ['PROVIDING EXPERIENCES']
# @ginakoko6 @vegan_vexation I have an IUD but I've never seen a gyno lmaooo
# =============================================
# 1110522567302004700
# ['PROVIDING EXPERIENCES', 'PROVIDING INFORMATIONAL SUPPORT']
# @aardvarkwizard @J_M_T_ @tiarala OH I REMEMBER WHY I DIDNT GET NEXPLANON IT INHIBITS OVULATION. And ya demigirl is a big fan of ovulation because I like bein horny. https://t.co/gCjlq82HSb
# =============================================
# 1297674604744454100
# ['PROVIDING EXPERIENCES']
# @stephanieel19 My iud moved I think 😒
# =============================================
# 951983143954866200
# ['PROVIDING EXPERIENCES']
# @merlinslaugh Oh, gosh, honey. I had hot flashes because of either perimenopause or a cyst (the cyst is real, the peri we dunno. The IUD fixed the symptoms). They are AWFUL.
# =============================================
# 1220041419743801300
# ['PROVIDING EXPERIENCES', 'DISCOURSE']
# @abbyxcuri I’ve been stalling to go get my iud copper implant🥴 https://t.co/pvaEGDPFxU
# =============================================
# 1330883260419858400
# ['PROVIDING INFORMATIONAL SUPPORT']
# @ultratcha What about catching HIV OR Syphilis because of no condom that is worse you do know as well that you can get a contraceptive implant that lasts for 3 years
# =============================================
# 1147027194864177200
# ['DISCOURSE']
# @svetlya_chok #ECP2019 Traces origin of thin ideal to introduction of oral contraception and the second wave of feminism.
# =============================================
# 1185755971584290800
# ['PROVIDING EXPERIENCES']
# @Babrooster If I could take the hormones, I'd be on one to stop my periods. Instead, I've got Paragard. Still get the periods, but the protection lasts for 10 years.
# =============================================
# 558855361575530500
# ['DISCOURSE']
# @playacondado @ChristieC733 @WayneBogda @Outofnames - Yes, they r mostly against the kind that abort after conceiving, like IUD, etc.
# =============================================
# 1283868380693516300
# ['PROVIDING EXPERIENCES']
# I wanted to stop the pill and go for ‘non hormonal’ I went for the copper IUD at 16. This made everything WORSE. It seemed like the panick I had multiplied. Read Tess's story here. https://t.co/fictD8kt31
# =============================================
# 1166823984652050400
# ['PROVIDING EXPERIENCES']
# @toridii bro they all are ass, I’m too scared to get the IUD, and the implant and I can’t remember to take the pills everyday so I just got back on depo 😕
# =============================================
# 585215709585641500
# ['PROVIDING INFORMATIONAL SUPPORT']
# WATCH IT: @Refinery29 covers @ThisIsFusion explainer on why IUDs are having a moment. http://t.co/TCQKaSng2i http://t.co/4bm2wHwtqH”
# =============================================
# 1305844258310697000
# ['PROVIDING EXPERIENCES', 'PROVIDING EMOTIONAL SUPPORT']
# @ElsaVanEden That sounds like an amazing experience, for something medical at least... From my experience, here it also really depends on your doctor. For example, I had two fundamentally different experiences with IUD removal/insertion, even though it was in the same surgery, different doc
# =============================================
# 1186023826322317300
# ['PROVIDING EXPERIENCES']
# @beniellamarkey @realandieangel Brush 'em off. IUD are the best so far, talking out of experience. https://t.co/jbnv6P6wWx
# =============================================
# 1205984836726464500
# ['PROVIDING EXPERIENCES']
# @parrisxarrianna Nexplanon implant 8/10 i didn’t gain weight my period is irregular but i don’t have cramps and my period isn’t heavy at all it all depends on your body tho
# =============================================
# 1217803253703958500
# ['PROVIDING EXPERIENCES']
# @LittleMissMoss_ That’s what I’m saying 😩😂 now I got to force myself to eat and only end up eating like 1 real meal per day smh I gotta change that ASAP! I have the IUD, love it but if my appetite don’t change soon I’m going to have to see about other options 😕.
# =============================================
# 1063218922676056000
# ['PROVIDING EXPERIENCES']
# @BMS_Arianna @KrystynaHutch I was having intense cramps after sex with my IUD, I got it taken out and I haven’t had and post sex cramps since.
# =============================================
# 1318654772916912000
# ['PROVIDING EXPERIENCES']
# @taeebee_ I got the mirena iud it sucks i never had as many problems but it’s going on two years and it just gets worse
# =============================================
# 21105070231
# ['PROVIDING EXPERIENCES']
# @TheLoneOlive I just got an IUD; and I sure hope it's covered. I has Mass state insurance. it should be.
# =============================================
# 232047558166474750
# ['PROVIDING EXPERIENCES']
# @MizpahMijares i think I will go to for the IUD too but if deli ko hiyang, murag magpa vasectomy akoa bana !!
# =============================================
# 1229984679723335700
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# @itsjessicalol Definitely NOT the IUD, they can’t really control the dosage you are getting so for some it can be too much. I was so depressed but to top it off I bleed for like half the month.
# =============================================
# 1303557944009613300
# ['PROVIDING EXPERIENCES']
# @Vanderellla i feel more sane on the iud than the implant that goes in ur arm
# =============================================
# 948024861313482800
# ['PROVIDING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT']
# @_karinnna I get the migraines go I had the iud i loved it but i just see so many bad stories online I’m scared to get it again
# =============================================
# 77076392621244420
# ['DISCOURSE']
# @DIESELJUGGALO no that doesn't solve anything tea him her morals and self respect wud b more helpful than an IUD
# =============================================
# 562576330475053060
# ['DISCOURSE']
# @Lays_India #GameKaDushman I will ask her to buy a contraceptive pill so that she gets scared and does not want to go out...
# =============================================
# 916315458915196900
# ['PROVIDING EXPERIENCES']
# @eveewing When I was having my IUD out, she didn’t warn me she was touching the cervix; my whole body clamped &amp; I shot that spec out like a missle 😂
# =============================================
# 1143910113050124300
# ['PROVIDING EXPERIENCES']
# @necrologies Getting my IUD put in and taken out were the two most painful things EVER
# =============================================
# 952603870789808100
# ['PROVIDING EMOTIONAL SUPPORT']
# @RioLepidoptera Sorry to hear about your experience, I'm guessing with an IUD insert? Glad that appreciate the rant!
# =============================================
# 1019015707621617700
# ['PROVIDING EXPERIENCES']
# @jennymeat all im saying is if i didnt have an iud i think my bf would have knocked me up?
# =============================================
# 1225187142751572000
# ['PROVIDING EMOTIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# @TFemnation I 100% know *exactly* what you're going through. Started for me at 8yo. I even had surgery at one point for endo, but there was no endo. Ended up getting a Mirena IUD, which has changed my heckin' life. I don't know if that's an option for you, but it saved me.
# =============================================
# 1314758388706730000
# ['PROVIDING EXPERIENCES']
# @BaileySarian I have the mirena IUD and I don’t get my period anymore!! Sooooo good because I’ve got Endometriosis and it’s been so great.
# =============================================
# 1291150949466214400
# ['PROVIDING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT']
# @_Conway__ Yess!! Gonna try the IUD hopefully it works out 😩
# =============================================
# 1288274408923111400
# ['DISCOURSE']
# @QanonYahshua Looks like her old IUD. She definitely doesn’t need it anymore.
# =============================================
# 1090397774296830000
# ['PROVIDING EXPERIENCES']
# @faithmoroness My sister got pregnant on birth control had the whole iud in her uterus &amp; had to get it removed to save her baby that was also growing in there as well sometimes things happen guys switching up unplanned pregnancies due to birth Control failing to work its life.
# =============================================
# 889723516148305900
# ['PROVIDING INFORMATIONAL SUPPORT']
# @skeletonbrat Ya, hormones are always tricky. They also have the non hormonal IUD but I heard IUDs hurt to be put in 🤷🏽‍♀️
# =============================================
# 755900380152750100
# ['PROVIDING EXPERIENCES']
# @digimediamama I have the nexplanon implant
# =============================================
# 996812126139363300
# ['PROVIDING EXPERIENCES']
# @jedishelbz I use Paraguard and it has zero hormones, and it’s good for 10 years!!! Love it!
# =============================================
# 1162081682104737800
# ['PROVIDING INFORMATIONAL SUPPORT']
# @DohDeal @TwitterMoments According to the CDC that has a 22% failure rate compared the the pill's 9%, compare to a condom at 18%, the pill a 9%, an IUD at 0.2-0.8%, an implant at 0.5%. Even abstinence proves to hard for most people. I won't get into virgin births in religion.
# =============================================
# 278960167138258940
# ['PROVIDING INFORMATIONAL SUPPORT']
# @hzeph you should get one seasonale- best birth control pill EVER! Only 4 periods a year 😎
# =============================================
# 1128301067572260900
# ['SEEKING INFORMATIONAL SUPPORT']
# @amberj__ I’ve heard of the IUD what’s the bar? The thing that goes into your arm or something?
# =============================================
# 1258896067552325600
# ['PROVIDING EXPERIENCES']
# @RiceRiceBaybee Oh boy. I use females for Gyn for the purpose of empathy. And I will never get an IUD bc I’ve seen the reactions from patients on insertion from screaming &amp; cursing. The lucky ones just vagaled and syncopozed. I will never get one. https://t.co/SdUaIA7EW9
# =============================================
# 555242600954093600
# ['DISCOURSE']
# @maximumplum Doctor, esp. if you're #TeamIUD. She jokes she has the "fastest IUD insertion this side of the Mississippi!"
# =============================================
# 1048667288747081700
# ['PROVIDING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT']
# @NARAL This is absolutely terrifying. Getting my IUD in a week!
# =============================================
# 1156195936684642300
# ['PROVIDING EXPERIENCES']
# @movebackbuggz 😂I had to wait because I got the IUD
# =============================================
# 1197930689204805600
# ['DISCOURSE']
# @deborahagold I know. That guy sounds amazing. IUD less so..
# =============================================
# 24131138714
# ['PROVIDING EXPERIENCES']
# @heirtoblair late to the party but I gave a mirena iud and love it. It's my second one, loved the first one too.
# =============================================
# 1006553809987035100
# ['PROVIDING EXPERIENCES']
# @mellokittie @mothraofkittens @KrockCodyMack Bahaha I also have an IUD now!
# =============================================
# 1261586581628031000
# ['SEEKING INFORMATIONAL SUPPORT']
# @LauraHolland The pill, as in the contraceptive pill?
# =============================================
# 197003423219056640
# ['PROVIDING INFORMATIONAL SUPPORT']
# @bdcthomas as long as it's not the contraceptive pill, you should be ok.
# =============================================
# 319617788408897540
# ['PROVIDING EXPERIENCES']
# @KodiakCleveland ha yea I have the nexplanon which is a lil rod that was inserted into my arm and fricken hurtssssssss. Guys have it easy
# =============================================
# 1286358388645884000
# ['DISCOURSE']
# @asila_7 Until she said i did not took birth control pill today
# =============================================
# 1092622754464088000
# ['PROVIDING EXPERIENCES']
# @just_bein_Bee I'll take Ibuprofen for the pain and the birth control pill was switched. I have a fibroid too. Taking iron for low hemoglobin.
# =============================================
# 483273618202173440
# ['DISCOURSE']
# @boogerbuttt always wrap it before you tap itttt, &amp; get the nexplanon. It does wonders ☺️ #noperiods #nobabies
# =============================================
# 1235644180824645600
# ['PROVIDING EXPERIENCES']
# @brencharvy Nexplanon literally ruined my life :-) haven’t been the same since
# =============================================
# 1231617733349052400
# ['DISCOURSE']
# @TarotByBronx The way I ran to take my birth control pill after reading this
# =============================================
# 1083740844635635700
# ['PROVIDING EXPERIENCES', 'DISCOURSE']
# @TheRebelTV @MartinaMarkota Birth Control messes with womens' bodies too - really messes with your body. In the 80s my mom's friend had a massive stroke from an approved birth control pill on the market and sued for millions and won; but it wasn't and still is NOT worth the risk.
# =============================================
# 1197711015347130400
# ['PROVIDING EXPERIENCES']
# @alaynashottakes @fanabonga @IanEnsign @SaesDeHonos @nypost Same....the IUD is good enough for me but it only lasts 5 years. My tubes are tied so I am not using it for birth control.
# =============================================
# 966184691412996100
# ['PROVIDING EXPERIENCES']
# @44dddsinurmouth Banging into the cervix isn’t pleasant anyway. So my thoughts are if it only happens maybe once every 500 or so times you fuck, and it’s WAY more convenient, I’d stick with it. My wife lost weight going from pill to iud if that matters to you.
# =============================================
# 1116140126797795300
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# @cozybela Try an IUD!! Life changing
# =============================================
# 1098633887025107000
# ['PROVIDING INFORMATIONAL SUPPORT']
# @XhazeI Any pill taken many times isnt safe. Even that birth control pill isn't. Recommend yall take 3 months breaks off it
# =============================================
# 916417177703665700
# ['PROVIDING INFORMATIONAL SUPPORT']
# @BillyBarnacles @fawfulfan @PolitikMasFina No, you have to have a Doctors subscription to get birth control pills, both the depo shot &amp; IUD are done by the Doc. NOT over the counter
# =============================================
# 1316209914105204700
# ['PROVIDING EXPERIENCES']
# @bigskybabs Had an IUD installed.
# =============================================
# 1179444985894191000
# ['PROVIDING EXPERIENCES']
# @wtfisazulieee Baybeeeeee—it’s like 30 and LOOKS LIKE IT. I had to take my IUD out bc the lethargy was UNBELIEVABLE
# =============================================
# 836742493811191800
# ['DISCOURSE']
# @TM2LeahDawn @Mysphonic So, not having sex, turns into having an IUD. Pick a story, and stick with it. #addieistherealmvp
# =============================================
# 1304087665986408400
# ['PROVIDING EXPERIENCES']
# @xobrianadej My god son is a BC baby, and his brother is a IUD baby!
# =============================================
# 1139629166981238800
# ['DISCOURSE']
# @QuancyClayborne An IUD can't be taken out then put back in at random..What an arsehole..
# =============================================
# 521271574402703360
# ['PROVIDING EXPERIENCES']
# @mo_ranyart On pills I didn't get any explanation. When I got an IUD I was heavily counseled.
# =============================================
# 1187419421398012000
# ['PROVIDING EXPERIENCES']
# @iam_apeachh That's what I've heard too. In fact, the first time I heard about it was through a friend of mine that got it. It looks like it hurts at first, but I'd rather have it hurt in my arm rather than get an iud thats gonna hurt down there.
# =============================================
# 250220579775455230
# ['PROVIDING INFORMATIONAL SUPPORT']
# @SarahNMoon @amaditalks Info from book that may be useful - Implanon failure rate is 0.05%, Mirena is 0.2%. If that matters.
# =============================================
# 1164355825466581000
# ['DISCOURSE']
# @359bertle yeah i get the nuance you are going for. but would it be safe to assume adults consenting to iud insertion have some experience w menstruation? wonder what other ideas folks will have.
# =============================================
# 1022297555646836700
# ['PROVIDING INFORMATIONAL SUPPORT']
# @Kauionalaaani Try nexplanon sis
# =============================================
# 1074828224738324500
# ['SEEKING INFORMATIONAL SUPPORT']
# @bcphoto can you not wear a cup with an iud?
# =============================================
# 1127351312641871900
# ['DISCOURSE', 'PROVIDING INFORMATIONAL SUPPORT']
# @badicaldino @LilaGraceRose @Alyssa_Milano Many of these pro birthers are not ok with an IUD because it prevents the implantation of a fertilized egg.
# =============================================
# 1094843802987184100
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EMOTIONAL SUPPORT']
# @slutaburger1 sorry babe! until you can get your iud looked at, oxypads (available at any drug store) or murad (sephora or amazon) products will help with the break outs, though! they’re both pretty affordable options
# =============================================
# 823639640313892900
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# nexplanon implants and IUDs have the same protection as the BC pills (99.9%) i got my implant from planned parenthood
# =============================================
# 1318595896968421400
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# @nownlatergators they work but the side affects can be trash. i was on the shot for 2 years and i'm about to switch to an iud. the shot was messing with my emotions and body way too much
# =============================================
# 1118223350931828700
# ['PROVIDING EXPERIENCES']
# @renythemenace Ain’t no way. An old coworker of mine had one that dislodged from her uterus and went into her stomach. She’s used the IUD for YEARS no problem and now she has to have a 3rd surgery to TRY to get the last piece out.
# =============================================
# 1249556990554062800
# ['PROVIDING EXPERIENCES', 'SEEKING INFORMATIONAL SUPPORT']
# @SafeeraHussainy I got the emergency contraceptive pill recently from @ChemistWhouse. The pharmacist said it was a legal requirement that I fill out/sign the PSA checklist. I called later to query this and the pharmacist said PSA guidelines are still up-to-date. Is this true?
# =============================================
# 1181373073121071000
# ['PROVIDING INFORMATIONAL SUPPORT']
# @_Gorda96 Para guard iud doesn’t have hormones. Talk about it with your doctor
# =============================================
# 1085297295355109400
# ['DISCOURSE']
# @apihtawikosisan lmao i fucking wish. someone make me an offer. i’ll withdraw my pension and remove my iud.
# =============================================
# 205881199082741760
# ['PROVIDING EXPERIENCES']
# @PBandJenelley_1 I know sooooo many girls who have had the implanon removed bc of weight gain. #switchtomirena
# =============================================
# 84092427278893060
# ['SEEKING EXPERIENCES']
# @LadyGranuaile what's da name of da birth control pill u use?
# =============================================
# 1083696709312675800
# ['SEEKING INFORMATIONAL SUPPORT']
# @Olwe2Lesh How often should I be checking on my iud, asking for a friend 🤔
# =============================================
# 1040822433916153900
# ['PROVIDING INFORMATIONAL SUPPORT']
# @elizaaaabeths Nexplanon, the one in your arm.
# ...
# 1290998471256944600
# ['PROVIDING EXPERIENCES']
# @abblejuiceabby yeah I have an IUD and i’m on the pill
# =============================================
# 1063640952382898200
# ['PROVIDING EXPERIENCES']
# @jakeftmagic I'm on the shot and it's been working well for me, my spouse is on T and has a nonhormonal IUD, which may help with shark week but may not
# =============================================
# 1203063142361817000
# ['PROVIDING EXPERIENCES']
# @psiliminal It is reminiscent of birth pains, apparently. I didnt pass out or faint or anything but the doctor said I went white as a sheet haha. Just be prepaid for some weird feelings. Getting IUD #2 is worse than IUD #1 if you ask me
# =============================================
# 205761465628626940
# ['PROVIDING INFORMATIONAL SUPPORT']
# HEALTHTIPS Researchers say birth control pill's risk of failure is 20x more than that of IUDs or implants. @realmxradio
# =============================================
# 1272709776166793200
# ['SEEKING EMOTIONAL SUPPORT', 'SEEKING INFORMATIONAL SUPPORT']
# @iluvcats95 That’s great that it’s better now! I’m worried bc I went on some threads and Paragard has people bleeding extra heavy and cramping bad and Mirena seems to be similar but eventually goes away. Technically I don’t know if mirena would be better since it’s still hormonal but it
# =============================================
# 339073231518572540
# ['DISCOURSE']
# @LMervz hahahahah your mom wishes she was on the contraception pill before making you 😂
# =============================================
# 1126663896079593500
# ['PROVIDING EXPERIENCES']
# @ThayerJessica5 Get the IUD, I feel the exact same as when I wasn’t on any form of birth control! I love it
# =============================================
# 1158941534324084700
# ['PROVIDING EXPERIENCES']
# @goforawalker That’s how I felt when I got an IUD installed
# =============================================
# 303112371281489900
# ['DISCOURSE']
# @sarajcox lol, there should be a cocktail liqueur that has contraceptive pill as an ingredient :-)
# =============================================
# 624568228359049200
# ['PROVIDING INFORMATIONAL SUPPORT']
# Or at my question about fisting. Which, for those following along at home, should not be a problem for an IUD. Appointment to place it made.
# =============================================
# 706367924496310300
# ['DISCOURSE']
# @TR3Y_ she CRYIN out for somebody to TRY and knock her IUD out... Only explanation for her total disputing of that man's experience.
# =============================================
# 1199404313937928200
# ['PROVIDING EXPERIENCES']
# @trinsativa @indxxaa @__jxnnie @dddonyah Girl depo is almost as deadly as the arm implant I like my iud tho and I still get my period every once in a while
# =============================================
# 982801515743100900
# ['DISCOURSE']
# @sweeet_n_high my friend calls her implanon a slut rod, i called mine the sad stick
# =============================================
# 365288524745949200
# ['PROVIDING INFORMATIONAL SUPPORT']
# @Paaay10 they said it lets out the same hormones as the iud
# =============================================
# 960963066065125400
# ['PROVIDING EXPERIENCES']
# I specifically asked for an iud because I am bad at remembering to take medication. And she told me no. Bitch.
# =============================================
# 1210038632293093400
# ['DISCOURSE']
# @goldendebbie @BreitbartNews Its Its nearly 2020. You haven't figured out how to use the Pill,IUD,Condom,Deprovera,Letssee I can name 20firms of birthcontrol other than killing a baby. How dumb and Lazy do you have to be not to have figured this out. Its not Rocket Science. These sick f""ks make $$$$ of this
# =============================================
# 1306289992260620300
# ['PROVIDING EXPERIENCES']
# @jenslomos I had the nexplanon twice. First time I loved it, never got my period. Second time it sucked, I got my period every two weeks so I took it out about a year in. I also gained like 10 pounds
# =============================================
# 1012524214249611300
# ['DISCOURSE']
# @Inkstainedshts @ABinTX @emilylhauser Obvs meant IUD not LID. Stupid phone.
# =============================================
# 1270337033546993700
# ['PROVIDING EXPERIENCES']
# @vlnguyen @_chismosa_ The hormones from the pill were messing with my migraines so I got an iud. For the most part I love it, but insertion was excruciating and now I’m dreading removal when the time comes. But the four years I’ve had it have been great.
# =============================================
# 1198662050580455400
# ['PROVIDING INFORMATIONAL SUPPORT']
# @fetishburglar @yourpaljuliee If you have an iud it’s normal babe. Not sure what birth control you’re on though
# =============================================
# 1201172109759783000
# ['PROVIDING EXPERIENCES']
# @DanielaaRuby @clarissagomez24 @oxminaox that’s awesome! my cousin got the iud &amp; her milk dried up after a week. it’s different for everyone, i personally didn’t wanna risk my milk drying bc i wasn’t getting a lot of it to start with
# =============================================
# 1275178370763030500
# ['PROVIDING INFORMATIONAL SUPPORT']
# @pingus1997 that is up to u entirely . there is Lso the cyberpatch and cyber iud . and a chip that u put in your ass
# =============================================
# 1115282769850933200
# ['DISCOURSE']
# @kenziebeck23 @CPTDoomDC @VictoriaErem @TeriPoulton @ConnellMaire @ReproRights My recommendation! Even better than pills and IUD combo!! No sex will give you no chance for parasite! Very good. Very good!
# =============================================
# 1316384798579933200
# ['PROVIDING EXPERIENCES']
# @bigskybabs Got a diaphragm, which apparently, sizing them is becoming a lost skill since IUDs are pushed so heavily. My actual doctor tried to push IUD then wanted me to have two appointments for the diaphragm, which would have been two co-pays. Got it no problem, in one visit at PP.
# =============================================
# 1143932223634063400
# ['PROVIDING EXPERIENCES']
# @SimoneSaidSo It’s just like that. I have the copper IUD, so no hormones over here 🥴 except for the ones that wreck havoc normally
# =============================================
# 740981689615163400
# ['DISCOURSE']
# @PaternityCourt It could all be so much simpler. Condoms, The Pill, Diaphragm, IUD, Depo shots, NuvaRing, VCF film and oh so many more.
# =============================================
# 1143634148025864200
# ['DISCOURSE']
# @The_Lock_God @VelvetUndergr10 @Downeyangel @GinnieLumpkin @WhatsUp00085277 @Mat0816 @OwlFoxVT @Mellecon @hboulware @WriteGrlProbs @DrLeanaWen @molratty @Patriot_Musket @SouthernKeeks Well I dont know," lock god", you planning on busting through that condom, bc pill, iud, and every other bc device on the market bc you're such a stud??
# =============================================
# 1166009076469457000
# ['PROVIDING EXPERIENCES']
# Anyways, long story short, biopsy results came back, and it was indeed a reaction from the IUD. Had it removed, all bumps went away by day 2 of removal.
# =============================================
# 1333592427001688000
# ['DISCOURSE']
# @Meh_i_guess_ @DerekSheen @TalbertSwan @realDonaldTrump I believe that would be better to promote a policy to give IUD to women than allow abortion
# =============================================
# 898124321188593700
# ['PROVIDING EXPERIENCES']
# @fondlarrie101 @lizzyf101 @ManicPangloss @mrsscanlan @sophierymer @lanalanab0bana @AlisonDolan @Independent I once had to leave work early because my cramps were immobilizing me. I was in so much pain that I couldn't work. Luckily my IUD fixed that
# =============================================
# 334906143040217100
# ['DISCOURSE']
# @Fedx_ahoe at least u know it &amp; admit it. Somebody iud fall out &amp; I'm a criminal
# =============================================
# 853495027187814400
# ['DISCOURSE']
# Did this girl just take a birth control pill with a shot of Don Julio 🤔
# =============================================
# 1259575942457876500
# ['PROVIDING EXPERIENCES']
# @gabbers93 Thank you!!💜 I hope you’re not experiencing it anymore either? I got an IUD &amp;now I have the same (tolerable) cramps as the average woman, only occasional vomiting with those rare original cramps, no 29 day long periods, no crippling depression💁🏾‍♀️ #feelinmyself #periodsRabreezenow
# =============================================
# 1177439863349612500
# ['DISCOURSE', 'PROVIDING EXPERIENCES']
# @14strk i think i’m getting horny again bc my iud is expiring, once i get my ovaries removed it will be over for these hoes
# =============================================
# 1202140891177201700
# ['PROVIDING EXPERIENCES', 'DISCOURSE']
# @mrs_denglish When I think about the cost of surgery and IUD I had 5 years ago, there’s NO way I could have afford it then. It’s horrendous and it’s my first time genuinely fearing the privatisation of it.
# =============================================
# 1308727427649204200
# ['PROVIDING INFORMATIONAL SUPPORT']
# The good news is that with time usually after 1- 3months), the body gets used to this changes and the side effects become history. Why not #whispatous and chat with a doctor to see if the daily contraceptive pill could be a good choice for you.
# =============================================
# 1013183605663772700
# ['DISCOURSE']
# @lyn_musk @JacobAWohl What does that have to do with the ACA birth control pill rider and condoms? That maybe you should have used them?
# =============================================
# 1219917806533144600
# ['DISCOURSE']
# @huntychan My wife's IUD hard at work
# =============================================
# 1138998402786713600
# ['PROVIDING EXPERIENCES']
# @yumcoconutmilk I developed gall bladder disease as a result of a birth control pill, but I don't think the outcome would have changed if I'd gotten the pill OTC. Every medication has side effects, OTC or not and I'd rather have easy access than none at all.
# =============================================
# 238432275119890430
# ['PROVIDING EXPERIENCES']
# @NERDwithSWAGGER I was talking about Bella lol her friends is currently hospitalized bc of an IUD gone wrong lol
# =============================================
# 595589799370711000
# ['PROVIDING EXPERIENCES']
# @iggigg Given that they *could not locate* my IUD I'm presuming it's the intrusive kind.
# =============================================
# 108661073980309500
# ['DISCOURSE']
# @thatpaleoguy @primalmeded better than oral contraception! #notreally
# =============================================
# 1112901883813920800
# ['DISCOURSE']
# @OfTheDaygirl Bitch you better some Nexplanon or Mirena or something bc surprise babies are NOT it.
# =============================================
# 1281228390775820300
# ['PROVIDING EXPERIENCES']
# @KFCradio wanna be even more confused about periods. I have an IUD, I haven’t had a period in 10 months. It’s fantastic (minus the periodic terror that I’ve been knocked up) @FeitsBarstool @KFCBarstool
# =============================================
# 1314807969847160800
# ['DISCOURSE']
# @4ktIsrael @5knutsacc @PissSpicy @chancexclip bisexual people exist? ivf and iud also exist. you don’t need to have sexual intercourse directly to reproduce
# =============================================
# 497645641648984060
# ['PROVIDING INFORMATIONAL SUPPORT']
# "SUVIDA" is the most popular #contraceptive pill brand in KOLKATA ,Ind Only Rs30@month is the cost to be worry free and no risk of pregnancy
# =============================================
# 1054094891435753500
# ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EXPERIENCES']
# @baileysamoht The one that goes in your arm. Not the iud. I’ve only heard bad things with that one.
# =============================================
# 1133797249375395800
# ['PROVIDING EXPERIENCES']
# @EmBaer Got my IUD in Nov 2016.
# =============================================
# 230193444449050620
# ['DISCOURSE', 'PROVIDING EXPERIENCES']
# @alicia_babii I am soo serious I even told Dae Dae ass that I told him we not having sex until after my 6 wk check up an I get my IUD
# =============================================
# 164823114616803330
# ['PROVIDING INFORMATIONAL SUPPORT']
# @CTurlington Birth control pill mix up could cause unintended pregnancies http://t.co/mpcX30Ce via @ABC News.
# =============================================
# 1217561714633461800
# ['PROVIDING INFORMATIONAL SUPPORT']
# @chadfelixg They can get a total hysterectomy or an IUD.
# =============================================
# 1260388930408587300
# ['PROVIDING INFORMATIONAL SUPPORT']
# @DollbabyAJ @Brieyonce The birth control pill was originally only approved for use for menstrual disorders and illegal be used otherwise. It was legalized in the 1960s for use by all women.
# =============================================
# 1328420887687696400
# ['PROVIDING EXPERIENCES']
# @sheeeiidaa I’ve had nexplanon for 4 years, the first time I got implanted my period was irregular for like 4 months but went back to normal. I like it
# =============================================
# 760912620509683700
# ['PROVIDING EXPERIENCES']
# @lexivanl @abx09 hahaha I have a few friends who have an IUD and love it or just regular bc pills
# =============================================
# 681295511584817200
# ['PROVIDING INFORMATIONAL SUPPORT', 'DISCOURSE']
# @eshaLegal @kalena141 @Carlrs1Scaggsc @jsavite @NEJM THE IUD causes so many problems... I can't even believe you bought into this one.
# =============================================
# 616642607129595900
# ['DISCOURSE']
# @toby_dorena LOL! Telling me I "need counseling" is silly. I have an IUD and live within 15 minutes of an abortion clinic.
# =============================================
# 490499311029874700
# ['DISCOURSE']
# Some information @ MOA of IUD's @HobbyLobbyStore Intrauterine Devices Separating Fact From Fallacy http://t.co/l4e69Jlv48 @GOP @NARAL @PPact
# =============================================
# 1230697689035051000
# ['PROVIDING EXPERIENCES', 'DISCOURSE']
# @seafishyy don’t worry my IUD has 5 years left on it
# =============================================
# 1085178893034606600
# ['PROVIDING EXPERIENCES']
# @_ambaalynn @Sammien_14 @karlyycarter i have nexplanon and my periods also last up to 3 months at times.
# =============================================
# 910893889644634100
# ['PROVIDING EXPERIENCES']
# @megobits Ooh yeah I noticed that in myself and wondered if the IUD was responsible
# =============================================
# 702927496631738400
# ['PROVIDING EXPERIENCES']
# @mcakotp @Jen_Lee 6cm simple ovarian cyst, 4cm fibroid, and an IUD that won't come out, but zero fat shaming!
# =============================================
# 1205326953177202700
# ['PROVIDING EXPERIENCES']
# @_urfavforeignn That used to happen to me all the time, only thing that helped was an iud
# =============================================
# 1059239731278630900
# ['DISCOURSE']
# @TheMercedezXXX @LittleMissLizz @PPFA @cmclymer nah, a keeper is a man who dresses as an IED DISGUISED as an IUD.
# =============================================
# 1090043015715004400
# ['PROVIDING EXPERIENCES']
# @lexin0va I have the Kyleena. It’s the smallest hormonal IUD they have (they recommend this one for women that haven’t had children yet). The only side effects I’ve really had was when it was first measured I’d get random uterine cramps but now don’t think about it at all, it’s a miracle.
# =============================================
# 673991608883388400
# ['PROVIDING EXPERIENCES']
# @_courtneee Lls Nexplanon! Yea This Convenient Cuz I Aint Gotta Worry Bout Taking Pills,Shots,Or Switching Patches 👌🏾
# =============================================
# 1114246598249406500
# ['PROVIDING INFORMATIONAL SUPPORT']
# @thotpatrolavril @RobChristie11 Here's a novel idea gals..get an IUD..it'Asmall device thats inserted@mouthOfwomb.MineWasCalled'Lippies Loop'..can be left in indefinitely..no side effects&amp;can be removed@any time..no pill2make Usick,bloated,gain wt.,U literally haveNO RESPONSIBILITY! Is THAT EASY ENOUGH4You????
# =============================================
# 105756176712613890
# ['PROVIDING EXPERIENCES']
# @Shir_MerDer - I get migraines so I got an IUD - no more period no more migraines :D
# =============================================

# %%
final_dicts = []
for _id, _labels in id_majority_labels_dict.items():
    for _label in _labels:
        final_dicts.append({'ID': _id,
                            'Label': _label,
                            'Text': id_text_dict[_id],
                            'Source': 'twitter-replies',
                            'Decision': 'two or more'})
final_df = pd.DataFrame(final_dicts)
final_df.to_csv(data_directory_path + '/labeling/majority.twitter_replies.csv')

# %% [markdown]
# <br><br>
#
# # Calculate agreement

# %%
import nltk
from nltk.metrics import agreement
from nltk.metrics.agreement import AnnotationTask
from nltk.metrics import masi_distance

# %%
target_df = combined_df[combined_df['Source'] == 'reddit-posts']
target_df['Label'].value_counts()
# Out:
# SEEKING INFORMATIONAL SUPPORT      908
# SEEKING EXPERIENCES                502
# SEEKING EMOTIONAL SUPPORT          301
# PROVIDING EXPERIENCES              102
# DISCOURSE                           13
# PROVIDING INFORMATIONAL SUPPORT     12
# PROVIDING EMOTIONAL SUPPORT         11
# Name: Label, dtype: int64

# %%
target_df = combined_df[combined_df['Source'] == 'reddit-posts']
target_labels = ['SEEKING INFORMATIONAL SUPPORT', 'SEEKING EXPERIENCES', 'SEEKING EMOTIONAL SUPPORT', 'PROVIDING EXPERIENCES']

ids_labeled_by_roz = list(set([r['ID'] for i, r in target_df.iterrows() if r['Labeler'] == 'Roz']))

id_labeler_labels_dict = defaultdict(lambda: defaultdict(list))
for i, r in target_df.iterrows():
    if r['ID'] in ids_labeled_by_roz and r['Label'] in target_labels:
        id_labeler_labels_dict[r['ID']][r['Labeler']].append(r['Label'])

task_data = []
for _id, _labeler_labels_dict in id_labeler_labels_dict.items():
    for _labeler, _labels in _labeler_labels_dict.items():
        task_data.append((_labeler, _id, frozenset(_labels)))

task = AnnotationTask(distance = masi_distance)
task.load_array(task_data)
task.alpha()
# Out:
# 0.6169686157184409

# %%
target_df = combined_df[combined_df['Source'] == 'reddit-comments']

ids_labeled_by_roz = list(set([r['ID'] for i, r in target_df.iterrows() if r['Labeler'] == 'Roz']))

id_labeler_labels_dict = defaultdict(lambda: defaultdict(list))
for i, r in target_df.iterrows():
    if r['ID'] in ids_labeled_by_roz:
        id_labeler_labels_dict[r['ID']][r['Labeler']].append(r['Label'])

task_data = []
for _id, _labeler_labels_dict in id_labeler_labels_dict.items():
    for _labeler, _labels in _labeler_labels_dict.items():
        task_data.append((_labeler, _id, frozenset(_labels)))

task = AnnotationTask(distance = masi_distance)
task.load_array(task_data)
task.alpha()
# Out:
# 0.6221652101674353

# %%
target_df = combined_df[combined_df['Source'] == 'twitter-posts']

ids_labeled_by_roz = list(set([r['ID'] for i, r in target_df.iterrows() if r['Labeler'] == 'Roz']))

id_labeler_labels_dict = defaultdict(lambda: defaultdict(list))
for i, r in target_df.iterrows():
    if r['ID'] in ids_labeled_by_roz:
        id_labeler_labels_dict[r['ID']][r['Labeler']].append(r['Label'])

task_data = []
for _id, _labeler_labels_dict in id_labeler_labels_dict.items():
    for _labeler, _labels in _labeler_labels_dict.items():
        task_data.append((_labeler, _id, frozenset(_labels)))

task = AnnotationTask(distance = masi_distance)
task.load_array(task_data)
task.alpha()
# Out:
# 0.6007451355858668

# %%
target_df = combined_df[combined_df['Source'] == 'twitter-replies']

ids_labeled_by_roz = list(set([r['ID'] for i, r in target_df.iterrows() if r['Labeler'] == 'Roz']))

id_labeler_labels_dict = defaultdict(lambda: defaultdict(list))
for i, r in target_df.iterrows():
    if r['ID'] in ids_labeled_by_roz:
        id_labeler_labels_dict[r['ID']][r['Labeler']].append(r['Label'])

task_data = []
for _id, _labeler_labels_dict in id_labeler_labels_dict.items():
    for _labeler, _labels in _labeler_labels_dict.items():
        task_data.append((_labeler, _id, frozenset(_labels)))

task = AnnotationTask(distance = masi_distance)
task.load_array(task_data)
task.alpha()
# Out:
# 0.6241422358848049

# %%
import pingouin as pg

# %%
target_df = combined_df[combined_df['Source'] == 'twitter-replies']

ids_labeled_by_roz = list(set([r['ID'] for i, r in target_df.iterrows() if r['Labeler'] == 'Roz']))
id_labeler_labels_dict = defaultdict(lambda: defaultdict(list))
for i, r in target_df.iterrows():
    if r['ID'] in ids_labeled_by_roz:
        id_labeler_labels_dict[r['ID']][r['Labeler']].append(r['Label'])

labels_dicts = []
for _id, _labeler_labels_dict in id_labeler_labels_dict.items():
    for _labeler, _labels in _labeler_labels_dict.items():
        labels_dicts.append({'Labeler': _labeler,
                             'Item': _id,
                             'Labels': _labels})
labels_df = pd.DataFrame(labels_dicts)

icc = pg.intraclass_corr(data=labels_df, 
                         targets='Item', 
                         raters='Labeler',
                         ratings='Labels')

icc
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-203-810f37a2197b> in <module>
#      18                          targets='Item',
#      19                          raters='Labeler',
# ---> 20                          ratings='Labels')
#      21
#      22 icc
#
# ~/opt/anaconda3/envs/python3.7env/lib/python3.7/site-packages/pingouin/reliability.py in intraclass_corr(data, targets, raters, ratings, nan_policy)
#     266
#     267     # Convert data to wide-format
# --> 268     data = data.pivot_table(index=targets, columns=raters, values=ratings)
#     269
#     270     # Listwise deletion of missing values
#
# ~/opt/anaconda3/envs/python3.7env/lib/python3.7/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    7039             dropna=dropna,
#    7040             margins_name=margins_name,
# -> 7041             observed=observed,
#    7042         )
#    7043
#
# ~/opt/anaconda3/envs/python3.7env/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#     111
#     112     grouped = data.groupby(keys, observed=observed)
# --> 113     agged = grouped.agg(aggfunc)
#     114     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     115         agged = agged.dropna(how="all")
#
# ~/opt/anaconda3/envs/python3.7env/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     943         func = maybe_mangle_lambdas(func)
#     944
# --> 945         result, how = aggregate(self, func, *args, **kwargs)
#     946         if how is None:
#     947             return result
#
# ~/opt/anaconda3/envs/python3.7env/lib/python3.7/site-packages/pandas/core/aggregation.py in aggregate(obj, arg, *args, **kwargs)
#     577
#     578     if isinstance(arg, str):
# --> 579         return obj._try_aggregate_string_function(arg, *args, **kwargs), None
#     580     elif is_dict_like(arg):
#     581         arg = cast(AggFuncTypeDict, arg)
#
# ~/opt/anaconda3/envs/python3.7env/lib/python3.7/site-packages/pandas/core/base.py in _try_aggregate_string_function(self, arg, *args, **kwargs)
#     313         if f is not None:
#     314             if callable(f):
# --> 315                 return f(*args, **kwargs)
#     316
#     317             # people may try to aggregate on a non-callable attribute
#
# ~/opt/anaconda3/envs/python3.7env/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only)
#    1497             "mean",
#    1498             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
# -> 1499             numeric_only=numeric_only,
#    1500         )
#    1501
#
# ~/opt/anaconda3/envs/python3.7env/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1014     ) -> DataFrame:
#    1015         agg_mgr = self._cython_agg_blocks(
# -> 1016             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#    1017         )
#    1018         return self._wrap_agged_blocks(agg_mgr.blocks, items=agg_mgr.items)
#
# ~/opt/anaconda3/envs/python3.7env/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1119
#    1120         if not len(new_mgr):
# -> 1121             raise DataError("No numeric types to aggregate")
#    1122
#    1123         return new_mgr
#
# DataError: No numeric types to aggregate
