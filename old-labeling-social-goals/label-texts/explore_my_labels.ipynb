# %% [markdown]
# # Instructions
#
# Use "prodigyEnv" conda environment for this notebook.
#
# To set up Prodigy environment, download the wheel file from the Prodigy email (which you receive after purchasing a license).
#
# Then run `pip install ./prodigy*.whl`
#
# Instructions: https://prodi.gy/docs/install
#
# Database is stored at /

# %% [markdown]
# <br><br>
#
# # Imports

# %%
from collections import defaultdict
import random

import pandas as pd
from prodigy.components.db import connect

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='ticks', font_scale=1.2)

# %%
def sort_by_mean(df, by, column, rot=0):
    # use dict comprehension to create new dataframe from the iterable groupby object
    # each group name becomes a column in the new dataframe
    df2 = pd.DataFrame({col:vals[column] for col, vals in df.groupby(by)})
    # find and sort the median values in this new dataframe
    means = df2.mean().sort_values()
    # use the columns in the dataframe, ordered sorted by median value
    # return axes so changes can be made outside the function
#     return df2[meds.index].boxplot(rot=rot, return_type="axes")
    return means

# %% [markdown]
# <br><br>
#
# # Connect to database

# %%
db = connect()

db.datasets # This will list all of your prodigy databases
# Out:
# ['book-graph',
#  'book-graph-ethics',
#  'book-graph-structure',
#  'book-graph-humor-romance',
#  'birth-control',
#  'birth-control-webmd',
#  'birth-control-reddit',
#  'birth-control-all-labels-reddit',
#  'birth-control-all-labels-twitter',
#  'birth-control-all-labels-webmd',
#  'birth-control-reddit-discourse',
#  'birth-control-all-labels-reddit-comments',
#  'birth-control-all-labels-twitter-posts',
#  'birth-control-all-labels-twitter-replies',
#  'birth-control-all-labels-reddit-extra']

# %%
# db.drop_dataset('birth-control-all-labels-twitter')  # Only do this if you want to delete all your annotations!!!!!!!!!!!

# %% [markdown]
# <br><br>
#
# # Explore REDDIT comments

# %%
examples = db.get_dataset('birth-control-all-labels-reddit-comments')

print(len(examples))
# Out:
# 500

# %%
label_count_dict = defaultdict(int)
label_texts_dict = defaultdict(list)
for e in examples:
    for _label in e['accept']:
        label_count_dict[_label] += 1
        label_texts_dict[_label].append(e['text'])

print('------------------------------------------------------')
print('total number of posts labeled')
print('[out of 4,395 total]')
print('------------------------------------------------------')
print()
for _label, _count in sorted(label_count_dict.items(), key=lambda x: x[1], reverse=True):
    print(_count, '\t', _label)
# Out:
# ------------------------------------------------------
# total number of posts labeled
# [out of 4,395 total]
# ------------------------------------------------------
#
# 270 	 PROVIDING INFORMATIONAL SUPPORT
# 243 	 PROVIDING EXPERIENCES
# 64 	 PROVIDING EMOTIONAL SUPPORT
# 40 	 DISCOURSE
# 8 	 SEEKING EMOTIONAL SUPPORT
# 7 	 SEEKING INFORMATIONAL SUPPORT
# 7 	 SEEKING EXPERIENCES

# %%
label_percent_dict = {_label: _count/float(len(examples)) for _label, _count in label_count_dict.items()}

print('------------------------------')
print('percent of posts with label')
print('------------------------------')
print()
for _label, _percent in sorted(label_percent_dict.items(), key=lambda x: x[1], reverse=True):
    print(str(round(_percent*100, 1)) + '%', '\t', _label)
# Out:
# ------------------------------
# percent of posts with label
# ------------------------------
#
# 54.0% 	 PROVIDING INFORMATIONAL SUPPORT
# 48.6% 	 PROVIDING EXPERIENCES
# 12.8% 	 PROVIDING EMOTIONAL SUPPORT
# 8.0% 	 DISCOURSE
# 1.6% 	 SEEKING EMOTIONAL SUPPORT
# 1.4% 	 SEEKING INFORMATIONAL SUPPORT
# 1.4% 	 SEEKING EXPERIENCES

# %%
for _label, _texts in label_texts_dict.items():
    if _label == 'DISCOURSE':
        print('===========================================')
        print(_label)
        print('===========================================\n')
        for e in _texts:
            print(e)
            print('\n-------------------------------------------\n')
        print()
# Out:
# ===========================================
# DISCOURSE
# ===========================================
#
# Holy fucking smokes. Now I appreciate the doctor who dangled the old IUD that she removed before my eyes way more.
#
# -------------------------------------------
#
# I would think because it sounds like she’s already made up her mind about keeping the babies- so it’s kind of like someone asking “are you sure?” to someone to has made up their mind about an abortion.
#
# However, I completely agree with this post and agree that these are all extremely valid points. Everyone jumps to congratulate someone being pregnant even though it is very likely not a great situation. I just hope OP has a support system.
#
# -------------------------------------------
#
# Do you say that to patients who ask questions that have been asked millions of times too?
#
# -------------------------------------------
#
# Haha yeah, that's the point you switched to once your statement that "perfect use for pills is not 99.7% effective" was proven wrong.
#
# -------------------------------------------
#
# Men’s problems (including pain) are always treated more attentively than women’s problems (even by female doctors).
#
# UGH, indeed.
#
# -------------------------------------------
#
# Happy to help!
#
# -------------------------------------------
#
# Is this satire?
#
# -------------------------------------------
#
# Sure, no problem. My misunderstanding. Could I get a clarification about whether it’s okay to tell other users that they’re “going to get pregnant” based on their chosen method?
#
# -------------------------------------------
#
# I love it till that happened 😭
#
# -------------------------------------------
#
# Amen to that!
#
# -------------------------------------------
#
# Thank you again!
#
# -------------------------------------------
#
# Glad to hear your experience has been so positive. Appreciate your reply so much! Hope you’re doing well!
#
# -------------------------------------------
#
# Haha yeah me too! 😂
#
# -------------------------------------------
#
# This is not true, pap smear do show a false positive result a lot of the time, especially in young women.
# And please do not tell young women who are apprehensive about having their gentials prayed open and fingered by a stranger to seek therapy because clearly they are mentally ill if they have a problem with that. Plenty of women chose not to get pap smears becuase they're invasive and painful and there is nothing mentally wrong with them.
#
# -------------------------------------------
#
# &gt; I don't think that a teenager knows her body enough to check the strings, to feel the cervix or to know if the IUD is in the right position.
#
# That is assuming that most people even check the strings. If a teenager is mature enough to engage in a sexual relationship, they're also mature enough to stick a finger up and check the strings. It's really not rocket science. My point wasn't that all teenagers should get IUDs, but that it's not important to have children before getting IUDs, and that *even* teenagers can get them.
#
# &gt;There were lots of posts with the IUD perforating the uterus.
#
# Except that has nothing to do with whether the patient has children or not. Perforation occurs due to error of the gynecologist. That being said, once the "escape hatch" heals up, one is free to have children. It does not lead to infertility.
#
# I understand that it's not for *you*, but you presented it as almost a general thing, and that may scare other people from getting it too.
#
# -------------------------------------------
#
# I've never heard a good urgent care story. I'm honestly starting to think that the doctors who can't get jobs anywhere else just go to urgent care.
#
# -------------------------------------------
#
# I agree completely! It’s terrible how little we’re taught about this stuff.
#
# To be fair, it would be extremely difficult to test per-encounter likelihoods - I’m not even sure how it would be practically possible to design a study like that.
#
# However, we do know that outside a woman’s fertile window the probability is 0% - it’s a physical impossibility, not simply unlikely. The difficulty is figuring out when the window is.
#
# -------------------------------------------
#
# Thank you so much for this info!!
#
#
# -------------------------------------------
#
# You have asked this question many times in a number of different subs, and gotten the same answer multiple times.
#
# From your posts here you seem quite immature with regards to sexual matters. You need to sit down with a healthcare professional that can discuss all of this with you. You don’t seem to be satisfied with the answers Reddit users are giving you, so you need to sit down with someone of authority you will trust.
#
# -------------------------------------------
#
# There is a Tedx Talk video on YouTube called "The Surprising Link Between Women's Brians and the Birth Control Pill by Sarah E. Hill. She mentions how women are attracted to different features when they are on the pill compared to other features when they are off it. She also wrote a book called "This is Your Brain on Birth Control".
#
# -------------------------------------------
#
# I had jaydess ( which is even less hormones than kyleena) and personally I had to take it out after one year because I went from a bit anxious mostly normally functioning person to being diagnosed with MDD, GAD,  attempting suicide and going on medical leave from being a student in a professional healthcare program.
#
#  As soon as I took out my IUD within 3 months I discontinued all 3 of my psychiatric medications ( I was on wellbutrin, mirtazapine and propranolol for the tension headaches my anxiety caused), taking it out made me feel like I got my life back.
#
# While I was so unstable I saw multiple doctors and psychiatrists and not a single one of the suspected the IUD or even paid attention to it. I highly highly recommend you ( or anyone else considering an IUD) go and **read the monograph for the product**.
#
#  Just control find ( ctrl + F and search for depression).
#
# [https://www.bayer.ca/omr/online/kyleena-pm-en.pdf](https://www.bayer.ca/omr/online/kyleena-pm-en.pdf)
#
# **The notion that hormones in an IUD act only locally is not true, the monograph clearly states "** Psychiatric Patients with a history of emotional disturbances, especially the depressive type, may be more prone to have a recurrence of depression while using KYLEENA. In cases of a serious recurrence, consideration should be given to removing KYLEENA, since the depression may be drug-related. "
#
# &amp;#x200B;
#
# Of course, this was only my experience but I just want **all patients to make an informed decision** regarding birth control and I feel as though I did not. It was wild that the monograph for the product was only given to me in a little 94pg booklet after the IUD was installed.
#
# &amp;#x200B;
#
# I am not against birth control, I think its extremely empowering and has revolutionized our society, however as any other drug its  potential side effects in *certain populations*  should not be taken lightly.
#
# &amp;#x200B;
#
# &amp;#x200B;
#
# -------------------------------------------
#
# People go on internet to complain...
#
# -------------------------------------------
#
# I know what she means, I said she said most women don’t see side effects because it’s “localized”. My doctor acknowledged that some women get side effects from it still. I was just saying to OP that that’s why doctors recommend it, at least in my doctors case cause of the belief that it’s less likely to react to it
#
# -------------------------------------------
#
# Removed as the copper IUD can not cause depression.
#
# That is an internet myth similar to the anti vaccines myth.
#
# -------------------------------------------
#
# Her history doesn’t mean he lacks body autonomy, which is what you are saying.
#
# -------------------------------------------
#
# I understand where you’re coming from but I do think this was a fair way to see if it was a real issue. If he said he could still feel it after the “trim” then you know it’s a genuine problem that will need addressed.
#
# If the doctor had suggested saying a new IUD was inserted after one was removed (meaning OP was not on birth control but saying she was), I would wholeheartedly agree that that deception is not a good, conscientious choice.
#
# -------------------------------------------
#
# Haha for real! Men have it so easy. Don't feel bad about freaking me out, I have long enough to forget my fears before it happens. I sincerely hope the IUD works out for you! When birth control is causing a suckfest, I try to remember it's better than getting pregnant.
#
# -------------------------------------------
#
# Your post is currently pending mod approval.
#
# *I am a bot, and this action was performed automatically. Please [contact the moderators of this subreddit](/message/compose/?to=/r/birthcontrol) if you have any questions or concerns.*
#
# -------------------------------------------
#
# Well, first of all, no, why would it?
#
# Second,
# &gt;everyone knows looking young=ugly.
#
# No. You might want to change that mindset first. Why is everyone "hating you for looking young"? This makes no sense. I swear, except for teenagers, nobody I know wants to look "their age", and looking younger has always been a compliment in my books.
#
# -------------------------------------------
#
# It's hard to pinpoint *why* they happen. The cause is there, but the reason why they happen is hard to find out. Besides, they don't happen to everyone, and the ones who encounter said side effects might actually have different reasons why they're triggered.
#
# Why they don't change it? Because they have to go through all the hoops of FDA all over again. That's why they don't even change the warnings about antibiotics, because they need studies to back that up and the funding and participants and actually people who *want* to make the study is scarce. Besides, a lot of women will still trust a pill that has been there for a long time compared to something that just came out.
#
#  Back in the day when the female pill was invented, there weren't so many hoops to jump through to approve something, and some side effects were just "it doesn't kill you? then it's okay". Even if stricter rules came, they can't retroactively re-test every single product on the market, birth control or not, to see if it fits - if it was approved before and they didn't get crazy complaints about it, they're not gonna change it.
#
# -------------------------------------------
#
# ^^^ so true, whenever things go awful we want everybody and their mother to know but when things go good we just move on with our lives lol
#
# -------------------------------------------
#
# It’s stories like this that makes me terrified of iuds. A friend of mine has the skyla and loves it but I’m too scared I’ll be one of those people where something goes horribly wrong. I personally prefer methods that I can stop/start on my own at any time without any help. I just feel more at ease that way, though unfortunately there aren’t all that many options for that, especially if you also want a method that doesn’t alter your body chemistry (which eliminates basically all hormonal methods). So with that altogether I have like half the options and some aren’t all that great (ie nonoxynol 9 is literally evil and felt like bleach being poured into my body!). I wish there was more awareness about these options and more effort to expand and improve these methods. Some women can’t use hormones and some just don’t want them, but they’re often much easier to get than things like diaphragms
#
# -------------------------------------------
#
# Hi, there!
#
# I approved your post as it is on topic and you seem human; *however*, your account seems to be shadowbanned. Admins (not Mods) used to shadowban humans for breaking Sitewide rules, but have since changed their policy and don't currently shadowban humans (only bots or those that act like bots), For more info or "what to do", check out /r/ShadowBan/
#
# But until the Admins un shadowban you, no one can see what you post or comment.
#
#
#
# -------------------------------------------
#
# Or when you go to toss it back with some water, but you don't feel it go down because you drank too much water and now you're paranoid for some reason.
#
# -------------------------------------------
#
# I’m confused ... why is your roommate deciding how heavy your periods are? Are you saying Mirena helped, but your bleeding is heavier than hers? Does she naturally have normal / light periods?
#
# -------------------------------------------
#
# The ashlyna packets are so terrible because they are literally impossible to get out!!
#
# -------------------------------------------
#
# 22 Female USA. I really hope male birth control becomes as big and varied as female bc. If we had more options other than a vasectomy or condoms then it would help so much to alleviate the stress of having to guard against unplanned/unwanted pregnancies. I have an IUD and I always stress that I’ll be in that 1% that do get pregnant with it.
#
# -------------------------------------------
#
# Why do you need to force her to take plan b if she’s been on effective birth control for 4 years?
#
# -------------------------------------------
#
# You are being very discouraging of the OP. Do not make her feel like she's crazy. It may very well be her BC and it is 100% up to her. Your comment makes it seem like bc is the only option and something is wrong with her. That isn't okay.
#
# -------------------------------------------
#
# I'm always curious about these posts where someone sees bleeding and thinks it's evidence of pregnancy. This is *never* logical. Bleeding in pregnancy is rare. All kinds of bleeding are far more common in nonpregnant women than pregnant women. "Implantation bleeding" only happens in about 9% of pregnancies, and not actually around the time of implantation but around the time of expected period - so it does not actually have to do with implantation. A higher percentage than that of women have spotting around the time of their period when they are not pregnant, so it's likely that those 9% would have had bleeding then even if they were not pregnant.
#
# Basically, it seems like the lines got crossed somewhere between "a minority of women bleed even when they are pregnant - isn't that crazy?" (true) to "bleeding is evidence of pregnancy" (false). It's actually the opposite: ANY bleeding is evidence of nonpregnancy. Not definitive evidence, but evidence nonetheless.
#
# Using the pill and condoms correctly, I did the math and it's about 80 times more likely you'll get cancer than pregnant.
#
# -------------------------------------------

# %% [markdown]
# <br><br>
#
# # Explore REDDIT posts

# %%
examples = db.get_dataset('birth-control-all-labels-reddit')

print(len(examples))
# Out:
# 500

# %%
label_count_dict = defaultdict(int)
label_texts_dict = defaultdict(list)
for e in examples:
    for _label in e['accept']:
        label_count_dict[_label] += 1
        label_texts_dict[_label].append(e['text'])

print('------------------------------------------------------')
print('total number of posts labeled')
print('[out of 4,395 total]')
print('------------------------------------------------------')
print()
for _label, _count in sorted(label_count_dict.items(), key=lambda x: x[1], reverse=True):
    print(_count, '\t', _label)
# Out:
# ------------------------------------------------------
# total number of posts labeled
# [out of 4,395 total]
# ------------------------------------------------------
#
# 355 	 SEEKING INFORMATIONAL SUPPORT
# 170 	 SEEKING EXPERIENCES
# 123 	 SEEKING EMOTIONAL SUPPORT
# 32 	 PROVIDING EXPERIENCES
# 5 	 PROVIDING INFORMATIONAL SUPPORT
# 4 	 PROVIDING EMOTIONAL SUPPORT
# 4 	 DISCOURSE

# %%
print(examples[0])
# Out:
# {'text': '[TITLE: starting/getting birth control online with online health center?] \n\nNew to all things birth control. Well, except condoms. Which my bf and I have been using up until this point. However, we both would like to ditch them or at least go without them once in awhile so I\'m looking into birth control and ways to obtain it.  My preferred choice would be those ones implanted in the arm that I\'ve read about, but due to expenses and being a poor college student at the moment... the pill seems as though the better solution to go for now. \n\nSo being that I\'ll be at college without a mode of transportation and just overall being a socially awkward person that doesn\'t like to go to new places and talk to strangers all that often... I was quite intrigued in finding out Planned Parenthood has an Online Health Center and I was wondering if anyone here uses this or can give me any and all information about it? \n\n-If one has never gone in for an appt. before and has never been on BC, can this whole online visit + fee after filling out information really get you prescribed something? It *does* say on their site "It\'s a great option if you want to get started on the pill but haven\'t had a chance to book an appointment!"  ... What about if you just don\'t want to book an appointment? (Well, unless I\'d start having issues that would needed to be discussed.)\n\n-Would they provide you with all details you should know about BC or even the specific kind you decide on? If not, would a simple question to their "Ask a Nurse" portion of the site provide such answers? Or would it be best to head to google and look for multiple resources?\n\nI guess overall I\'m just wondering if it\'s a decent route to go for someone like myself, am trying to understand what it all entails, and would like to hear from anyone who uses it.', 'meta': {'ID': '1jsiij', 'Source': 'reddit'}, '_input_hash': -1336985457, '_task_hash': 1916818944, 'options': [{'id': 'SEEKING INFORMATIONAL SUPPORT', 'text': 'SEEKING INFORMATIONAL SUPPORT'}, {'id': 'PROVIDING INFORMATIONAL SUPPORT', 'text': 'PROVIDING INFORMATIONAL SUPPORT'}, {'id': 'SEEKING EMOTIONAL SUPPORT', 'text': 'SEEKING EMOTIONAL SUPPORT'}, {'id': 'PROVIDING EMOTIONAL SUPPORT', 'text': 'PROVIDING EMOTIONAL SUPPORT'}, {'id': 'SEEKING EXPERIENCES', 'text': 'SEEKING EXPERIENCES'}, {'id': 'PROVIDING EXPERIENCES', 'text': 'PROVIDING EXPERIENCES'}, {'id': 'DISCOURSE', 'text': 'DISCOURSE'}], '_session_id': None, '_view_id': 'choice', 'config': {'choice_style': 'multiple'}, 'accept': ['SEEKING INFORMATIONAL SUPPORT', 'SEEKING EXPERIENCES'], 'answer': 'accept'}

# %%
label_percent_dict = {_label: _count/float(len(examples)) for _label, _count in label_count_dict.items()}

print('------------------------------')
print('percent of posts with label')
print('------------------------------')
print()
for _label, _percent in sorted(label_percent_dict.items(), key=lambda x: x[1], reverse=True):
    print(str(round(_percent*100, 1)) + '%', '\t', _label)
# Out:
# ------------------------------
# percent of posts with label
# ------------------------------
#
# 71.0% 	 SEEKING INFORMATIONAL SUPPORT
# 34.0% 	 SEEKING EXPERIENCES
# 24.6% 	 SEEKING EMOTIONAL SUPPORT
# 6.4% 	 PROVIDING EXPERIENCES
# 1.0% 	 PROVIDING INFORMATIONAL SUPPORT
# 0.8% 	 PROVIDING EMOTIONAL SUPPORT
# 0.8% 	 DISCOURSE

# %%
for _label, _texts in label_texts_dict.items():
    if _label == 'SEEKING EMOTIONAL SUPPORT':
        print('===========================================')
        print(_label)
        print('===========================================\n')
        for e in _texts:
            print(e)
            print('\n-------------------------------------------\n')
        print()
# Out:
# ===========================================
# SEEKING EMOTIONAL SUPPORT
# ===========================================
#
# [TITLE: took pill for 26 days - am i safe to start my placebo week?]
#
# Hey everybody! I'll try to make to make this very short -
#
# I'm in a LDR, I recently visited my lovely partner and the last time we've had unprotected intercourse was the night of the 21st to the 22nd of July. I should've already been on my placebo week then, but didn't want to deal with my mood swings while I was with him.
#
# Will I be protected if I take my 7 days of placebo week again starting on Saturday? This might be a no-brainer, sorry, but I just wanted to make sure! After that period, I'll start a new full blister and keep the started one for backup.
#
# Many thanks!
#
# -------------------------------------------
#
# [TITLE: nervous about starting birth control for the first time (lo loestrin fe)]
#
# I am supposed to start taking Lo Loestrin Fe today but I am really nervous about the side effects. I have never taken any birth control before so I don’t have anything to compare it to. I felt good about it when I left my gyno but have becoming more anxious about it since. I also made the mistake of reading all the bad reviews for this particular pill and now I am even more freaked out.
# Has anyone taken Lo Loestrin Fe? Did you have a positive or negative reaction! Should I be this worried?
#
# -------------------------------------------
#
# [TITLE: fighting with gyno about ortho micronor (mini pill)]
#
# I will try make this short and sweet. I switched to Ortho Micronor (mini pill) due to migraines and moved to a different state. The new Gyno prescribed Gildess FE 1/20 (combination pill). When I picked it up from CVS, I knew it wasn't right and called the Gyno. His nurse said, "it's the same and Ortho Micrnor is ONLY for those breastfeeding." I couldn't understand why I had been given it before. I called the previous Gyno nurse and she said, "They're the same pill, you're okay." I said fine and took it.
#
# Flash forward to this week (placebo week) and I've had a migraine for the past 4 days. I called to switch back and they're making me come in person to talk about my options since they refuse to put me back on Ortho Micronor since it's "only for breast feeding."
#
# Can someone please help me defend myself to him that I want to take the mini pill and not have an IUD/implant? Is OM exclusively for those breast feeding?
#
# I'm desperate to get rid of these migraines and have a gyno listen to me again. Thank you!
#
# -------------------------------------------
#
# [TITLE: going crazy thinking i’m pregnant. could it be?]
#
# So, I’m actually sweating because I’m scared as fuck I could be pregnant.
# I took the pill after the 7 days of stop eight days ago. First pill I didn’t have water with me and couldn’t take it. It melted a bit in my mouth then I reached home and took it with water, even if it crumbled a bit paid attention to take it all and nothing remained.
#
# Kept keeping it each day same hour until yesterday I felt a little bit of white discharge. Before pill I used to have ovulation but like A LOT, sometimes I had to put a pad!
# In the last two days I had a small bit of discharge but still I’m so scared! I didn’t think much about the first pill since I paid attention to not leave any crumble in the tablet and the parts that melted were actually in my mouth so...
# Now I think I might have been very dumb to have sex anyway.
# Do you think I could be pregnant? What can I do now?
# Please, please give me your opinion.
#
# -------------------------------------------
#
# [TITLE: help me]
#
# okay so i might just be overreacting but like please help! so today i got the implant inserted and everything was all good except i got called into work and so i showed up because my job doesn’t require me to lift heavy stuff up which was the only thing they warned me about. however throughout the day i noticed that the gauze was placed from the insertion point to only the middle of the implant causing the other end to pop out. i didn’t want to move the gauze so i kept working with it like that. however as the day came to an end it became extremely sore to the point where it was painful to move my arm. is this normal? or it it possible that it snapped? i’m just really freaking out. should i fix the gauze? it’s really tight on my arm so could that have snapped it since it was only covering half of the implant and there was a lot of moving around? i’m off now and the pain went down but there’s like shockwaves of heat and pain that go throughout my arm. how can i check if it’s broken once i remove the gauze?
#
# -------------------------------------------
#
# [TITLE: could i be pregnant?]
#
# This is my first month on birth control and I switched birth controls after the first few weeks and started another and am now on the placebo pills. Tonight is my third placebo pill but I have not gotten my period. I sometimes have taken the pill 2 hours late maximum but it is mixed hormone so I didn’t think it was a major problem. I started having sex on my 9th day on the new pills with condoms although some of the condoms got stuck in me when he pulled out leaving me to think that it possibly came off during, which means cum could’ve gotten inside me. Am I pregnant? I’m worried that me not getting it means I’m pregnant but I’ve also heard that can b normal?
#
# -------------------------------------------
#
# [TITLE: completely overwhelmed and completely new to birth control options]
#
# Hi,
#
# I have birth control pills (Mylan) and I'm currently sexually active. I had plan b fuck my cycle last time but I want to get protected asap and want to start taking pills soon as possible.
#
# My last period was from 23rd Jul- 28th Jul. Then I took plan B on the 28th then got my "period" on the 4th Aug - 8th Aug. Super weird. Anyway, I want to get started on the pills asap.
#
# Would it be okay to start taking Mylan starting today?
#
# Also, would I get my periods (whenever that is) and do I continue taking pills when I get the period? And how would the placebo pills work in this case?
#
# I will definitely be visiting a planned parenthood center but I want to know what I'm walking into so any information on this would be very helpful. Thank you very much.
#
# -------------------------------------------
#
# [TITLE: nightly leg cramps on lo loestrin fe]
#
# I’m not sure if this is a side effect of my birth control or something that is just happening. I’m at the end of my second month and I’ve been having bad calf leg cramps at night. And that’s got me worried that I could have a blood clot. I read an article about how some girls have almost died from blood clots caused from their birth control and it all started with leg cramps so now I’m freaking out! I know if could be caused from multiple things but has anyone else on this pill had any similar things happen?
#
# -------------------------------------------
#
# [TITLE: possible pregnancy with condom/pullout/period?]
#
# Me and my girlfriend had sex almost 3 weeks ago for the first time since March. During quarantine she went off the pill so she was using no BC when we had sex. I used a condom, pulled out and she was on the second day of her period when we had sex. We had no more penetrative sex over the next few days and I only ejaculated on her upper body. She has been having some irregular bleeding/spotting for the last 2 and a half weeks and nausea along with intense stabbing pain. She has had irregular periods when she was younger and we were thinking this could be coming from her stopping birth control in mid March, as I’ve read weird stuff can be going on with a women’s periods for a few months after stopping BC. I’m pretty sure it’s basically impossible that she got pregnant but she is planning to take a test soon. Can anyone help to calm us down?
#
# -------------------------------------------
#
# [TITLE: panicking]
#
# So my girlfriend and I, both young adults,  recently had sex with no condom,  but I pulled out and shes on minastrin 24....should I still be freaking about possible pregnancy?
#
# -------------------------------------------
#
# [TITLE: basically having a period in the middle of my cycle (on birth control pills)]
#
# hey guys,
#
# so i'm a little bit concerned by this. i've been on the pill for 6 months, always take it on time, and have never missed a pill. i'm on my sixth pack now and i'm in the middle of the second week. since i've been on the pill, i always have a little bit of bleeding in the middle of my cycle, but nothing alarming. this time i'm bleeding a fairly large amount for what i consider normal. it's basically like a period, and it hurts like one too. i have no idea why this is happening in the middle of my cycle. i haven't missed a pill or even been late on one.
#
# my biggest fear is always pregnancy, but i'm pretty sure this isn't a symptom. it's happening right at the time i would normally be ovulating if i weren't on the pill, and that's not when implantation bleeding happens as far as i know.
#
# i really just want to make sure this doesn't mean my birth control isn't working. i do have sex at least once a week and my bf doesn't always pull out.
#
# does anyone know what this could be? is it normal or is there something wrong? is my birth control still effective? thanks!!
#
# -------------------------------------------
#
# [TITLE: iud spotting]
#
# Hi guys,
#
# I’ve had an IUD for a year now. At first I experienced a lot of pain with it to the point I was admitted to hospital because I was convinced it was put in wrong but since then my periods have become less painful but still heavy.
#
# However I haven’t had any spotting when I’ve not been on my period.
#
# Fast forward to a year later (now) I’m bleeding in between periods (well, only one, which is right now), probably enough to fill a couple liners a day at most and it’s kind of on and off. Is this anything to be worried about or is this normal? It’s only worrying me because it’s never happened before only just now?
#
# Any advice will be appreciated. I’m gonna check the strings when I have a shower next.
#
# Thanks! X
#
# -------------------------------------------
#
# [TITLE: weird occurrences on nexplanon... please help!!]
#
# Okay. So this is going to be a long post, but I need to make sure I can explain everything to get the best answer(s) possible. Any response helps me a lot! (I am a 21 year old female college student)
# [TITLE: sex on the 7th day after mirena - did i mess up severly?]
#
# I had my Mirena inserted on Thursday 5th at 9am, and had unprotected sex on the following Thursday 12th at around 11pm. I had a complete mind blank when calculating the 7 days after insertion even though my OB STRESSED That I should use a barrier method till then. Does anyone have any experience with this? I have a feeling I might be over reacting, but I will take a pregnancy test at the right time regardless.
#
# -------------------------------------------
#
# [TITLE: getting nexplanon before my period?]
#
# I'm having Nexplanon inserted this Thursday, the 13th, but I don't start my period til Sept. 23rd. Is this okay? I know they say you can have it inserted at any point in your cycle, but I'm just nervous about side effects. Thanks for any advice!
#
# -------------------------------------------
#
# [TITLE: i need reassurance.]
#
# I’ve been on the pill for about a year and a half and I’m just about ready to stop taking them. This has not been a positive experience for me at all.
#
# I am a completely different person. I don’t ever feel happy, I cry just about daily, and the mood swings are worse than a rollercoaster. My personality has mellowed out and I’m either feeling fine or I’m miserable, happy is not an emotion I feel anymore. I think I’ve mentally convinced myself that I hate sex and I’m not into my boyfriend anymore (it’s not true). I am NEVER in the mood, with him or just by myself. Sex is painful now because I can never get wet enough. Lube has become my best friend, but it doesn’t clear the mental fog I have so it’s obvious I’m not really ever in the mood.
#
# I am always so agitated, like a low-anger all the time. I feel like there is always a slight flame lit inside me and it’s like the flip of a switch to turn it into a roaring campfire. 0-100 real quick, all the time.
#
# I was hesitant to go on the in the first place and basically only did for peace of mind. We’ve been together for 4 years and there was a 2.5ish year period of time where I wasn’t using BC. I am TERRIFIED of becoming or being pregnant. I’m also terrified of my boyfriend “releasing” inside me. If there was a phobia-type term for all that, I have it. Even on the pill we still use condoms. Now I’m terrified to go off of the pill. Part of me worries I’ll get pregnant, the other part worries that maybe all these issues aren’t caused from the pill. I doubt the latter is the case but I think these pills have also messed with me so much mentally, I can’t think straight or for myself anymore.
#
# I don’t want to keep trying new pills. I don’t think the hormones are good for me. I’ve thought about the copper IUD but every part of it terrifies me. I’d rather not do it.
#
# I can’t even remember who I am off of these pills. I’d love some reassurance on what to do, or if anyone else feels or has felt the same way.
#
# -------------------------------------------
#
# [TITLE: heavy spotting on continuous bc due to stress/anxiety]
#
# I've been taking continuous birth control for the past 4 years and on the rare occasion I have spotting when i'm nearing the end of a pack, which is fine. Last week something happened in my life which is causing major stress/anxiety and I have no appetite and haven't been eating as much and since then everyday i've been having cramps and heavier than normal spotting. Maybe TMI but I can feel the tiny rush of blood coming out everyday but it's not enough to be considered a period (at least compared to how heavily I used to bleed not on birth control) but it does last most of the day.
#
# Is there anything I should be doing? Now i'm stressed out about this bleeding on top of what i'm already stressed about. I just needed to rant. :(
#
# -------------------------------------------
#
# [TITLE: is it normal to experience these things on the pill?]
#
# Hello everyone. I’ve been experiencing some side effects that have me a little concerned. Some background info:
#
# I’ve been taking the bc pill Enpresse for 3 years without issue. Enpresse is apparently a generic brand for Triphasil. Well when I went to the pharmacist this past time, they gave me Levonest 28 instead and the pharmacist was very rude and refused to order in Enpresse when I said I’d prefer it.
#
#
# -------------------------------------------
#
# [TITLE: copper iud day 3 - does it get better?]
#
# 22 years old. Never have had kids. I have been off of oral hormonal birth control pills for about 5 months (was on for about 8 years). And have been off of NuvaRing for 2 months. (Went off of hormonal because it messed with my libido too much). I got the Copper IUD put in as a form of emergency contraception (knowing I would eventually get it/try it in the future, so I kind of just bit the bullet and did it after the condom broke). But now I’m wishing i would’ve done more research. The insertion almost made me vomit. Im on day 3 and the cramps are better and not as extreme and persistent (but still there off and on), spotting still, and a crazy amount of discharge on Day 3. I know that it can cause periods to be heavy, longer, crampier etc. but holy crap will the insertion effects subside?! Is day 3 still a bit early to be worried? What was your expierence? I just imagine it never going away! Also they never told me about checking the strings? Is that something I should be doing? I got this done at Planned Parenthood. Also, what side effects should i look out for? I remember them telling me some in the moment but I was crazy nervous.
#
# -------------------------------------------
#
# [TITLE: stubborn weight gain after stopping the pill (among other symptoms)]
#
# I was on the pill for about 10 years. Over time while on the pill I began to notice that my sex drive was almost non existent regardless of my loving relationship. After reading online of how the pill can sometimes cause low libido I decided to stop taking it. The great news is my sex drive came back! However, I began to experience a slew of symptoms I attributed to coming off the pill such as nausea, bloating, and a bit of weight gain. Two weeks ago (I stopped the pill about a month ago) I started working out hard everyday and eating right to try and loose weight. However, I have seen ZERO changes to my weight (I know my body and with how hard I'm working out I should have seen a change by now) and I am constantly bloated. Anyone have any experience with this? Reading online maybe it's a hormone imbalance? How do I fix this! Help!!!!
#
# -------------------------------------------
#
# [TITLE: a ball of anxiety over iud removal...]
#
# Hey guys! I’ve just discovered this community and I’m blown away at how wonderful everyone here seems to be.
#
# So, here’s the deal. I was diagnosed with PCOS at 12. At 14, after being put on the pill to help with the PCOS symptoms, my periods started getting super heavy and lasting for months at a time. To make a long story short, I bled so much that I needed blood transfusions and had to have a D&amp;C to scrape out the contents of my uterus and stop the bleeding. I tried a few different pills and they all resulted in the same thing. I ended up having 3 D&amp;Cs, and during the last one in 2014, they placed in a Mirena IUD while I was in surgery. This really worked at stopping the bleeding and I was free to live a normal life again (Albeit, without a period).
#
# So now, I’m 21, engaged, and thinking about children in the near future. I wanted some time before we start trying to conceive to work out the kinks, figure out if I can have a normal, manageable cycle, and figure out if I actually even ovulate. I scheduled my removal for this Friday, and I have to admit, I’m nervous as hell. Every account I’ve read has either said it was super painful, or that they felt practically nothing. Almost everyone compares it to the insertion though, and because I wasn’t conscious to experience that, I have no point of reference. I’ve tried watching some technical videos to relieve some of my anxiety and nervousness, but it sends me into a full blown panic attack each time I even think about it. I have some PTSD-related issues due to the massive amounts of pain I was in after the surgeries on my uterus, so that’s definitely not helping. Finally, after dozens of OB-GYN appointments, I’m just now able to somewhat tolerate the smallest speculum they have at my office without completely panicking and freaking out.
#
# I know this is kind of an odd situation, but can anyone tell me what their removal was like without using insertion as a reference point? Or what I should expect during the procedure?
#
# -------------------------------------------
#
# [TITLE: someone tell me whether or not i should be worried?]
#
# Made a throwaway for this. My gf and I(M) both 17, had a condom break the other night, and I did not notice until after i ejaculated inside her. She has been getting the Depo-Provera for the last 7 or so months. What are the chances she is pregnant? Do i have nothing to worry about? I guess i just want something to help ease the nervousness haha, thanks
#
# -------------------------------------------
#
# [TITLE: is my girlfriend pregnant?]
#
# My partner and I have regular sex; at least once a week, up to three times a week. She is using the contraceptive patch and we don't use condoms on top of this ever.
#
# Recently, about 2-3 weeks ago, we had a scare that she was pregnant. Missed her period, boobs were sore, she felt bloated a lot so I managed to convince her to get a pregnancy test, even though she was adamant she's fine. The result tested as not pregnant but with recent developments I can't shake the feeling she did it wrong somehow, and really is pregnant.
#
# So heres the recent developments:
#
# I went away for a week and once back, she told me she'd missed a period again. At this stage id forgotten about the pregnancy scare so I brushed it off as nothing. Then I found out her boobs were still sore, which I can say was never really like this in the past, so this brought me back into anxiously assuming she's pregnant. Now I do have OCD so I wanna convince myself I'm over-obsessing the situation but once we got back to her house and she got changed, I couldn't help but noticed her stomach looked larger. And what scared me the most, what the disproportionate 'larger' that usually comes with pregnancy. E.g. if you gain weight, the extra fat goes everywhere, not just to the stomach, but this was purely the stomach being larger.
#
# Are pregnancies noticable at 2 months pregnant? Like would it be this noticeable at only 2 months?
#
# I know you might be thinking just talk to her, but she would not get the pregnancy test the first time for ages and now that it showed negative, if I asked again ill look stupid. I really want to know if theres ways I can tell if she's pregnant or not before actually asking.
#
# To conclude/ TL;DR
#
# Girlfriend misses two months worth of periods, boobs hurt, noticeable but not massive enlargement of the stomach, regular sex using only the contraceptive patch, did take a pregnancy test but tested negative, still extremely worried she's pregnant.
#
# -------------------------------------------
#
# [TITLE: can sex drive improve by switching from pills to hormonal iud?]
#
# I'm 27 years old, been on the pill \(estrogen\) for \~6\-7 years now. For years I never had any side effects \(that I'm aware of\) so I never considered switching methods \(don't fix what is not broken mentality\). HOWEVER, for the past 1\-2 years now I have the strong suspicion that the pill is completely killing my sex drive. I blamed it first on work stress, getting older... and just sex dying down after being with my partner for over 5 years... but no, it's REALLY low now and I really think it might be the pill. And either way, I am sick and tired of being on the pill.
#
# Therefore, I want to switch to something different. Right now I'm considering some kind of hormonal IUD \(I will probably be trying for kids in the next 3\-5 years so I think the copper IUD would be overkill. Also I don't want to endure the terrible periods\). I was recommended to go for Kyleena, since it has the lowest hormonal load.
#
# BUT, it is still hormonal BC... Has anyone had any experience with improved sex drive/libido when switching from the pill to a hormonal IUD? Is there hope?? :\(
#
# -------------------------------------------
#
# [TITLE: afraid to try my iud out]
#
# I finally got my second period on my Copper IUD (T380A, similar to Paragard) after all this anxiety I had over getting pregnant despite sex with condoms... I thought I'd get over my anxiety over pregnancy by now but I still can't wrap my head around having sex without condoms and relying solely on the IUD. :'(
#
# Does anyone have advice? will it just take some time getting used to?
#
# -------------------------------------------
#
# [TITLE: missed pill, bad timing.]
#
# Hey Reddit, I have a serious question.
#
# Overall I just feel gross all the time. How do I get my life back!? Going back on the pill isn't an option for me right now.. How do you all manage all these symptoms? Is it normal to be getting hit this hard by going off?
#
# Thanks in advance!
#
# -------------------------------------------
#
# [TITLE: had sex right after taking emergency contraceptive...]
#
# This series of events is going to make me sound like an idiot but here it goes...
#
# I had unprotected sex with a new partner on Saturday night. He climaxed in me without giving me warning. The next day, maybe 12 hours later, i went to the pharmacy and they gave me "Next Choice." I took the pill and shortly after we had unprotected sex again. And once again, even though I'd told him to pull out, he came inside of me.
#
# So i'm wondering if that pill i took protects me against the second time?
#
# Yes, i know unprotected sex is an awful idea if you don't want to get pregnant. I'm in the midst of a spiritual low... My behavior is nothing if not self-destructive.... Thanks for any help.
#
# -------------------------------------------
#
# [TITLE: inactive pills week, no period. i have doubts. anyone with similar experiences? help!]
#
# Had sex the days 14, 15 and 19 of the packet. I waited the recommended seven days and chose to not have sex until I finished the second week of the pack (starting the third week). I've been taking the pill everyday at the same time, haven't missed any. Haven't taken any meds but Sertraline and Loratadine for allergies (as long as I've been told, they DON'T interact with bc pills) PLUS I've been using condoms, the three times I had sex, to be extra sure.
# These are my questions (I'm new at this, this is my first month so bare with me please):
# 1. Does it make pregnancy more probable the fact that I didnt start the pills the first day of my period and intead started the FIRST SUNDAY after my last period STARTED? (the information that came with the pill listed this as a possibility, but it warns that I should wait 7 days to have unprotected sex, which I DID, I waited two full weeks to have sex)
# 2. I'm having terrible brest pain, my breast are bigger, tense and painful at touch. This was common before too, one week prior to my periods they would hurt, BUT NOT THIS MUCH! I've read that this is a common side effect of the pill, but also, this is a common early symptom of pregnancy. I've been experiencing nausea at night, before I go to bed too, which is also associated with pregnancy.
# Can symptoms of pregnancy show this early on? (It's been roughly 9 days since I became sexually active for the first time) Can the nausea be associated with the TIME I take the pill? I take it everyday at 6pm sharp.
# 3. What are my chances? I thought birth control pills plus condoms should be super safe.. but I'm in my 4th day of sugar pills and still no sign of blood. Not even a bit. I'm scared. But I don't know if buying a pregnancy test is necessary FOR REAL or not. I don't want to tell my mom about this.
# Please be kind and patient, I'm a super anxious person, but I've always been regular on my period and this is scaring me.
# I didn't want to post this because even I think all I need is reassurance, but me and my mom aren't close and I'm a first year student in another city far from home, so I don't know anyone here that well.
# ANY experience, opinions and advice you guys can provide I'll be grateful for. Thanks for your time, strangers.
# (This is a throwaway account, I don't want this on my personal reddit account since my friends use reddit too)
#
# -------------------------------------------
#
# [TITLE: ellaone with a high bmi]
#
# Hello, just a quick recap of the last 24hours - just had unprotected sex after being poorly last week and realised that my everyday contraceptive is no longer 99% effective ive just purchased EllaOne (morning after pill)
#
# I’ve just read that the high your BMI the less effective it is. I won’t lie, my BMI is quite high at 38.
#
# Does anybody have any insight to how effective it is with a high BMI?
#
# P.S - sorry if this sounds silly but slightly panicking!! Lol
#
# -------------------------------------------
#
# [TITLE: the monthly pregnancy scare]
#
# Im on the pill and i take it every single day, ive never missed a pill in the 2 years ive been taking it and was only "late" a handful of times, none of which were this past month. Every single month i get so scared that im pregnant. My period is supposed to come today, and im FREAKING OUT. Ive already taken a test, and it came out negative. I have been shifting to lighter periods that start later in these 2 years, so maybe it's just going to start later, but I cant relax until I see even a bit of pink spotting. Sometimes i consider going on a birth control where i dont get periods, but I will flip out even more. I hate this so much
#
# -------------------------------------------

# %% [markdown]
# <br><br>
#
# # Explore TWITTER posts

# %%
examples = db.get_dataset('birth-control-all-labels-twitter-posts')

print(len(examples))
# Out:
# 460

# %%
label_total_count_dict = defaultdict(int)
for e in examples:
    for _label in e['accept']:
        label_total_count_dict[_label] += 1

print('------------------------------------------------------')
print('total number of tweets labeled')
print('[out of 4,395 total]')
print('------------------------------------------------------')
print()
for _label, _count in sorted(label_total_count_dict.items(), key=lambda x: x[1], reverse=True):
    print(_count, '\t', _label)
# Out:
# ------------------------------------------------------
# total number of tweets labeled
# [out of 4,395 total]
# ------------------------------------------------------
#
# 205 	 DISCOURSE
# 131 	 PROVIDING INFORMATIONAL SUPPORT
# 101 	 PROVIDING EXPERIENCES
# 39 	 SEEKING EMOTIONAL SUPPORT
# 21 	 SEEKING EXPERIENCES
# 21 	 SEEKING INFORMATIONAL SUPPORT
# 1 	 PROVIDING EMOTIONAL SUPPORT

# %%
print(examples[0])
# Out:
# {'text': "President Obama &amp; HHS will fine all participants in Obamacare who won't pay for Oral Contraception $36,000.00 per year per person. #TYRANNY", 'meta': {'ID': 504048215810113540, 'Source': 'twitter-posts'}, '_input_hash': -1270619619, '_task_hash': -1560586231, 'options': [{'id': 'SEEKING INFORMATIONAL SUPPORT', 'text': 'SEEKING INFORMATIONAL SUPPORT'}, {'id': 'PROVIDING INFORMATIONAL SUPPORT', 'text': 'PROVIDING INFORMATIONAL SUPPORT'}, {'id': 'SEEKING EMOTIONAL SUPPORT', 'text': 'SEEKING EMOTIONAL SUPPORT'}, {'id': 'PROVIDING EMOTIONAL SUPPORT', 'text': 'PROVIDING EMOTIONAL SUPPORT'}, {'id': 'SEEKING EXPERIENCES', 'text': 'SEEKING EXPERIENCES'}, {'id': 'PROVIDING EXPERIENCES', 'text': 'PROVIDING EXPERIENCES'}, {'id': 'DISCOURSE', 'text': 'DISCOURSE'}], '_session_id': None, '_view_id': 'choice', 'accept': ['DISCOURSE'], 'answer': 'accept'}

# %%
label_positive_percent_dict = {_label: _positive_count/float(len(examples)) for _label, _positive_count in label_total_count_dict.items()}

print('------------------------------')
print('percent of reviews with label')
print('------------------------------')
print()
for _label, _percent in sorted(label_positive_percent_dict.items(), key=lambda x: x[1], reverse=True):
    print(str(round(_percent*100, 1)) + '%', '\t', _label)
# Out:
# ------------------------------
# percent of reviews with label
# ------------------------------
#
# 44.6% 	 DISCOURSE
# 28.5% 	 PROVIDING INFORMATIONAL SUPPORT
# 22.0% 	 PROVIDING EXPERIENCES
# 8.5% 	 SEEKING EMOTIONAL SUPPORT
# 4.6% 	 SEEKING EXPERIENCES
# 4.6% 	 SEEKING INFORMATIONAL SUPPORT
# 0.2% 	 PROVIDING EMOTIONAL SUPPORT

# %%
label_examples_dict = defaultdict(list)
for e in examples:
    for _label in e['accept']:
        label_examples_dict[_label].append(e['text'])

for _label, _examples in label_examples_dict.items():
    if _label == 'SEEKING EMOTIONAL SUPPORT':
        print('===========================================')
        print(_label)
        print('===========================================\n')
        for e in _examples:
            print(e)
            print('-------------------------------------------')
        print()
# Out:
# ===========================================
# SEEKING EMOTIONAL SUPPORT
# ===========================================
#
# I want the IUD so bad but I’m scared 🥺🙄
# -------------------------------------------
# i cannot believe there’s a non-hormonal oral contraceptive that’s been on the market for thirty YEARS but it’s only available in india. this world is a sick joke
# -------------------------------------------
# Thank you Jesus no more implanon !! Bck to basic birth control !!*praise the lord I'm free*
# -------------------------------------------
# I'm at the lady doctor... Recommend some BC for me... I lowkey want the IUD or Mirena but, people scare me with their horror stories
# -------------------------------------------
# I'm so nervous to get this nexplanon put it 😰
# -------------------------------------------
# Ok so I’m having really bad cramps Rn and i JUST got off my period. If having the iud is just constant cramps idk if i can do this shit
# -------------------------------------------
# Finally able to get this nexplanon removed as of tomorrow!!!
# -------------------------------------------
# I'm anti BC but WHO AINT GETTING AN IUD ON SEPT 5th???????? THIS GIRL IS!!!
# -------------------------------------------
# i hope this IUD doesn’t fuck up my body
# -------------------------------------------
# my body is literally going to be in so much pain this week😭 i get my teeth pulled tmrw i just got my implant out so my arm is sore n this iud is giving me hell
# -------------------------------------------
# I made my appointment to possibly get my iud im so excited. I hope this will help me shed this intense weight
# -------------------------------------------
# That voice in the back of my head that likes babies is trying to convince me that when my nexplanon gets removed in 2021 that I will definitely want another kid. Legit. Shoot me before I multiply 😂
# -------------------------------------------
# I’m crampy today so it’s either my vagina is expelling my IUD, or my IUD has migrated, or I’m ovulating, or my body’s just saying fuck you you’re not allowed to forget you can bear children even if you don’t want to. It’s a toss up, really.
# -------------------------------------------
# accidentally dropped my birth control pill in the trash yesterday so my mood is fucked to shit lmao
# -------------------------------------------
# heres a summary of how my week is going: my boyfriend tells me he thinks it better if we split, my contracted hours at work are cut, i am told i can't have my iud re-fitted or removed because of the virus, my dad has told me hes coughed up blood, i gained 4lbs👍👍👍
# -------------------------------------------
# Working half a day today because I woke up with a migraine and period cramps from hell. Getting a iud was a good idea but holy fuck do these cramps hurt 😭
# -------------------------------------------
# Idk how to ask the medical dude for a contraceptive pill. I heard it helps with cramps.
# -------------------------------------------
# Does anyone have an IUD? Have y’all ever couldn’t find your strings? Google is scaring me 😒😩
# -------------------------------------------
# Getting my nexplanon replaced 🥴 I’m so nervous
# -------------------------------------------
# Going to get my IUD taken out... If this hurts as bad as putting it in I will no longer be here k thanks
# -------------------------------------------
# Ugh! It's not like I'm here for a huge appointment. I just want my effing iud checked so I can get on with my baby-free life!
# -------------------------------------------
# RT @d_79 And I was so busy today that I forgot to take my birth control pill. #fml my period is going to be fucked up this month.
# -------------------------------------------
# the nexplanon birth control got the worst side effects I’ve ever seen on a commercial like wtf 😭
# -------------------------------------------
# I’ve been on hold for like 20 min just give me my frickin IUD just shove it in already
# -------------------------------------------
# I’m going to get an IUD in my coochie again today and I’m so relieved. To 5 more years without periods or babies 🥂
# -------------------------------------------
# Just finished telling my mom how shitty it was that she scared me off getting an IUD when I was a teenager, because this is thoroughly good.
# -------------------------------------------
# my iud experience has been the absolute fucking worse.
# -------------------------------------------
# I've heard horror stories about the iud perforating, migrating, and doing terrible things. Gonna try to wait it out til tomorrow, bc...
# -------------------------------------------
# Stupid fucking IUD is fucking with my hormones and dangerously impacting my mental health. Foolproof birth control versus suicidal urges &gt;.&lt;
# -------------------------------------------
# It’s times like these that I’m grateful I got an IUD months ago and sad that I had to have the foresight that it was something I should do
# -------------------------------------------
# That IUD really wrecked my shit 🥴 I’m hurtingggg
# -------------------------------------------
# Took out the nexplanon and my skin is going back to normal!! I’m so happy!!!!
# -------------------------------------------
# IUD, Implant, PAP Smear, wish me luck
# -------------------------------------------
# got my nexplanon implant out bc i’m not fucking anyone + effexor kills my sex drive anyways and ofc now i’m so fucking horny this shit is so unfair but a weighted blanket + my vibrator still gets the job done better than a man could ok send tweet
# -------------------------------------------
# Here we go: I have an appointment on September 8th to have my IUD removed. I am so excited. http://bit.ly/oH8ZK3 #infertility #ttc
# -------------------------------------------
# Found out an IUD costs $700. :/
# -------------------------------------------
# Well fucccccccck Implanon is expensive! But it lasts 3 years...upfront cost=less than pills for 3 years. fuck blah.
# -------------------------------------------
# Fun fact. After an extended IUD implant replacement procedure (Google says it takes 5 minutes, mine was 35 minutes) booze doesn't stop the cramps 12 hours later. Ya just don't care. *thank u unofficial advice of my gyno who was as emotionally done as I was physically by the end*
# -------------------------------------------
# I'm low key scared of that Nexplanon tho. Anything can say you won't be pregnant for 3-5 years seems it will make you infertile
# -------------------------------------------

# %% [markdown]
# <br><br>
#
# # Explore Twitter REPLIES

# %%
examples = db.get_dataset('birth-control-all-labels-twitter-replies')

print(len(examples))
# Out:
# 500

# %%
label_total_count_dict = defaultdict(int)
for e in examples:
    for _label in e['accept']:
        label_total_count_dict[_label] += 1

print('------------------------------------------------------')
print('total number of tweets labeled')
print('[out of 4,395 total]')
print('------------------------------------------------------')
print()
for _label, _count in sorted(label_total_count_dict.items(), key=lambda x: x[1], reverse=True):
    print(_count, '\t', _label)
# Out:
# ------------------------------------------------------
# total number of tweets labeled
# [out of 4,395 total]
# ------------------------------------------------------
#
# 246 	 PROVIDING EXPERIENCES
# 163 	 DISCOURSE
# 124 	 PROVIDING INFORMATIONAL SUPPORT
# 19 	 SEEKING EMOTIONAL SUPPORT
# 16 	 SEEKING INFORMATIONAL SUPPORT
# 15 	 PROVIDING EMOTIONAL SUPPORT
# 11 	 SEEKING EXPERIENCES

# %%
label_positive_percent_dict = {_label: _positive_count/float(len(examples)) for _label, _positive_count in label_total_count_dict.items()}

print('------------------------------')
print('percent of reviews with label')
print('------------------------------')
print()
for _label, _percent in sorted(label_positive_percent_dict.items(), key=lambda x: x[1], reverse=True):
    print(str(round(_percent*100, 1)) + '%', '\t', _label)
# Out:
# ------------------------------
# percent of reviews with label
# ------------------------------
#
# 49.2% 	 PROVIDING EXPERIENCES
# 32.6% 	 DISCOURSE
# 24.8% 	 PROVIDING INFORMATIONAL SUPPORT
# 3.8% 	 SEEKING EMOTIONAL SUPPORT
# 3.2% 	 SEEKING INFORMATIONAL SUPPORT
# 3.0% 	 PROVIDING EMOTIONAL SUPPORT
# 2.2% 	 SEEKING EXPERIENCES

# %%
label_examples_dict = defaultdict(list)
for e in examples:
    for _label in e['accept']:
        label_examples_dict[_label].append(e['text'])

for _label, _examples in label_examples_dict.items():
    if _label == 'SEEKING INFORMATIONAL SUPPORT':
        print('===========================================')
        print(_label)
        print('===========================================\n')
        for e in _examples:
            print(e)
            print('-------------------------------------------')
        print()
# Out:
# ===========================================
# SEEKING INFORMATIONAL SUPPORT
# ===========================================
#
# @iAmMissKarma whats IUD?
# -------------------------------------------
# @fanxybean WTF IS A KYLEENA?!!?! https://t.co/zMSLGkNk0o
# -------------------------------------------
# @amberj__ I’ve heard of the IUD what’s the bar? The thing that goes into your arm or something?
# -------------------------------------------
# @LauraHolland The pill, as in the contraceptive pill?
# -------------------------------------------
# @linkHalfway Which was a condom or birth control pill right?
# -------------------------------------------
# @bcphoto can you not wear a cup with an iud?
# -------------------------------------------
# @SafeeraHussainy I got the emergency contraceptive pill recently from @ChemistWhouse. The pharmacist said it was a legal requirement that I fill out/sign the PSA checklist. I called later to query this and the pharmacist said PSA guidelines are still up-to-date. Is this true?
# -------------------------------------------
# @Olwe2Lesh How often should I be checking on my iud, asking for a friend 🤔
# -------------------------------------------
# @susanwalkergirl @MattWalshBlog @dolphzd How does celibacy help with the other medical issues that birth control pill can solve?
# -------------------------------------------
# @DrStevenTChen Hey Dr sorry to ask but my erythema nodosum has flared back and is more painful than it has ever been. It is caused by oral contraception consumption and when I am under a high amount of stress if triggers the flare. I was given Prednisone last time it happened
# -------------------------------------------
# @iluvcats95 That’s great that it’s better now! I’m worried bc I went on some threads and Paragard has people bleeding extra heavy and cramping bad and Mirena seems to be similar but eventually goes away. Technically I don’t know if mirena would be better since it’s still hormonal but it
# -------------------------------------------
# @trumpet_kenny Alex has been on an IUD since he was 16, they made an exception due to his dysphoria so he didn’t have as bad of pain as you did. Is it tied to testosterone?
# -------------------------------------------
# @WeHear_ForYou wait they don't give you strong pain killers after an IUD? 'cause im scared now
# -------------------------------------------
# @TomiLahren hey I was wondering where I could get that $9 a month oral contraceptive you were talking about?
# -------------------------------------------
# @meg_merritt @PaigeCams @MichaelaOkla What’s the difference between kyleena and mirena except the size?
# -------------------------------------------
# @haiiluna @khaleesikittenn Is iud the best birth control.... in u guys opinion
# -------------------------------------------

# %% [markdown]
# <br><br>
#
# # Backup labeling into a CSV

# %%
reddit_post_examples = db.get_dataset('birth-control-all-labels-reddit')
reddit_comment_examples = db.get_dataset('birth-control-all-labels-reddit-comments')
reddit_extra_examples = db.get_dataset('birth-control-all-labels-reddit-extra')
twitter_post_examples = db.get_dataset('birth-control-all-labels-twitter-posts')
twitter_replies_examples = db.get_dataset('birth-control-all-labels-twitter-replies')

# %%
len(reddit_post_examples), len(reddit_comment_examples), len(reddit_extra_examples), len(twitter_post_examples), len(twitter_replies_examples)
# Out:
# (500, 500, 53, 500, 500)

# %%
reddit_comment_examples[0]
# Out:
# {'text': "You should take it easy for the first week at least, you'll have bruising and it'll be tender. \n\nJust go with your body! I've had mine for almost 3 months and I don't notice it at all, the insertion mark is a tiny dot on my arm. Unless you were actively looking/feeling for it - you'd never know!",
#  'meta': {'ID': 'exeejsv', 'Source': 'reddit-comments'},
#  '_input_hash': -246065321,
#  '_task_hash': 529846214,
#  'options': [{'id': 'SEEKING INFORMATIONAL SUPPORT',
#    'text': 'SEEKING INFORMATIONAL SUPPORT'},
#   {'id': 'PROVIDING INFORMATIONAL SUPPORT',
#    'text': 'PROVIDING INFORMATIONAL SUPPORT'},
#   {'id': 'SEEKING EMOTIONAL SUPPORT', 'text': 'SEEKING EMOTIONAL SUPPORT'},
#   {'id': 'PROVIDING EMOTIONAL SUPPORT', 'text': 'PROVIDING EMOTIONAL SUPPORT'},
#   {'id': 'SEEKING EXPERIENCES', 'text': 'SEEKING EXPERIENCES'},
#   {'id': 'PROVIDING EXPERIENCES', 'text': 'PROVIDING EXPERIENCES'},
#   {'id': 'DISCOURSE', 'text': 'DISCOURSE'}],
#  '_session_id': None,
#  '_view_id': 'choice',
#  'accept': ['PROVIDING INFORMATIONAL SUPPORT', 'PROVIDING EXPERIENCES'],
#  'answer': 'accept'}

# %%
label_dicts = []
for e in reddit_post_examples + reddit_comment_examples + reddit_extra_examples + twitter_post_examples + twitter_replies_examples:
    for _label in e['accept']:
        label_dicts.append({'Source': e['meta']['Source'],
                            'ID': e['meta']['ID'],
                            'Label': _label,
                            'Text': e['text']})
label_df = pd.DataFrame(label_dicts)

# %%
len(label_df)
# Out:
# 2570

# %%
label_df.sample(3)
# Out:
#                Source                   ID                  Label  \
# 2134  twitter-replies  1110522567302004700  PROVIDING EXPERIENCES
# 2344  twitter-replies  1319984836921184300  PROVIDING EXPERIENCES
# 781   reddit-comments              dzjo6xk  PROVIDING EXPERIENCES
#
#                                                    Text
# 2134  @aardvarkwizard @J_M_T_ @tiarala OH I REMEMBER...
# 2344  @DarTwoDeeTwo @JessicaValenti YES! I have the ...
# 781   I would use it if I had a life modelling gig o...

# %%
label_df.to_csv('/Volumes/Passport-1/data/birth-control/labeling/labeled_by_maria.all.csv')

# %%
import pickle

data_directory_path   = '/Volumes/Passport-1/data/birth-control'

id_type_dict1 = pickle.load(open(data_directory_path + '/labeling/reddit_comments.id_type_dict.pickle', 'rb'))
id_type_dict2 = pickle.load(open(data_directory_path + '/labeling/reddit.id_type_dict.pickle', 'rb'))

# %%
for e in reddit_extra_examples:
    _id = e['meta']['ID']
    assert _id in id_type_dict or _id in id_type_dict2
